# %%
# week 1
# !pip install PyPDF2 spacy pandas
# !python -m spacy download en_core_web_sm
# !pip install PyPDF2 spacy pandas requests
# !python -m spacy download en_core_web_sm
# !pip install gdown
# Out:
# Requirement already satisfied: PyPDF2 in /usr/local/lib/python3.11/dist-packages (3.0.1)
# Requirement already satisfied: spacy in /usr/local/lib/python3.11/dist-packages (3.8.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.11/dist-packages (from spacy) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.15.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.11.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.4.26)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 63.9 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# Requirement already satisfied: PyPDF2 in /usr/local/lib/python3.11/dist-packages (3.0.1)
# Requirement already satisfied: spacy in /usr/local/lib/python3.11/dist-packages (3.8.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.11/dist-packages (from spacy) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.15.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.11.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.4.26)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 106.7 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown) (4.13.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown) (3.18.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2025.4.26)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (1.7.1)

# %% [markdown]
# USING API to look for papers online

# %%
# Install required libraries
# !pip install pymed arxiv semanticscholar

import sqlite3
import pandas as pd
from pymed import PubMed
import arxiv
from semanticscholar import SemanticScholar
import re
from datetime import datetime

# Function to clean text (simple preprocessing)
def clean_text(text):
    if not text or pd.isna(text):
        return ""
    text = re.sub(r'\s+', ' ', text)  # Normalize whitespace
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation
    return text.strip().lower()

# Function to initialize or update the research_papers table
def initialize_db(db_name="healthcare_research.db"):
    conn = sqlite3.connect(db_name)
    cursor = conn.cursor()
    # Drop the existing table and recreate with full schema
    cursor.execute("DROP TABLE IF EXISTS research_papers")
    cursor.execute('''
        CREATE TABLE research_papers (
            filename TEXT PRIMARY KEY,
            cleaned_text TEXT,
            title TEXT,
            source TEXT,
            publication_date TEXT
        )
    ''')
    conn.commit()
    conn.close()
    print("Initialized research_papers table with updated schema.")

# Function to fetch and store papers
def collect_research_papers(db_name="healthcare_research.db", max_per_source=20):
    conn = sqlite3.connect(db_name)
    cursor = conn.cursor()

    # Initialize counters
    total_papers = 0

    # --- PubMed ---
    pubmed = PubMed(tool="ResearchPaperCollector", email="your_email@example.com")  # Replace with your email
    query = "healthcare innovation"
    results = pubmed.query(query, max_results=max_per_source)
    for article in results:
        title = article.title or "Untitled"
        abstract = article.abstract or ""
        pub_date = article.publication_date.strftime('%Y-%m-%d') if article.publication_date else "Unknown"
        filename = f"pubmed_{article.pubmed_id}"
        cleaned_text = clean_text(abstract)  # Full text not available via API, using abstract
        try:
            cursor.execute('''
                INSERT OR IGNORE INTO research_papers (filename, cleaned_text, title, source, publication_date)
                VALUES (?, ?, ?, ?, ?)
            ''', (filename, cleaned_text, title, "PubMed", pub_date))
            total_papers += 1
            print(f"Added {filename} from PubMed")
        except sqlite3.IntegrityError:
            print(f"Skipping duplicate {filename}")

    # --- arXiv ---
    arxiv_client = arxiv.Client()
    search = arxiv.Search(
        query="healthcare",
        max_results=max_per_source,
        sort_by=arxiv.SortCriterion.SubmittedDate
    )
    for result in arxiv_client.results(search):
        title = result.title or "Untitled"
        summary = result.summary or ""
        pub_date = result.published.strftime('%Y-%m-%d') if result.published else "Unknown"
        filename = f"arxiv_{result.entry_id.split('/')[-1]}"
        cleaned_text = clean_text(summary)  # Full text not directly available, using summary
        try:
            cursor.execute('''
                INSERT OR IGNORE INTO research_papers (filename, cleaned_text, title, source, publication_date)
                VALUES (?, ?, ?, ?, ?)
            ''', (filename, cleaned_text, title, "arXiv", pub_date))
            total_papers += 1
            print(f"Added {filename} from arXiv")
        except sqlite3.IntegrityError:
            print(f"Skipping duplicate {filename}")

    # --- Semantic Scholar ---
    sch = SemanticScholar()
    search = sch.search_paper(query="healthcare innovation", limit=max_per_source)
    for paper in search:
        title = paper.title or "Untitled"
        abstract = paper.abstract or ""
        pub_date = paper.year if paper.year else "Unknown"
        filename = f"semanticscholar_{paper.paperId}"
        cleaned_text = clean_text(abstract)  # Full text not available, using abstract
        try:
            cursor.execute('''
                INSERT OR IGNORE INTO research_papers (filename, cleaned_text, title, source, publication_date)
                VALUES (?, ?, ?, ?, ?)
            ''', (filename, cleaned_text, title, "Semantic Scholar", str(pub_date)))
            total_papers += 1
            print(f"Added {filename} from Semantic Scholar")
        except sqlite3.IntegrityError:
            print(f"Skipping duplicate {filename}")

    # Commit and close
    conn.commit()
    conn.close()
    print(f"Collected and stored {total_papers} papers in total.")

# Main execution
if __name__ == "__main__":
    initialize_db()
    collect_research_papers(max_per_source=20)  # 20 from each source = 60 total
# Out:
# Requirement already satisfied: pymed in /usr/local/lib/python3.11/dist-packages (0.8.9)
# Requirement already satisfied: arxiv in /usr/local/lib/python3.11/dist-packages (2.2.0)
# Requirement already satisfied: semanticscholar in /usr/local/lib/python3.11/dist-packages (0.10.0)
# Requirement already satisfied: requests>=2.20.0 in /usr/local/lib/python3.11/dist-packages (from pymed) (2.32.3)
# Requirement already satisfied: feedparser~=6.0.10 in /usr/local/lib/python3.11/dist-packages (from arxiv) (6.0.11)
# Requirement already satisfied: tenacity in /usr/local/lib/python3.11/dist-packages (from semanticscholar) (9.1.2)
# Requirement already satisfied: httpx in /usr/local/lib/python3.11/dist-packages (from semanticscholar) (0.28.1)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.11/dist-packages (from semanticscholar) (1.6.0)
# Requirement already satisfied: sgmllib3k in /usr/local/lib/python3.11/dist-packages (from feedparser~=6.0.10->arxiv) (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20.0->pymed) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20.0->pymed) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20.0->pymed) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20.0->pymed) (2025.4.26)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx->semanticscholar) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx->semanticscholar) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx->semanticscholar) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx->semanticscholar) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx->semanticscholar) (4.13.2)
# Initialized research_papers table with updated schema.
# Added pubmed_40327459 from PubMed
# Added pubmed_40327390 from PubMed
# Added pubmed_40327384 from PubMed
# Added pubmed_40327329 from PubMed
# Added pubmed_40327286
# 27918725
# 33766750
# 17537614
# 20668052
# 33754023
# 19641587
# 35210368
# 17384583
# 9446642
# 32392088
# 34753510
# 35134463
# 33045622
# 24382354
# 21440622
# 23474486
# 35273493
# 30053525
# 38574433
# 37154056
# 26232232
# 33314649
# 32468629
# 11709088
# 37425037
# 23325925
# 10628339
# 36435202
# 32112883
# 24058702
# 31883358
# 38323433
# 26112889
# 17250813
# 37871668
# 33437153
# 38150302
# 38316068
# 29061338
# 27567406
# 35914558
# 37714227
# 36510036
# 32958254
# 29304479 from PubMed
# Added pubmed_40327095
# 32984198
# 31953750
# 15955855
# 10352583
# 16615053
# 23958828
# 14531007
# 29306987
# 12677511
# 21643638
# 20093572
# 19022993
# 21567143
# 26736224
# 15114491
# 23285596
# 22764084
# 27330520
# 14974593
# 18400271
# 15476531
# 23793577
# 19255628
# 32613678 from PubMed
# Added pubmed_40327021 from PubMed
# Added pubmed_40326881 from PubMed
# Added pubmed_40326805 from PubMed
# Added pubmed_40326781 from PubMed
# Added pubmed_40326754 from PubMed
# Added pubmed_40326742 from PubMed
# Added pubmed_40326724 from PubMed
# Added pubmed_40326514 from PubMed
# Added pubmed_40326410 from PubMed
# Added pubmed_40326302 from PubMed
# Added pubmed_40325945 from PubMed
# Added pubmed_40325894 from PubMed
# Added pubmed_40325870 from PubMed
# Added pubmed_40325830 from PubMed
# Added arxiv_2505.02751v1 from arXiv
# Added arxiv_2505.02694v1 from arXiv
# Added arxiv_2505.02470v1 from arXiv
# Added arxiv_2505.02238v1 from arXiv
# Added arxiv_2505.02228v1 from arXiv
# Added arxiv_2505.02173v1 from arXiv
# Added arxiv_2505.02062v1 from arXiv
# Added arxiv_2505.02024v1 from arXiv
# Added arxiv_2505.02008v1 from arXiv
# Added arxiv_2505.01866v1 from arXiv
# Added arxiv_2505.01821v1 from arXiv
# Added arxiv_2505.01783v1 from arXiv
# Added arxiv_2505.01651v1 from arXiv
# Added arxiv_2505.01576v1 from arXiv
# Added arxiv_2505.01543v1 from arXiv
# Added arxiv_2505.01277v1 from arXiv
# Added arxiv_2505.01096v1 from arXiv
# Added arxiv_2505.01091v1 from arXiv
# Added arxiv_2505.00941v1 from arXiv
# Added arxiv_2505.00918v1 from arXiv
# Added semanticscholar_6e7b07d3fc06e2332107eefa4325e54f16d1cb1a from Semantic Scholar
# Added semanticscholar_386fe40398087a63ba0e2e8c646b678244b85461 from Semantic Scholar
# Added semanticscholar_8157f3f9c1be66f448ee0589cbb4b699e2f9e1a8 from Semantic Scholar
# Added semanticscholar_78e1aec5f05d0b435ca119ebce1b55bd85124fcb from Semantic Scholar
# Added semanticscholar_f2f453f4f3cbb342bd45d1104ea5a15e3e814d07 from Semantic Scholar
# Added semanticscholar_7680092a1dab52c9db1972085610470e7b9465b5 from Semantic Scholar
# Added semanticscholar_14881b7be6f8c409d766cbd7c2c5db9450baf9e8 from Semantic Scholar
# Added semanticscholar_d50bc2f0b4c0b858c1887b923c562e21731e54b2 from Semantic Scholar
# Added semanticscholar_71402259d3073e789d8eba0367ecf87e8def79b8 from Semantic Scholar
# Added semanticscholar_cf7bbcfbeae7ad78594cd39556d348f8b90e4988 from Semantic Scholar
# Added semanticscholar_e8678b399310baa26cdbc42ec75f37adc8a112f2 from Semantic Scholar
# Added semanticscholar_fe771cc1c6d6f0403bf0e30048a9cbc34263e200 from Semantic Scholar
# Added semanticscholar_c8f6ca89c0b0e99028d38d73f149cf6d180dbafb from Semantic Scholar
# Added semanticscholar_90f3b8904f2735de916fbbd6906f7745590a5a01 from Semantic Scholar
# Added semanticscholar_e376965b86dce35866c8f9d76ea967ddee96e9f3 from Semantic Scholar
# Added semanticscholar_e6fd611e426b1a2b38a8f8682e4d07aa61d9839a from Semantic Scholar
# Added semanticscholar_333fdaabc15bb8e7e9b2386ff1b7cb4a42c9855a from Semantic Scholar
# Added semanticscholar_41246b1805d4c35ac6c575c2e4146225ebfec0e1 from Semantic Scholar
# Added semanticscholar_650a366890e65390e4ed1cc8c134cf2540928706 from Semantic Scholar
# Added semanticscholar_b5a6a7bc2a3234ed162287d8c3f6782ac0c95b48 from Semantic Scholar
# Added semanticscholar_2eb675abb55e48406d0dfe24ecef09d200a5f1ff from Semantic Scholar
# Added semanticscholar_54fb8f91de3166af35064a5b9f8d521ae785791a from Semantic Scholar
# Added semanticscholar_46a3c95a10907ff9003387b501173c6f709a55d3 from Semantic Scholar
# Added semanticscholar_3a0f0bcea2ece1892caa0eb702dcb8b3fe9ffac4 from Semantic Scholar
# Added semanticscholar_4a0faf540174e072e8440ded65057c10d5964667 from Semantic Scholar
# Added semanticscholar_035e9cd81d5dd3b1621fb14e00b452959daffddf from Semantic Scholar
# Added semanticscholar_dc4a70cb41612703a4e0ac94d883c1abe82b2fc2 from Semantic Scholar
# Added semanticscholar_e55dabadb91d28c2fd00afaf4be49c7144845abd from Semantic Scholar
# Added semanticscholar_edfad9cb15febd303ed930b9462539df7059f473 from Semantic Scholar
# Added semanticscholar_21a76ab24e50f3d0690e839f313e6963d79e95c8 from Semantic Scholar
# Added semanticscholar_68c1c45da73d232dfe351870b129f44039ca0129 from Semantic Scholar
# Added semanticscholar_09eb0319a81a548edbcfaf894c7dffc60b502edd from Semantic Scholar
# Added semanticscholar_2e85e45c367b02d59c29eacbd95dbf65dab77fcf from Semantic Scholar
# Added semanticscholar_02c6cada355425284c4533e244356c43b21e9507 from Semantic Scholar
# Added semanticscholar_82f731b9f127cf682b29f3111b8a789e0147865e from Semantic Scholar
# Added semanticscholar_8ca6dc0c2320c81a45107c6176580a5948544782 from Semantic Scholar
# Added semanticscholar_f6389aff7b977adcf55bb5910127e18a21da593f from Semantic Scholar
# Added semanticscholar_8f729f8e898e64a5c56741b41216ad786ccd97c1 from Semantic Scholar
# Added semanticscholar_286e6f95ee536ffc9c99477fbff7927d86003619 from Semantic Scholar
# Added semanticscholar_cf6d8164c74a25e4119e23f69d5ab8412f11a609 from Semantic Scholar
# Added semanticscholar_cf6d8164c74a25e4119e23f69d5ab8412f11a609 from Semantic Scholar
# Added semanticscholar_bd8050e477fdbacc8f65bfb207f6ad12c586a5ed from Semantic Scholar
# Added semanticscholar_0d23516441fc5e2b616e46affb6e5ea1e00e1044 from Semantic Scholar
# Added semanticscholar_1ad53bae43ed95b4edcd463065356ca143fe7af5 from Semantic Scholar
# Added semanticscholar_a27b40d323eb98b10115f28f8a0fe1957eda40c8 from Semantic Scholar
# Added semanticscholar_374bda97d2de12046e6324607911ed22e6f48cb1 from Semantic Scholar
# Added semanticscholar_f601141f187b0c99429b2619c5fbb85888e132df from Semantic Scholar
# Added semanticscholar_e4ff102c17bf869a3bea02ccc72775b7c55e8ad2 from Semantic Scholar
# Added semanticscholar_428c161cbd3a8f9150010c486af3099d166b491e from Semantic Scholar
# Added semanticscholar_53d9c883de5f75369faf4c7e0eeb4a5110fa390f from Semantic Scholar
# Added semanticscholar_e02083b119100609612724552cbdfa7249a55bca from Semantic Scholar
# Added semanticscholar_03b61b6886a7d066e3b008f727bf06adf797b222 from Semantic Scholar
# Added semanticscholar_4943781074f37a3768f52fa1757a0cf5a9f51db7 from Semantic Scholar
# Added semanticscholar_2fba87886961b502416dace3cdaf44387629c134 from Semantic Scholar
# Added semanticscholar_4756fbd25aa0d65f336730cf2eb43d4c8f4beee1 from Semantic Scholar
# Added semanticscholar_789735aa46c0d97fb73f3ab8aa62511251e54604 from Semantic Scholar
# Added semanticscholar_ad6ce4a1d8a11208fc19b3dd17b5f0e96f40d2ab from Semantic Scholar
# Added semanticscholar_960c3417ac5500575b1ab1f64f478fd52fcdfc16 from Semantic Scholar
# Added semanticscholar_3fb042a4ad98aa8e9f3ea11bce8676dee6e2de4b from Semantic Scholar
# Added semanticscholar_4bf266fe2809db66cfb896bdb060302346d214be from Semantic Scholar
# Added semanticscholar_8e460a050511bc0cca84a4c28c80e06162a13b50 from Semantic Scholar
# Added semanticscholar_c160bc4f02f75199c8edf9239126b0729cfae465 from Semantic Scholar
# Added semanticscholar_eca3e31d7f37fb586e6bdf5bf8df6e60db0ba135 from Semantic Scholar
# Added semanticscholar_c19015b925ab9083a5addcd76ebf0192ff455844 from Semantic Scholar
# Added semanticscholar_82c3f2ce5a93e397611dd860cd1a5159b6d0809a from Semantic Scholar
# Added semanticscholar_9af09ff23e6bb9cc8316b51a8772d036e7a3b2c1 from Semantic Scholar
# Added semanticscholar_056d86a6599429db18a31ec04d037589295e9028 from Semantic Scholar
# Added semanticscholar_5c4ded20583de8216232e62b83503ef8b2c0ee63 from Semantic Scholar
# Added semanticscholar_c593c1adf858050fdf09c840e71e815cf1bcf5c9 from Semantic Scholar
# Added semanticscholar_5611b42596ff91b4319ea25379e71d6589adc327 from Semantic Scholar
# Added semanticscholar_3b39e8321996180a4f6a0609c876c15f73e039e9 from Semantic Scholar
# Added semanticscholar_d5ef3cdac56ebd3121579e263e1623ae2926913e from Semantic Scholar
# Added semanticscholar_c4739da86061103a52ee628133c0c8ce5dc11353 from Semantic Scholar
# Added semanticscholar_693fa610798d760d70fe1fb92d1cfd685d93bb8c from Semantic Scholar
# Added semanticscholar_379c269f70ad7a7437367893fa394c33399d7e77 from Semantic Scholar
# Added semanticscholar_009ad4aabd241dda2905d07933cd7347f326a2b8 from Semantic Scholar
# Added semanticscholar_37d899488dbf70b247d9ec99992b5bb12fcfdaf2 from Semantic Scholar
# Added semanticscholar_3eb43bedda8240244a47f3144561608731f68f26 from Semantic Scholar
# Added semanticscholar_08f8217037a004433a24f6a5be2a8b8c63a0d470 from Semantic Scholar
# Added semanticscholar_c9c5756f6bb25d5dc222f8dfbfd4bf349acbcdea from Semantic Scholar
# Added semanticscholar_9629e1e882d17f51a6dadaa1d5349e2198b0a7b5 from Semantic Scholar
# Added semanticscholar_85e42ad30ef2bd78273f46b05a406dd265a42cbb from Semantic Scholar
# Added semanticscholar_54924924c4c4ecc73320a5466e34a22ca5f62ba7 from Semantic Scholar
# Added semanticscholar_7369f51ae86b07ff91362deacb2820e042054942 from Semantic Scholar
# Added semanticscholar_8ec9a9ee4c4bbbbe76b53c174145c2b8a7a29978 from Semantic Scholar
# Added semanticscholar_0777ca86319c1f44e9ffdb458571adb028d65925 from Semantic Scholar
# Added semanticscholar_666e4983f9eb5396266a2bef598ebe4a883447a2 from Semantic Scholar
# Added semanticscholar_dbb6a5534fb1216b678f822c00c15bcae1d23f00 from Semantic Scholar
# Added semanticscholar_69f31f547788c33ba66b25cbfaffd7bbbac753e6 from Semantic Scholar
# Added semanticscholar_973aa725aa80b0bbd51a899b4db72b5f94a28e64 from Semantic Scholar
# Added semanticscholar_c1e1e971d993a50fa470710bb7a7bbbb4ce5b1af from Semantic Scholar
# Added semanticscholar_9c6c7cd4133357c4ead8f0c3ca3727063dd57b84 from Semantic Scholar
# Added semanticscholar_7fe59291a57aa743ca42a91199d4519e214c328f from Semantic Scholar
# Added semanticscholar_8fd904d492b2250752e7ffbfd210f5331f5994c0 from Semantic Scholar
# Added semanticscholar_56d65b54e02b5fb5b1d690fd6ffd2b2839b28294 from Semantic Scholar
# Added semanticscholar_d3dd9b5a6d927cb3974d58467dfda03ce22289dc from Semantic Scholar
# Added semanticscholar_2721971f2e525e55c03dc6cd231deb65d9d06438 from Semantic Scholar
# Added semanticscholar_b2eb39cf9f99e49dc2ebe4f52ee8c3f8ada6dcfc from Semantic Scholar
# Added semanticscholar_e77a6fc69b4f30e3c28253dfa83e14b72bbc8597 from Semantic Scholar
# Added semanticscholar_7783d83cd68c99106d637537ba3291b0ff432b3b from Semantic Scholar
# Added semanticscholar_df558a3daf22955fe42f4bbeb1415f6607b67567 from Semantic Scholar
# Added semanticscholar_673132dce3103851763663a42c28073a665a8b2d from Semantic Scholar
# Added semanticscholar_b515eb7cade478e41280d724a846aa70037d85df from Semantic Scholar
# Added semanticscholar_44d4dd3163749490a92922536e8ea60615a6c9c6 from Semantic Scholar
# Added semanticscholar_b2e9c91a9c909977991438e508af9e5c00388aad from Semantic Scholar
# Added semanticscholar_0e64cdbac3b13b08d0836e00062caec71631e57a from Semantic Scholar
# Added semanticscholar_136d4add842368a398e6549e4389a54354899eff from Semantic Scholar
# Added semanticscholar_20547a8aa2545921ea4515b17d8fc3b7780c234f from Semantic Scholar
# Added semanticscholar_3649c4cbde4f5d81de774b7fae366f19ad9fb3aa from Semantic Scholar
# Added semanticscholar_38fe11166e85ae06d0af0aecdcb9a6a0e6275f74 from Semantic Scholar
# Added semanticscholar_395aad5ec8f591913253f531c979f56fc3029d2d from Semantic Scholar
# Added semanticscholar_ab4c13eb618057bf98b8f6c1e3e7120eefc43ddc from Semantic Scholar
# Added semanticscholar_bb678afa2685e6493f9875b66ac2b32dce5e7e9b from Semantic Scholar
# Added semanticscholar_ee86393e9889e3735f57c9adf5990d41f10c5d22 from Semantic Scholar
# Added semanticscholar_f623cd030c74a8bb7c2aae2f8bcd1dd8325bef32 from Semantic Scholar
# Added semanticscholar_bc561f967f300a14d61c35247a908318956a502b from Semantic Scholar
# Added semanticscholar_33566ed3adfdbd7c950d1d02a113a5b78513cb36 from Semantic Scholar
# Added semanticscholar_6d85819e23c463b602830728751f4c292c77a9d4 from Semantic Scholar
# Added semanticscholar_2414e25d0a59be3b0cd3caa8db7b9328ef118c2d from Semantic Scholar
# Added semanticscholar_37556b31ac092d8872db064e9afc44b1cd2f47be from Semantic Scholar
# Added semanticscholar_5c8073c7c908c65e41ec11bb6c43b4a80848178a from Semantic Scholar
# Added semanticscholar_6b7af1b8442ec82ab63610448197f7c883385e6d from Semantic Scholar
# Added semanticscholar_a49c9ac390039a1be7344b7c8f03a5fcd3d696f5 from Semantic Scholar
# Added semanticscholar_9929a068d29503413b93a0e26896e88c7ae1c29c from Semantic Scholar
# Added semanticscholar_1f9ee8bc72bfcd31a23f6b592518af3e67e48597 from Semantic Scholar
# Added semanticscholar_482967072c8f0751cb326cd22dba7d6fecc21d98 from Semantic Scholar
# Added semanticscholar_50301a231a41fe3dffd89b8a19f818c554a0a389 from Semantic Scholar
# Added semanticscholar_732e2d5f2ad782710ab08d89545906bc97579ef1 from Semantic Scholar
# Added semanticscholar_64cee874b4214f94e6db61b84f6097f97c1b1216 from Semantic Scholar
# Added semanticscholar_991f0e9a39455c2e7d90b6cd3ea8144acdda0cc6 from Semantic Scholar
# Added semanticscholar_4f67cc883f007614fbd42dd4948b466c265e2938 from Semantic Scholar
# Added semanticscholar_7830588b35f5ba4a7e98df572c86790ee959e4ca from Semantic Scholar
# Added semanticscholar_e78d9a379ee348c6ce048056ac35a61d2eb32376 from Semantic Scholar
# Added semanticscholar_3dc26a373298e2e7848823021a31a829eee5beb3 from Semantic Scholar
# Added semanticscholar_fb5e621fd31a8f0d5116d4d2e2beb2d11b5a7361 from Semantic Scholar
# Added semanticscholar_340e1e09fe3c5b98ed2835360f9bb87dbfee3858 from Semantic Scholar
# Added semanticscholar_8c7dbf117c22d3413fc7c91463fb20dc1fca78b7 from Semantic Scholar
# Added semanticscholar_1c4e74510b0257727f35c421f93a54e0727c1f0c from Semantic Scholar
# Added semanticscholar_3efe88c120819c08143ede15b9ccac04f3b00b36 from Semantic Scholar
# Added semanticscholar_36e40ddee4e6c5ffe82f70889176e0c28c3d8aed from Semantic Scholar
# Added semanticscholar_caa0a90d8d746ecb4b1fb115767cfef5b6bae0b1 from Semantic Scholar
# Added semanticscholar_9e0782de01c63712eddd9930fa73a7babe7452e5 from Semantic Scholar
# Added semanticscholar_18740741a4f5536c7e4b0efa7992a77299d87f1f from Semantic Scholar
# Added semanticscholar_e53b8666519da7a1d577c838159d301de5d8b90f from Semantic Scholar
# Added semanticscholar_02ea3610c071966159accc5c816c6c3ffa871aff from Semantic Scholar
# Added semanticscholar_e26ef616143f7bdde98ff7c23403ab42b4fb6901 from Semantic Scholar
# Added semanticscholar_4062c5c579b3f307e14977725ce20fac87527498 from Semantic Scholar
# Added semanticscholar_66fa19493838d43074ef4eb46f9bc1ad7d17e423 from Semantic Scholar
# Added semanticscholar_a8594df3a3aaa6264fbf00030374e2542729f260 from Semantic Scholar
# Added semanticscholar_eb6f3f02404976a0d9ee771e1330a7bede735897 from Semantic Scholar
# Added semanticscholar_4893c9b1b0e99bf3be1f2ce533a4b4752ae1a6ff from Semantic Scholar
# Added semanticscholar_8cdba45b11698cef9fc96e1920d04d00bbefd9e1 from Semantic Scholar
# Added semanticscholar_ecb555071b6d04c8266056bc10d23a314e176958 from Semantic Scholar
# Added semanticscholar_655bd8c11b2489426abe0ef6bb3384cb625aa57c from Semantic Scholar
# Added semanticscholar_cd811e941c44c6a31959ccf0e8183801cbf4d291 from Semantic Scholar
# Added semanticscholar_8a5da714d01365c55f344de0616b0e44536750a5 from Semantic Scholar
# Added semanticscholar_6d70b411ffbee540673951ae13afe987865bd2e4 from Semantic Scholar
# Added semanticscholar_89fb44297ebaa1c6908479da86322909132be6ee from Semantic Scholar
# Added semanticscholar_b3327e8c1571bb0e2e65ff41d9d9c7700991cf21 from Semantic Scholar
# Added semanticscholar_738ddd45d4e9a075ae93aa5528b63e81a6a09ae7 from Semantic Scholar
# Added semanticscholar_cc7392d0514c8c5e3e45e3fa9513596a58640623 from Semantic Scholar
# Added semanticscholar_7ca78ae4dbe943b9b5d78c7dfcba7f88cd088343 from Semantic Scholar
# Added semanticscholar_eb617ab7017997cc047bb81a29be5a378e00c02a from Semantic Scholar
# Added semanticscholar_820923c859c110c03ff79639055af123ab8c7e6e from Semantic Scholar
# Added semanticscholar_94c8c8b4125f2fc8b141e60ebb25213ff7427b70 from Semantic Scholar
# Added semanticscholar_fdbd1350e14171eaebd82eb2b11ee9141b0963c2 from Semantic Scholar
# Added semanticscholar_903e4648b47bb0acfb57c3ced9729499774b7b57 from Semantic Scholar
# Added semanticscholar_4814237990c2916ff783b6b77ea0b09ee701a4dd from Semantic Scholar
# Added semanticscholar_bfb6542da475c8fb5712dc85bc5b972f4f0bb589 from Semantic Scholar
# Added semanticscholar_e9650176e09979926947c653b246328720c6d5f9 from Semantic Scholar
# Added semanticscholar_e05ba0020d6382b436c180d168fbfa289b616f4d from Semantic Scholar
# Added semanticscholar_2e39846444e149098d141d9fb39c3eaf3928ed3e from Semantic Scholar
# Added semanticscholar_4a4a2ccc19d41e2642fe797b303b2f398e93a912 from Semantic Scholar
# Added semanticscholar_487ee0e58d699ae0aa7c64233c9633f3d084b973 from Semantic Scholar
# Added semanticscholar_a1179741c1db18506b3c667d83fb31e4f5e13398 from Semantic Scholar
# Added semanticscholar_1e9a754e5b60161cd99f017fa6641ae1acee5b3e from Semantic Scholar
# Added semanticscholar_a1eb35cc4494e48dd587203366b49ba6ba3594ed from Semantic Scholar
# Added semanticscholar_67eb1b19b5b5d3f8209c25b2e9611d74ba9457f6 from Semantic Scholar
# Added semanticscholar_bfafc7589e98af46f164e8b9b73c899260070229 from Semantic Scholar
# Added semanticscholar_342ab99d9219bdccbcb307a4f933cb7e51e51c80 from Semantic Scholar
# Added semanticscholar_dd7b11fefab05d92923bde35c84305ab3b96fda8 from Semantic Scholar
# Added semanticscholar_b20d75cc72fa529974a2a3c7a0d614c05a733fdc from Semantic Scholar
# Added semanticscholar_8ece9a6cdfd6ff1b25f92768fa0356a57c90df33 from Semantic Scholar
# Added semanticscholar_94149c8b50ae89978433d965aea937a2e0077d8c from Semantic Scholar
# Added semanticscholar_e21beac4201b565b8d881311c9c8cce7ad1362cb from Semantic Scholar
# Added semanticscholar_3ed0db58a7aec7bafc2aa14ca550031b9f7021d5 from Semantic Scholar
# Added semanticscholar_e45e5bc3e1bdad1c8fa49ebd9ab863ece9e785e6 from Semantic Scholar
# Added semanticscholar_4f728e5d0fb5575a1c1547a338c53779be4dfaed from Semantic Scholar
# Added semanticscholar_4aabb8a7c60060239ed236ed8b6fe5818c2e975d from Semantic Scholar
# Added semanticscholar_6bc897c05523c212a9630c1494ad2795ae610c18 from Semantic Scholar
# Added semanticscholar_45cf2fea37858d0fa446a954e0bedd24ed3de9c5 from Semantic Scholar
# Added semanticscholar_582ad10b10b13e9e97b2e8bac314cccbac9c60a0 from Semantic Scholar
# Added semanticscholar_98ee255b86dea6a71c9e65d512f7476d263439fe from Semantic Scholar
# Added semanticscholar_bce43a15423c7b1b049cfec2d923cb2352f646df from Semantic Scholar
# Added semanticscholar_a0c82ecc13ec21a9bd339dd36a0b6a80cb6f521f from Semantic Scholar
# Added semanticscholar_4e164481df2f4317ad2552daf0be01b4c2af5531 from Semantic Scholar
# Added semanticscholar_0507d09681b05fe3db73b1df241f8055559c3d4e from Semantic Scholar
# Added semanticscholar_6380518596352a0be5e9612812a15e1d366212bf from Semantic Scholar
# Added semanticscholar_e565bc2ca7767eb7d5c2282a03946d27c6b12294 from Semantic Scholar
# Added semanticscholar_6aeeb865aca80aa30bb2ee6ba0e42d41c6220645 from Semantic Scholar
# Added semanticscholar_fdc5179a0068e8b84424de26bf355cedad249422 from Semantic Scholar
# Added semanticscholar_a5fb2790be9ea6326b8bb21795b8344faafb475f from Semantic Scholar
# Added semanticscholar_9f0cb0e4dce2daf3a4fb624b4d6e89d9a4280b74 from Semantic Scholar
# Added semanticscholar_1ca10199c89785895f204c4be81cf2316167c24f from Semantic Scholar
# Added semanticscholar_8fd934cee2a571952aeb90db0e752cf446d273eb from Semantic Scholar
# Added semanticscholar_c99577b334c2d151cac086b4b5a590c4678dbeb4 from Semantic Scholar
# Added semanticscholar_6d819f14cfb95df86ceccf53cec8cc7794bd6f9c from Semantic Scholar
# Added semanticscholar_0326932f09a540ecc63e42072af608a59db6e602 from Semantic Scholar
# Added semanticscholar_38ac6ad1e3b9646f03b6d99f50ee312f2df5dd3c from Semantic Scholar
# Added semanticscholar_fd953a36992e3f2e0806bcbe280e05f26f4a710f from Semantic Scholar
# Added semanticscholar_25f4b12a94ffc40593087ad3b3824ff29831be57 from Semantic Scholar
# Added semanticscholar_eb4a4d50610c19767936a4bd6fcd740509a4314a from Semantic Scholar
# Added semanticscholar_368763addecc9cc62e87c2dcd71f10ad171c4a7b from Semantic Scholar
# Added semanticscholar_c3e4eefcaac995833a258634292b22b5960287a8 from Semantic Scholar
# Added semanticscholar_a9d52b468187afb7bbae35b576d2e08c85717b35 from Semantic Scholar
# Added semanticscholar_2ebb87d3ec1b0f949ca836c65bc9c2ccfb7db98c from Semantic Scholar
# Added semanticscholar_98642f121bfaf3bb6deb045516650528db04ecc4 from Semantic Scholar
# Added semanticscholar_03667c5cb3b2e685743d0c76c394e218fbc32d4e from Semantic Scholar
# Added semanticscholar_bdc5c520b3eeeaee80198e482ed8070427a322c2 from Semantic Scholar
# Added semanticscholar_0b6252259cf78d0e2e24c3faf3da248b6d37226c from Semantic Scholar
# Added semanticscholar_eb6a68ed1250fa6cb3318b2f6c0b887ef85fb047 from Semantic Scholar
# Added semanticscholar_e84d39ab8491deb640aa87dbde33961f86be5e34 from Semantic Scholar
# Added semanticscholar_1b38202e9243878aaa2cd82172bd12ecaf6c2adb from Semantic Scholar
# Added semanticscholar_515e4277a268ff7fd83ddfd355503bf9c9e5ede7 from Semantic Scholar
# Added semanticscholar_da422f6e82cab7ced4f6cbfe4a7383f15437c844 from Semantic Scholar
# Added semanticscholar_92a13c9b3b4a34ccafc485aaa255ae43edf3c655 from Semantic Scholar
# Added semanticscholar_3df8dce8bbdb9dea5f6ade66e95880f50c300cf4 from Semantic Scholar
# Added semanticscholar_78ce793c5b1ab80450780d2ba92e3931d13bc026 from Semantic Scholar
# Added semanticscholar_d8b4ae975076aec4a826d65850fe8741b525bb7d from Semantic Scholar
# Added semanticscholar_325bd5eb738f847e5016fe536a41ac310e78f1f4 from Semantic Scholar
# Added semanticscholar_4848a787aee70448214c00c1d4b551227969b94f from Semantic Scholar
# Added semanticscholar_c392b4533659ae039c7c761b3764d8f3b55f43a2 from Semantic Scholar
# Added semanticscholar_fca789e057ca0c6ed3c1a4bf19be80c261003e16 from Semantic Scholar
# Added semanticscholar_3d9116fb4a75e2ab8c47a94ecb40a23a707324a6 from Semantic Scholar
# Added semanticscholar_bceb59a6c696990cb7ece1646062adbad2e6189b from Semantic Scholar
# Added semanticscholar_e19cbab9fb23d5170e65bda39926dd5da2d1c138 from Semantic Scholar
# Added semanticscholar_fcb9cfc2275787d6e9c78022284520b7e18bd895 from Semantic Scholar
# Added semanticscholar_4a14a851c1c393b83c317d1bc85b95e77092c38d from Semantic Scholar
# Added semanticscholar_6c54dce835c732948d3a877722ab23948a2b7562 from Semantic Scholar
# Added semanticscholar_12b413befc9ded4d72b84ebcdee06ba28cf7b90f from Semantic Scholar
# Added semanticscholar_45e01e301877e8d50485ad925958216073aaa0e3 from Semantic Scholar
# Added semanticscholar_b1b9d899f27733f1270c9809721b8865bbf66400 from Semantic Scholar
# Added semanticscholar_09c2ac984b26fcb7949454d2dda6c45800b79a05 from Semantic Scholar
# Added semanticscholar_8c04cc9854b363629f7ee673515985627702d879 from Semantic Scholar
# Added semanticscholar_b0c5410bf7ecc6f81fbdaab660a897f6a2eba944 from Semantic Scholar
# Added semanticscholar_82690746cdc142e9b3a72757513819a15c733eca from Semantic Scholar
# Added semanticscholar_fac9053637e7f490d6bd4edee24a90f58865e16b from Semantic Scholar
# Added semanticscholar_3e7dabbea88d45d961b9c6b1de98ba5325a45317 from Semantic Scholar
# Added semanticscholar_6c7da9c38e60774ece709110ba50f4f6adb607d2 from Semantic Scholar
# Added semanticscholar_30b8fcd5c72f495f092af2c3f7303f657ad80996 from Semantic Scholar
# Added semanticscholar_3cffb8ff68c168702f0bfb4b49021aacf2d47ac4 from Semantic Scholar
# Added semanticscholar_8ddc50257cc90d675a7ef967362a078227f798a7 from Semantic Scholar
# Added semanticscholar_022bb5ff6e1dce8eeeb6833c859450a391ba43ea from Semantic Scholar
# Added semanticscholar_3d2b95682e4167f62878c88cb9265f9267de0465 from Semantic Scholar
# Added semanticscholar_2f794410c588d38dc9c9ed1791e7013f2813fa0b from Semantic Scholar
# Added semanticscholar_f7fd93b25217d27868d203f882377c3d0d1fe6e9 from Semantic Scholar
# Added semanticscholar_64228bc0cdff11df5d1a2b314bd5ab04f0959736 from Semantic Scholar
# Added semanticscholar_7e1b1b122183ce860e7e7372079a7052ac4001b7 from Semantic Scholar
# Added semanticscholar_9b7e83d52e96caf8fe09bebe981f07c3144cd065 from Semantic Scholar
# Added semanticscholar_91fcb6d026aa8b775543255f5f8e91475ec7a5c5 from Semantic Scholar
# Added semanticscholar_95036c3b68b9455e0d8a8a6b5be0b8877132aa09 from Semantic Scholar
# Added semanticscholar_c5ea16763e5c509cc7b1270945354de4812fa7a9 from Semantic Scholar
# Added semanticscholar_20d528d2e38b5e72c899ebf5c263847be0b47906 from Semantic Scholar
# Added semanticscholar_0cc825ef618ee62854d29027e5ac30bbde2ceb8f from Semantic Scholar
# Added semanticscholar_d66d9690d2f8bdc763bff35fe38bcefa2e391fc2 from Semantic Scholar
# Added semanticscholar_036fbc99a76a1d6610c634c622f42f53b1efbed3 from Semantic Scholar
# Added semanticscholar_06a989f4b46a92f44e871a7eb80499b8bfdbc189 from Semantic Scholar
# Added semanticscholar_b46fa93ab5b626b5d1109e5f4b35cbab34f925b6 from Semantic Scholar
# Added semanticscholar_21b67d3921b7bf20634588e3b3ae3e97ff8acf6f from Semantic Scholar
# Added semanticscholar_0962a11f0f5f891b0b36d99fb9e6ac30578d3c65 from Semantic Scholar
# Added semanticscholar_b2bb5401225c2061bec2cea24e6005cdd7fd0fba from Semantic Scholar
# Added semanticscholar_38a516096aceacb3b5327e19dd36070b82bb1309 from Semantic Scholar
# Added semanticscholar_4155f8bd6b35cd5b8c67bc2d06717cb7e6500313 from Semantic Scholar
# Added semanticscholar_36d7913bce4077821cc4fe8c298f7ab65b5c3469 from Semantic Scholar
# Added semanticscholar_24a99d9de44c1a438bfc9a668f81be7357f5abfa from Semantic Scholar
# Added semanticscholar_619a4afbc0485427586ce7e7405ab306ba0e40f9 from Semantic Scholar
# Added semanticscholar_14d99d5d497c953754ba710b0a46874ed201d73a from Semantic Scholar
# Added semanticscholar_287d2b088fe66086ab4df6c59c14231121c9eb71 from Semantic Scholar
# Added semanticscholar_a51746334f6fe268790ca033fd687948733923b7 from Semantic Scholar
# Added semanticscholar_8b1a78a90fa2a77fee57393833356e534e70d3f6 from Semantic Scholar
# Added semanticscholar_dec0f7066bc11cadba42837f68314b4bd08e27ec from Semantic Scholar
# Added semanticscholar_d7548c80b4cf7d2107a125f62f9edc222f66fb2d from Semantic Scholar
# Added semanticscholar_41af1e81fd4d7d8423be964be51d68b581a84f11 from Semantic Scholar
# Added semanticscholar_a461fe778f9f9e91804f22ddbd2505f607a891f1 from Semantic Scholar
# Added semanticscholar_bc4577754c4218ce071254116cb499b931e57ec7 from Semantic Scholar
# Added semanticscholar_2d6d00ac46739c0db869e52ddaf0207dec4dbf1b from Semantic Scholar
# Added semanticscholar_9fb6bd2c024c143168af8747dc20dc2095d2de6f from Semantic Scholar
# Added semanticscholar_4b826cbd683ef89dcd515690cadce1d5465b6054 from Semantic Scholar
# Added semanticscholar_b858a3ffe813c7d368115899502edb2a0888e524 from Semantic Scholar
# Added semanticscholar_b3581fdcfba97d45f7772fda13c83915405923ee from Semantic Scholar
# Added semanticscholar_6bacc1ce948182e026f07f0aba6f7107dfb04312 from Semantic Scholar
# Added semanticscholar_34fe897b13f599f76dc1fb53e41809454b322748 from Semantic Scholar
# Added semanticscholar_cdb5f5e020d90903a5ef3d09e1066bb23ebe80cf from Semantic Scholar
# Added semanticscholar_640e81930d25d623aaa650bdd124ebf0def1ed23 from Semantic Scholar
# Added semanticscholar_3ce6848c24c64e67a557b3aa27417d14cb89428b from Semantic Scholar
# Added semanticscholar_4fbc955c340d6a1a986d5a5441c1b4de7b50a14e from Semantic Scholar
# Added semanticscholar_6523ff03da2e4876b86fe820e73463c5b7ee1a6b from Semantic Scholar
# Added semanticscholar_ba23c15b06d931086aa237971f17f215fc43fc3c from Semantic Scholar
# Added semanticscholar_9af842d0dc3f01722c87b5aefe809f42fadc3394 from Semantic Scholar
# Added semanticscholar_de2c06089aef5e980b2e84b5ae7d19850a737a35 from Semantic Scholar
# Added semanticscholar_6f385c478e34717e4cadf425c95870606cec4cda from Semantic Scholar
# Added semanticscholar_800cb5bd3d36796778d6e3bfda00f89f7514e05d from Semantic Scholar
# Added semanticscholar_e52da59e3c0a195cd267a73f2a5221fb3a0af2b0 from Semantic Scholar
# Added semanticscholar_dd3b6575386a2f2952c02bdf70518a5feee1451e from Semantic Scholar
# Added semanticscholar_8c2b170da5593c413ac59c90502ed3c80db05c04 from Semantic Scholar
# Added semanticscholar_29d49ddf54098d877b0db94ef6a4b59984c81acf from Semantic Scholar
# Added semanticscholar_6ec28aaded577704a3d195cbee49c823a4eaf502 from Semantic Scholar
# Added semanticscholar_9271f6fe705a27e705985f6c5bb241c0cf7cf3af from Semantic Scholar
# Added semanticscholar_b8688e4eb6cd8a97214e4217535c38c6f45ce624 from Semantic Scholar
# Added semanticscholar_d974a232773fc90a240fb812c5b4a49bc6e414e6 from Semantic Scholar
# Added semanticscholar_ec519383546e12a94f6cdb2e48498e391350e3cd from Semantic Scholar
# Added semanticscholar_4549aff2ee68b95605244306810b263b85e7b864 from Semantic Scholar
# Added semanticscholar_4cd7b3ed6feda0eae5013866aa4fc8cb97cc7066 from Semantic Scholar
# Added semanticscholar_cd93305a8f0074bde9418c04fbe5a09aee0c1f20 from Semantic Scholar
# Added semanticscholar_6535acb612579a45a204350c2bd856b58122a47f from Semantic Scholar
# Added semanticscholar_23668f2ba307a6c157e697383f559c5493d77c51 from Semantic Scholar
# Added semanticscholar_6286e16cc3524f8fb8d6f87657969867162a21d3 from Semantic Scholar
# Added semanticscholar_5c564172f68514c78cf3f4e6c22a0066b156e71b from Semantic Scholar
# Added semanticscholar_d31046615ea2505e1ea4251634aaf88ab302d50e from Semantic Scholar
# Added semanticscholar_7651f988d688145bb797a34f6969f90687b64b2e from Semantic Scholar
# Added semanticscholar_7651f988d688145bb797a34f6969f90687b64b2e from Semantic Scholar
# Added semanticscholar_c589802d0544597f009ece053742b9ed928bb06b from Semantic Scholar
# Added semanticscholar_4f5f61b2b5ffbdd81808806f6dbef6b68b128f0d from Semantic Scholar
# Added semanticscholar_91b6e23d58a6e7fbfa6c74bbe0e006b5ac3a63cd from Semantic Scholar
# Added semanticscholar_afe39bc03837cb98ae73d2a67b63326c446c5e28 from Semantic Scholar
# Added semanticscholar_20391630e7b80dd9e735a64b978f9f0631f13b4e from Semantic Scholar
# Added semanticscholar_48c5499b977b06e663b954f47523713b34b48df1 from Semantic Scholar
# Added semanticscholar_e4a2bfadcee200c9370de6d58489ecb4dfb43e31 from Semantic Scholar
# Added semanticscholar_d185e69532a0b881ec9df5f5018590fd459f181a from Semantic Scholar
# Added semanticscholar_4478313b27a121757e03a3b894e9d1de85477469 from Semantic Scholar
# Added semanticscholar_bd1283f8c92a90fbef8bd21a674dd0a772d0be85 from Semantic Scholar
# Added semanticscholar_d8110032990dc8f603068c031f4125c3fc2c8d0d from Semantic Scholar
# Added semanticscholar_d667dd1aac4573deaa01055e4354209471652b8c from Semantic Scholar
# Added semanticscholar_681119bb27d093a4c9893cfa1c758e76c92e5da5 from Semantic Scholar
# Added semanticscholar_d7c64d3b4690401c7637b01fbe416940dd824e28 from Semantic Scholar
# Added semanticscholar_c9e90b606f760a9e6c1e7d826eb902cd7507a330 from Semantic Scholar
# Added semanticscholar_623bccc73d2becaedfb93e1d13f960ff6ba04c67 from Semantic Scholar
# Added semanticscholar_a00628d26798ba9770e45ef9e41e1a6eeca94fae from Semantic Scholar
# Added semanticscholar_782e6b7b66ded9cc1db7e99b828df72f750cfd7d from Semantic Scholar
# Added semanticscholar_04a6c8174f539cb0f8782abe8ec81cd8eae43a98 from Semantic Scholar
# Added semanticscholar_ddbebd1d724490b0d455e30a4c5123904f533cc8 from Semantic Scholar
# Added semanticscholar_7b2b257aa04334727a636601821969830bcf8c04 from Semantic Scholar
# Added semanticscholar_be4b811ed61400ded046d088de6004368db77835 from Semantic Scholar
# Added semanticscholar_23edf3b72d4704e1d34b0fd956a014de09ab684f from Semantic Scholar
# Added semanticscholar_6ca176b223b644ecd035683dbda2361ebaa5d780 from Semantic Scholar
# Added semanticscholar_f5696055bc1e16b3a0fef185b88495134f3d0216 from Semantic Scholar
# Added semanticscholar_abbf1c3f93cdf6865b35e2de7a19efab49eb1c3f from Semantic Scholar
# Added semanticscholar_a08c8c6330be2e65b02c62885a7e4ea249cd18f8 from Semantic Scholar
# Added semanticscholar_da968e6541e2a5f1e57f44f95d2b5d6d4060188a from Semantic Scholar
# Added semanticscholar_da594bfc53f61c1fe1e818251fb010cf180f94d0 from Semantic Scholar
# Added semanticscholar_3a918fce0b45df1c87e448249b898b474040c1b2 from Semantic Scholar
# Added semanticscholar_7c96fe5cbcab9b715a5f366780e5e40edc2f421a from Semantic Scholar
# Added semanticscholar_2e3c354fd61fd5aa2d0ed93a651c31ef3281afba from Semantic Scholar
# Added semanticscholar_b1e7c835bea4a260decab7a877aec04fc2f3b325 from Semantic Scholar
# Added semanticscholar_ff6a7a79c849a02ca0462bd1c7bf95893c9e72d2 from Semantic Scholar
# Added semanticscholar_2708fb1c628f369b016193e0763029963dfbe5b3 from Semantic Scholar
# Added semanticscholar_bbf5cc2e5f9d65db44d73f75ea50dfabe80acea3 from Semantic Scholar
# Added semanticscholar_e392cac1a222b2ce6b3db9a476bda9115887edf9 from Semantic Scholar
# Added semanticscholar_bfb334cca2ca7a509b265f64a1fbba7db125ba17 from Semantic Scholar
# Added semanticscholar_62b2d82f4eb38ac83a8de2c1d660004671c2b248 from Semantic Scholar
# Added semanticscholar_22e4a3e7f29c083bb14b115bebd484fbab3f681c from Semantic Scholar
# Added semanticscholar_6f4dabd18935601e82ac774bf56d2ffad28f6966 from Semantic Scholar
# Added semanticscholar_e0acaaa50615f42c378bbcecbedc4bd60e38f08a from Semantic Scholar
# Added semanticscholar_690618456fd3c90ffa4a03468ea67bf8426d6f5b from Semantic Scholar
# Added semanticscholar_2c9644f2a22729dd5d327d8f0faa75b9c13e8091 from Semantic Scholar
# Added semanticscholar_d98d816979f56f10f98b5418aeaddb323c907473 from Semantic Scholar
# Added semanticscholar_c2e399354428690888c3dd83ac0c46441e4623ab from Semantic Scholar
# Added semanticscholar_858d9ec5c9c1c7b9d17576c4294c311518f68e12 from Semantic Scholar
# Added semanticscholar_ff1119cc806683b932f439360b1fe106a0fb9613 from Semantic Scholar
# Added semanticscholar_eb8c94a2b171de08cf81505e2f356a31ad37f53f from Semantic Scholar
# Added semanticscholar_47202fe996fe5abb61aa84ca441854f11b636179 from Semantic Scholar
# Added semanticscholar_496dc96a78bc15fe6d52dd3ae080b202cd040ebf from Semantic Scholar
# Added semanticscholar_5e28e91fb002767070ac841f806027ca7cd3b958 from Semantic Scholar
# Added semanticscholar_50006f763dd9b6a25941f31c0d58eac6a72a5fb5 from Semantic Scholar
# Added semanticscholar_4bdaeeae549a63557b57bc41050f51ffe8068fbf from Semantic Scholar
# Added semanticscholar_7447f30b9351ab0be9ce3281ee5387b714eb0b78 from Semantic Scholar
# Added semanticscholar_18d0adda41fcb3698203ae0d8f5e8ff1cf85e6e0 from Semantic Scholar
# Added semanticscholar_689f0cd4571585f6ec044520cbbad3f745401cce from Semantic Scholar
# Added semanticscholar_d009233ae5bf2693761a1c1a75507cd6be3d1095 from Semantic Scholar
# Added semanticscholar_0cb8c65e0924907992df1877cb9a92f6598a0fdb from Semantic Scholar
# Added semanticscholar_430ffc89ea01fdde1eb25b719d8942c0eb931932 from Semantic Scholar
# Added semanticscholar_be8acba2011fa2e10eb2ac33da7db4acd741ffca from Semantic Scholar
# Added semanticscholar_51d5406e8e4f1dc24ef595568b32cd719bad8500 from Semantic Scholar
# Added semanticscholar_c58850c9b737339f5e50ea835a3ac04f5dc9fff4 from Semantic Scholar
# Added semanticscholar_cca037b18a25e0c9feeb9e4ee65e88be9873715c from Semantic Scholar
# Added semanticscholar_60d228fedc067ee98ac828fb431917f2bc142dab from Semantic Scholar
# Added semanticscholar_5b2d9393fa0802e781ce7d7be6402b0ddd0d54d6 from Semantic Scholar
# Added semanticscholar_d9f59d99019c3680f6ab7bfd30359a2d826072dc from Semantic Scholar
# Added semanticscholar_09463682de29280de84508a56144be17ab311c83 from Semantic Scholar
# Added semanticscholar_44e98917a233fd0a8482ac7c3a950bbfa37c0f91 from Semantic Scholar
# Added semanticscholar_1ad5c87abfe26cca391640187d5b96d6ac0e5885 from Semantic Scholar
# Added semanticscholar_c216e4f653c620b3f1142aaada8c07b9cf7c8a05 from Semantic Scholar
# Added semanticscholar_bd8a307efcffbf57d2e5c3c23577de44d883d865 from Semantic Scholar
# Added semanticscholar_b8990ccf8665c4912f56a77bcd683018e229737b from Semantic Scholar
# Added semanticscholar_b3b985879daa05faf2705a14f4dcf69e8619c36b from Semantic Scholar
# Added semanticscholar_46d6e059a281a385a0aa0886c1dad43861c9bd46 from Semantic Scholar
# Added semanticscholar_1111ac1598761df8b72df5c287a4e189248dd5c9 from Semantic Scholar
# Added semanticscholar_3423a5724e4a4a3fcf5b13b528659a76fb0b2283 from Semantic Scholar
# Added semanticscholar_1122fa7565b463f0a01c7f91555e9d2ac4380939 from Semantic Scholar
# Added semanticscholar_9c27893061869530128cb7291141d5b827d19089 from Semantic Scholar
# Added semanticscholar_81eb9e2980a7df82de7b8dc4bc109f2cf6be1eb0 from Semantic Scholar
# Added semanticscholar_1342e6383e2b88d6df23ea429f599cebe99a2e02 from Semantic Scholar
# Added semanticscholar_190de1f39e7a2474ff01352debb707fdff44b946 from Semantic Scholar
# Added semanticscholar_a29c42ed30b47974c88d97377125ae8a4a0b9843 from Semantic Scholar
# Added semanticscholar_6a8b1adb29bc37063ed8da2a00c1e69a445eb913 from Semantic Scholar
# Added semanticscholar_e43ce17257af6d444c523fe7f0b3bdfa8cb91e3d from Semantic Scholar
# Added semanticscholar_0102ea439be1377532aa4a4af2ce641aad4e4f9a from Semantic Scholar
# Added semanticscholar_99e0dc0e516264ec96acaff2565e2cf7aa0f35ed from Semantic Scholar
# Added semanticscholar_b275a47a445bb91d16575f3535fa8776ef971d5b from Semantic Scholar
# Added semanticscholar_fa0b41f53e06abc21d2ab2e64f7012e4965a575d from Semantic Scholar
# Added semanticscholar_c17ae08d9c076e924f77b77c937570f060371a2c from Semantic Scholar
# Added semanticscholar_43f0ea1cba2d8a0d96c3a5461c268d3f47277143 from Semantic Scholar
# Added semanticscholar_565b8be8822e970685e571de6aaf5268053b8488 from Semantic Scholar
# Added semanticscholar_8543f4ba5299930d64eb5605be0cb42d3543df15 from Semantic Scholar
# Added semanticscholar_7c63e8f0159422966fce80c31de039dd5ad774b0 from Semantic Scholar
# Added semanticscholar_706aeb2e0499aec457c63cf6c164bda1598e30f9 from Semantic Scholar
# Added semanticscholar_c8fae810282c1e4636c459bd1a2780d4eb2c951e from Semantic Scholar
# Added semanticscholar_dd217e747c5a3d2c928552658b660a2caeb6d281 from Semantic Scholar
# Added semanticscholar_0fa3c3291803d5c0eab8b51984955c15821a12a6 from Semantic Scholar
# Added semanticscholar_3d840fcaca3e16c7afad9a2b168a4c81bb661a9d from Semantic Scholar
# Added semanticscholar_3d840fcaca3e16c7afad9a2b168a4c81bb661a9d from Semantic Scholar
# Added semanticscholar_e89bb48eb4557cf5bb085afe5699b7a82014e9d2 from Semantic Scholar
# Added semanticscholar_8fdb40c613518bfbe992939c43728fe4cf7ffd1b from Semantic Scholar
# Added semanticscholar_afc0234116e2e120675a920ac88262ac9c14b017 from Semantic Scholar
# Added semanticscholar_2cf2c3ab71bd0bcdf9878c4fe8e8dc6aceb7779e from Semantic Scholar
# Added semanticscholar_ffab3dd12084b86c52b29f72f6cefb3a304a57d3 from Semantic Scholar
# Added semanticscholar_f98812340416aea2d0fd028a8283a407fc9773f6 from Semantic Scholar
# Added semanticscholar_dfd75090a4ab1e5cf6a359144239329e99aa6a85 from Semantic Scholar
# Added semanticscholar_84ce38d8a6a08a2b188d46adab17d95834b67a6b from Semantic Scholar
# Added semanticscholar_997667ef4fb9880c3e73968d641f930f8038ade8 from Semantic Scholar
# Added semanticscholar_46c2657d607fa4cdd42887b28a5df01541ae9d38 from Semantic Scholar
# Added semanticscholar_3bbf2b74fc6646b987e4330b08506d39f8bababc from Semantic Scholar
# Added semanticscholar_ff846a199c254b3a40b880cfe1ad71ab7d5a358a from Semantic Scholar
# Added semanticscholar_a3a8b19e298f8766c4e12e1148c04d7fd886639b from Semantic Scholar
# Added semanticscholar_e16d9149a667769d16e53cb75ef6983cf956a463 from Semantic Scholar
# Added semanticscholar_f2f38f9dfd657aad1d087bbbda193683bf360592 from Semantic Scholar
# Added semanticscholar_c6f2f23b95cc8d441c5a9d63270f9bb3cee4edeb from Semantic Scholar
# Added semanticscholar_851bc4dffb8749bd2736bd08ae18fbdc5eff287a from Semantic Scholar
# Added semanticscholar_787ed7a9fcb448924da92f0b8038660f4b4f7e13 from Semantic Scholar
# Added semanticscholar_ae6700c8d1b26e19ef69dab91bfc22de43870f02 from Semantic Scholar
# Added semanticscholar_379319132b68a95808c48fb230b9451167af2c8d from Semantic Scholar
# Added semanticscholar_ccfb5b5675e426771a3c0863a6bed8a30459c7ca from Semantic Scholar
# Added semanticscholar_1580488bcd52ed157f2030708e22fc6ee0abea02 from Semantic Scholar
# Added semanticscholar_223ed293028a130286f050827de4ac8ce501d6e6 from Semantic Scholar
# Added semanticscholar_f25b22281d72aff793b9609e7229a78827856d78 from Semantic Scholar
# Added semanticscholar_4d483eb94ac9367a180c3a820a5833b407ba67bf from Semantic Scholar
# Added semanticscholar_0c8552f79e57df33dd6bf7a48eb009cad9529da0 from Semantic Scholar
# Added semanticscholar_60f6c4ef63c6094ac05d261228f436e9304684b4 from Semantic Scholar
# Added semanticscholar_36c4b3c35cbe6a8de940dd40c2374dd2cb1b42a4 from Semantic Scholar
# Added semanticscholar_c23227d13c45bcf545f46ac16ddef03571216ab2 from Semantic Scholar
# Added semanticscholar_89e006c48f230f957859f533c307f3cbd4fe5408 from Semantic Scholar
# Added semanticscholar_84de730eaee842b7d1c5788ad2d2ffd8ec86264e from Semantic Scholar
# Added semanticscholar_051e677faba6cb04a075928281137ac0299c39ab from Semantic Scholar
# Added semanticscholar_716cc254590ec6143bcdbd9c85ae46a62dd6da9e from Semantic Scholar
# Added semanticscholar_17d415d404e232defc20c9b9c06eae48443ca5e5 from Semantic Scholar
# Added semanticscholar_87dc51d88c3e792ab2072e0303f13ad954c300ef from Semantic Scholar
# Added semanticscholar_6ec8f38b40516be3634860e08d4fe96c903c552f from Semantic Scholar
# Added semanticscholar_df1cd2347b7077014cc1397b4689d4ce4acd97a1 from Semantic Scholar
# Added semanticscholar_fbfa7135a1648cef34288106f59ead1dfb08deea from Semantic Scholar
# Added semanticscholar_18415f502145919e905113c6591621bd6050322f from Semantic Scholar
# Added semanticscholar_fbfa7135a1648cef34288106f59ead1dfb08deea from Semantic Scholar
# Added semanticscholar_18415f502145919e905113c6591621bd6050322f from Semantic Scholar
# Added semanticscholar_5c9d2751ca1da03e4c6f4621759b5e67b51faade from Semantic Scholar
# Added semanticscholar_5f74d8fd097c7ea3da52e68b53fa923a75a282c4 from Semantic Scholar
# Added semanticscholar_c38f9ab80a18b54ae5d66d91dc65549c3c4d6942 from Semantic Scholar
# Added semanticscholar_0b6497e4241f0cfe1dd6e439761557d3bd305224 from Semantic Scholar
# Added semanticscholar_9d2c488d7d375594a303e1945643b600bc062d09 from Semantic Scholar
# Added semanticscholar_c4a883a21b0b9fe2532d94562fa583d0f564a40e from Semantic Scholar
# Added semanticscholar_9454a9b784e1517681048eac4ffeb1542df02208 from Semantic Scholar
# Added semanticscholar_6c127c8dbbe45ac522a1fb1484ea451db9f894e5 from Semantic Scholar
# Added semanticscholar_0eb8871389fcadd2b2501c3d00617ef7dddf5954 from Semantic Scholar
# Added semanticscholar_a74a03549d373238819df29729a833b098eaf9fa from Semantic Scholar
# Added semanticscholar_0dfad4813a3fbd4f1103af75728185664f18d8d9 from Semantic Scholar
# Added semanticscholar_85f7ca5c0fe64401bff3da9ada28a4f302bfc4aa from Semantic Scholar
# Added semanticscholar_33e4ecc1674a9518aea99ce7c790700a92705371 from Semantic Scholar
# Added semanticscholar_67db087e87eb1351e7796b0ec6fda2db5fd8d2fc from Semantic Scholar
# Added semanticscholar_676d324ab2eddca33db0e96f60df08cf9ad0178c from Semantic Scholar
# Added semanticscholar_315f710f4f3f115434fba89e85e1c333ab804b9e from Semantic Scholar
# Added semanticscholar_0d397b8f787bb5afaf379fd28c39b012f87a6da9 from Semantic Scholar
# Added semanticscholar_2edd5e0fef9f7f9fd0262dea937cb997b3ab8d5f from Semantic Scholar
# Added semanticscholar_786fa735e955cc39ed3f19222d20663440baa324 from Semantic Scholar
# Added semanticscholar_f4fc19f54a102e742c6e7e1461b6d12390affcd3 from Semantic Scholar
# Added semanticscholar_b3fedd0f5fffd7602c959d7d58b14a8b8f4609ad from Semantic Scholar
# Added semanticscholar_4637595bcc1c0747b4fd2b15aedf85166a8ba26b from Semantic Scholar
# Added semanticscholar_12e06666ca3ab4d98630b80cc91d81543c7b9eeb from Semantic Scholar
# Added semanticscholar_98dc74ec3941a9fcc6e3d21d0f59d326cb36954a from Semantic Scholar
# Added semanticscholar_60e344d334f4a6ec7c051f05816be93b06767c26 from Semantic Scholar
# Added semanticscholar_eb5b5f92101e8c0a4ba53c90506d9daf9bdec51b from Semantic Scholar
# Added semanticscholar_5a1e6071e8673741abacc4d30f8bee8599f2bca9 from Semantic Scholar
# Added semanticscholar_f27145335f7efd3af594e5f67028480272712083 from Semantic Scholar
# Added semanticscholar_8c5fd34531ca0b47c8d252e9fdf76283fb3f051e from Semantic Scholar
# Added semanticscholar_3d29c84c1f5f1a709b174811935f337817ec5e49 from Semantic Scholar
# Added semanticscholar_19ca96c3de8b3ac619adcd83f8f2099f524eade6 from Semantic Scholar
# Added semanticscholar_23c749987a73b82a2b9185194b1ba399a69d61e8 from Semantic Scholar
# Added semanticscholar_c697a2fa579d8162075c97abd99c01f01b2c3763 from Semantic Scholar
# Added semanticscholar_8180f00ed305b1aa9f2f5a33964f833deb6c3559 from Semantic Scholar
# Added semanticscholar_8fa3c16fbb7777282467c14dbcca8f954a592604 from Semantic Scholar
# Added semanticscholar_ff07b4e1508cf2e4c2d0bb24f82db8d840cc079d from Semantic Scholar
# Added semanticscholar_9729270f42c1066ce4b9c14616a51b659cd093ac from Semantic Scholar
# Added semanticscholar_dc68c732f5787a3446fd8db51fc2b2f831d5c099 from Semantic Scholar
# Added semanticscholar_c84463836aac6c8b4f6d5b6f5dd1c27dbdd7363e from Semantic Scholar
# Added semanticscholar_d2f2223a6a3e2c74636b14cac45e4170a75f2cbe from Semantic Scholar
# Added semanticscholar_2269331c77586698d3b2a2bd69f73531a6f1034a from Semantic Scholar
# Added semanticscholar_4b76cc96ebffcccd5ca37505860f185339ed5f9c from Semantic Scholar
# Added semanticscholar_910cf18a5399b5fc53ed852a281f70e36100a87b from Semantic Scholar
# Added semanticscholar_a7d78b3cfb08e4e0a7f94de3a72f1d564db5c182 from Semantic Scholar
# Added semanticscholar_ce1eaff4daabe4f6782043470b34db7536b0935e from Semantic Scholar
# Added semanticscholar_e3336051f81b58c46397d94aaf926d58f9d6468e from Semantic Scholar
# Added semanticscholar_2f1107c1f7d4e195b904848a54d75978c0631f57 from Semantic Scholar
# Added semanticscholar_6304b3a4c84d4064063d4d9bc313513c310203a8 from Semantic Scholar
# Added semanticscholar_e26411bc7cdbc85053f0248e274175088a673423 from Semantic Scholar
# Added semanticscholar_8d8e1a01060583972b602ff1e08b5033aaf3e41f from Semantic Scholar
# Added semanticscholar_5bf54dac9494061c44515b3be4d609a9473d66aa from Semantic Scholar
# Added semanticscholar_1c8b719acebcaa8545f8281362b25194d36b2b88 from Semantic Scholar
# ...
# Added semanticscholar_c21df3df7eeb3430d9266b305640c68150b98103 from Semantic Scholar
# Added semanticscholar_cebf94e8d4051ee7f96b99355efedc8f7db4fa91 from Semantic Scholar
# Added semanticscholar_3fb3ea8fbc211752cedc0106f4b6940327b3c7e0 from Semantic Scholar
# Added semanticscholar_065df112ee19b87f2bbe82c11c1dcc611bb6cb3d from Semantic Scholar
# Added semanticscholar_83882dff7dad44532095a75ca0494c321db0ea0a from Semantic Scholar
# Added semanticscholar_f55aff902b25070a2f64508bc0a6edc624a61424 from Semantic Scholar
# Added semanticscholar_2ff6935bdcf6bf6152c9a92c8886f695da244f0d from Semantic Scholar
# Added semanticscholar_9215b9bbe4c4a977081827801219bce409473332 from Semantic Scholar
# Added semanticscholar_d1a4b88bd1e9721a7309ff2172c08639192b8c1e from Semantic Scholar
# Added semanticscholar_64b766ffd1cb258e5ae7a70fc0bfb446fd2c49f9 from Semantic Scholar
# Added semanticscholar_ffaab01026c3ad016aa4ab0c1e1070243d935a97 from Semantic Scholar
# Added semanticscholar_6c882eafef444e916b08592941a7177fea45eb88 from Semantic Scholar
# Added semanticscholar_5f3a5ae0d3e5aac06d42e54f248a56cd54c6aa16 from Semantic Scholar
# Added semanticscholar_6f761bebc219c435c448ca089fadb1aec0836595 from Semantic Scholar
# Added semanticscholar_8293f139357bae1d0cb52e01924293ef31d41b98 from Semantic Scholar
# Added semanticscholar_308346e58f53495ac7418559f3309de3a25e3fdc from Semantic Scholar
# Added semanticscholar_ecfd6a5d7bbdaad6b4eafc6bd3216d82b1f68758 from Semantic Scholar
# Added semanticscholar_c876c397d8fd44c692e54b270073dfd09544a32c from Semantic Scholar
# Added semanticscholar_e011b459461b555c70a8b2fa3b2d7ef434622297 from Semantic Scholar
# Added semanticscholar_f3b58b7bb33a1494f3d6a31af324a93a0eff5932 from Semantic Scholar
# Added semanticscholar_9e94980c85dc50988d186261e37b6312b28b3749 from Semantic Scholar
# Added semanticscholar_073973092407ac1ecc53e410eb05678051dea5c5 from Semantic Scholar
# Added semanticscholar_a14d7a8a86ca67ad7da85e575ad84bc701437416 from Semantic Scholar
# Added semanticscholar_f1bc43932beb14a00cd47feac4e40951601dd7a9 from Semantic Scholar
# Added semanticscholar_53a1bf5894828350f5a7114dbbf36a639768d9a9 from Semantic Scholar
# Added semanticscholar_42c1c0f0604e1f0f2e74a75696468782a58f5a06 from Semantic Scholar
# Added semanticscholar_e6cfd781cbd0872bd2343f15f1184c21e617f4be from Semantic Scholar
# Added semanticscholar_d9da8efcb488a758e7808e32c6ded28c2c2cbb68 from Semantic Scholar
# Added semanticscholar_5c56849181d2871dedb95f3bda443dc11d29a399 from Semantic Scholar
# Added semanticscholar_35a7ecbb505fa66e2c21bf04b6419d9ee78455a5 from Semantic Scholar
# Added semanticscholar_308c097fd5de76c4a73e92fee7c77b0c2259f24a from Semantic Scholar
# Added semanticscholar_d4bf35f70fa1e4993b01b637fb8c73321db94b3d from Semantic Scholar
# Added semanticscholar_01cceabb4dbcfcd414a0c1ef8481ca32224cafc1 from Semantic Scholar
# Added semanticscholar_1f57e2d9f77f1793f6323e1744465801cd10dc4c from Semantic Scholar
# Added semanticscholar_4c296099aa3f453166fc1339eabcd9f85492ab0e from Semantic Scholar
# Added semanticscholar_de3d572af3800f07370453e2703e5e93cc96384a from Semantic Scholar
# Added semanticscholar_fa5fc8499385c746a23a2bd63d068b21f5e66d05 from Semantic Scholar
# Added semanticscholar_afda2b673cf7378601ae8afb6102e399955723fa from Semantic Scholar
# Added semanticscholar_3cc314818d5fe01637d0914240389a0a123c18eb from Semantic Scholar
# Added semanticscholar_1152ae5e219fd82d2ccd95e1e287297e6e89b7fd from Semantic Scholar
# Added semanticscholar_97b446e2ec3b402ea104421dab5eb4b99a21e42a from Semantic Scholar
# Added semanticscholar_fe8f5c1997cf1dc7dc84f33fdd1ec247972394f1 from Semantic Scholar
# Added semanticscholar_61b00303afba67550e4331f26de4cacc82128d58 from Semantic Scholar
# Added semanticscholar_33e7194eba58fa9802480fd2e0d8cec48fc3dc57 from Semantic Scholar
# Added semanticscholar_4d5557848486c5565b46ea1a9f2668bf57a898b8 from Semantic Scholar
# Added semanticscholar_bea4b6f16b2aed4a46ac34f7474cab39327e69ee from Semantic Scholar
# Added semanticscholar_5f8b6b1663f2bd539819dbcd6d6ec88c33b3c06e from Semantic Scholar
# Added semanticscholar_954143c0451a410e42c80b55fe991d268ba8f56e from Semantic Scholar
# Added semanticscholar_20dc9fa7aa3334799d29bfe2234e772786ecf035 from Semantic Scholar
# Added semanticscholar_5060c8808b0f5c1c92c2e99f72806c8f119264ff from Semantic Scholar
# Added semanticscholar_f9a08b7d382ee51b6f9b5af0805d7bde97b6bdc0 from Semantic Scholar
# Added semanticscholar_af4520c95d9ee09b2f9da4c352bff38d5c05f6d5 from Semantic Scholar
# Added semanticscholar_240cf2e8fd536b3901bf91a91fecc1f1dc4d9675 from Semantic Scholar
# Added semanticscholar_b823126fe6ffc9fb9760712f9eac0b3cacaa8036 from Semantic Scholar
# Added semanticscholar_bb33cd506713327d9c2b71d7f0bc13e9a90d23cb from Semantic Scholar
# Added semanticscholar_4a728e31a6f406a7430de4a1e2908de0bd8326df from Semantic Scholar
# Added semanticscholar_33ea913b5754dd82b992b47fb610a0d48d804b2d from Semantic Scholar
# Added semanticscholar_c2ac0dad5897bf8be7bf055a0dd7196af6a3d890 from Semantic Scholar
# Added semanticscholar_2fa39467bfcf43959dd60b38a8bd855da5112677 from Semantic Scholar
# Added semanticscholar_24c9307a63a5ee3d8ed2fdcf027df9212c3393d6 from Semantic Scholar
# Added semanticscholar_e535ca38189483eb0271a8820bd1c802bd2a881b from Semantic Scholar
# Added semanticscholar_bd3caf8c2760570957f27fdf3be90cc7fe8586ff from Semantic Scholar
# Added semanticscholar_6b196cccbc54f484b08e71527cde7f7be239459e from Semantic Scholar
# Added semanticscholar_5bbfd48a333040aa2001d4159c3f13de7cfc8a76 from Semantic Scholar
# Added semanticscholar_47c4a7f5d65686c363a6311ef23d69ea113a2a41 from Semantic Scholar
# Added semanticscholar_2d40b038b14fdd0e7fba711d756107308269823c from Semantic Scholar
# Added semanticscholar_78fe680fab6d7b67df200a8eb6bffd8d137f2bfa from Semantic Scholar
# Added semanticscholar_4b67952f9145f70528e4c79dea6ffed124273020 from Semantic Scholar
# Added semanticscholar_ab1ecb99c7c6b0a35bc8b7afedbde7ca8602a790 from Semantic Scholar
# Added semanticscholar_2cdcd3d0e920c1620c909c15e95182d9ee8a0896 from Semantic Scholar
# Added semanticscholar_293a13881cd65f293d4c4b00e340395d7bdb3341 from Semantic Scholar
# Added semanticscholar_f49e9a0c608f0f1dac7192770f4e3386b7a19389 from Semantic Scholar
# Added semanticscholar_b77b7255887fc7836a164978ba96c6a7f7ed5ac8 from Semantic Scholar
# Added semanticscholar_c718e90bf032b6003f69e9f554486623dc09b3ce from Semantic Scholar
# Added semanticscholar_c3c79bf7432f97e9aee9571d57acae8171cf563a from Semantic Scholar
# Added semanticscholar_f9e2614ee1e9addf579bc6eb54fa0759760f9beb from Semantic Scholar
# Added semanticscholar_b54b33f4830d1af89d1d913f4ead10de3209d047 from Semantic Scholar
# Added semanticscholar_6cffaea0680e9162873af60869b442339395ae2f from Semantic Scholar
# Added semanticscholar_ad920ee60a7f5965e78babfd971c51b984f7da3f from Semantic Scholar
# Added semanticscholar_5f8e2536eb991df4115250bee0b9bb3ab03d6918 from Semantic Scholar
# Added semanticscholar_1feeeb43c902843f29960c8b9700ed7a2d267202 from Semantic Scholar
# Added semanticscholar_013f7747861e763ad32f2c2b2d6eacee4021b2e5 from Semantic Scholar
# Added semanticscholar_0e16ca49ec1acf5d69b4ce01c96161ecb14a6f2f from Semantic Scholar
# Added semanticscholar_61c499a588be0779bf5e619d7a8da3e683a35434 from Semantic Scholar
# Added semanticscholar_03e43752e278c693d6c8a5f0def874dd59dd8745 from Semantic Scholar
# Added semanticscholar_f559c8f003f2f336e6cca50fffaf724c4bfc7ea7 from Semantic Scholar
# Added semanticscholar_bd2062eb413816144bcfc1c8511f73712c67ac74 from Semantic Scholar
# Added semanticscholar_6fe28ec0ae8db577c7adccec7972a7bb09c33b9d from Semantic Scholar
# Added semanticscholar_e7493f6bff56d597cb0e3726b7089da858ec828d from Semantic Scholar
# Added semanticscholar_2821bf6b56d724eeefc5e7176cb2897345c33b32 from Semantic Scholar
# Added semanticscholar_5ffbd95a737e52fc42f3c6b4035c9dc188e56141 from Semantic Scholar
# Added semanticscholar_d14901cdc86a86fa5693be91c964226516819066 from Semantic Scholar
# Added semanticscholar_0ad61da6040593c5fded671d6744c373c25d02a9 from Semantic Scholar
# Added semanticscholar_f7d71f87ffcfa3a22141d9305f33523d3543e3cc from Semantic Scholar
# Added semanticscholar_a0293e942f8d59cf5cf5220cb324c4d5bf2b3907 from Semantic Scholar
# Added semanticscholar_2b75e4c582c267e21845ae04dbc95162fe00c84d from Semantic Scholar
# Added semanticscholar_6a2b01878243998f4c2ec67cd4916444e496efcd from Semantic Scholar
# Added semanticscholar_46e53f8c44b754321e44ffe7630c06b941b805a3 from Semantic Scholar
# Added semanticscholar_e9397f5026dcc20171b5b75b7b1ae684b37fc081 from Semantic Scholar
# Added semanticscholar_c602a39ed14aa71cc6d773aa0a912383f0b67117 from Semantic Scholar
# Added semanticscholar_2eb458ade4eaadfe8eaabc0fd449272a84a10580 from Semantic Scholar
# Added semanticscholar_bd235ec9985e6499a9ea25fc6d8869023e2d1066 from Semantic Scholar
# Added semanticscholar_d4ff79d66f85c061e8af489063ba90d48fbc076a from Semantic Scholar
# Added semanticscholar_c2f3b523f5051cbe8474e59e5fb7262d0bc6a6d4 from Semantic Scholar
# Added semanticscholar_9c2e55e6233e79579decec1f5bf1aee48256f209 from Semantic Scholar
# Added semanticscholar_f504fbcdc784158f298442d6301fed97dd583031 from Semantic Scholar
# Added semanticscholar_b11fb55575450c6da9ca56ed09e7d408a8ffa856 from Semantic Scholar
# Added semanticscholar_b11fb55575450c6da9ca56ed09e7d408a8ffa856 from Semantic Scholar
# Added semanticscholar_876f628bda9f454195cc14fbd3ebbe4f39b3942c from Semantic Scholar
# Added semanticscholar_4775eda9187a257f08c5000ee2ca84c27c1375fd from Semantic Scholar
# Added semanticscholar_adde3149a88d90f808f9583dda70c3216c84ac3b from Semantic Scholar
# Added semanticscholar_668671389d1ebda8b025f8c1aacf6468349d2a92 from Semantic Scholar
# Added semanticscholar_011ea0d5972ba2f40ace660b6ec3ad893f3714e6 from Semantic Scholar
# Added semanticscholar_3bcfff4f38e047375ad71f0a57c09e204c5acb52 from Semantic Scholar
# Added semanticscholar_78def21f1000d089ba079a0a080fb759899bf1ca from Semantic Scholar
# Added semanticscholar_486e8818b68290c17208bece208814cf74aa259d from Semantic Scholar
# Added semanticscholar_cd371214c6ce89d1f119cdd4d5f5a613a724a68d from Semantic Scholar
# Added semanticscholar_0124e24298ffa6df83f72fb42163e0ccb6746ea2 from Semantic Scholar
# Added semanticscholar_c3949bf6d14e5cd575dd3513bc215f0ff799081d from Semantic Scholar
# Added semanticscholar_6f1d72004de8dbb3d5ca79dde04cef5e42ba9caf from Semantic Scholar
# Added semanticscholar_d5994e0a38e487c0370a7756d97c31bc99d8062d from Semantic Scholar
# Added semanticscholar_36670fcc024408f3955c5aa008feb52749852a81 from Semantic Scholar
# Added semanticscholar_f663272d81b3d4e096cc1c0cf8fdffc8389b30f3 from Semantic Scholar
# Added semanticscholar_e96b15efff8bb731c7212e4832059cc56b01a9df from Semantic Scholar
# Added semanticscholar_0a7a04efd1974c3aa3ea4e7da9f532120ee8ff30 from Semantic Scholar
# Added semanticscholar_7b380f804383a38d22ede61928a5d17544934fad from Semantic Scholar
# Added semanticscholar_18e61aa25fcfffc9ef7d966d6501e1ed2450919b from Semantic Scholar
# Added semanticscholar_18e61aa25fcfffc9ef7d966d6501e1ed2450919b from Semantic Scholar
# Added semanticscholar_2a91da09578eadaab15777dcb2f666eb6c0964e7 from Semantic Scholar
# Added semanticscholar_996f4c9a868ba24ecf7eac3fd6e6a6dcd1c17fae from Semantic Scholar
# Added semanticscholar_04711a3420653753ad8c58f22cb3fdd65ebc8f07 from Semantic Scholar
# Added semanticscholar_8b24dc9cffeca8cc276d3102f8ae17467c7343b0 from Semantic Scholar
# Added semanticscholar_3d0e2fe41c418a5f732bb71b7d890c2cc86d0b8a from Semantic Scholar
# Added semanticscholar_5a61a63082d789f2055b480067cfebb8791a8aa3 from Semantic Scholar
# Added semanticscholar_fea8a9245fb9226ae3677a7346a0f8920b32ced9 from Semantic Scholar
# Added semanticscholar_470bf0917061f3a0e8d0e0e43651e1636a4824ff from Semantic Scholar
# Added semanticscholar_78a0ba7ed264be130bace995ddc5c45c1df9a797 from Semantic Scholar
# Added semanticscholar_189e4fdc794255d4f225af9439491489a3104585 from Semantic Scholar
# Added semanticscholar_8da647ea43c75e018f4ff0c684787a8eeeac8e79 from Semantic Scholar
# Added semanticscholar_f1ed3285cb4b1e0537193e8d94cb535878b1e7ec from Semantic Scholar
# Added semanticscholar_059df6faeecafff28bc57496b1a6cecbb758e5fb from Semantic Scholar
# Added semanticscholar_4fa84bbe5520892397027bcdcd385648d93c94a7 from Semantic Scholar
# Added semanticscholar_4ebe725e19f4bff7de199b5017e2b9e31d29442e from Semantic Scholar
# Added semanticscholar_cd91d5c48763aee41f32e43ee29809cac55e6b16 from Semantic Scholar
# Added semanticscholar_a86ecb673473f1d117e34afc5517399f31dc252b from Semantic Scholar
# Added semanticscholar_1b429d66f91a485dde5bb254b2fba3e9689e8cb7 from Semantic Scholar
# Added semanticscholar_6f50537e70885fa4b94c5725c559d76d7bd01b53 from Semantic Scholar
# Added semanticscholar_24cac144020ce74b36f340db66b74189a30b5197 from Semantic Scholar
# Added semanticscholar_ee0e65c3e8185426d8ef14fec05113b156860406 from Semantic Scholar
# Added semanticscholar_7f46c756798ddb41b3d953237f8f4540b7462231 from Semantic Scholar
# Added semanticscholar_39ac1eb83b6b122ce7041737c3c98b4a0f0ab3f2 from Semantic Scholar
# Added semanticscholar_62bb80bae84fbbb4361161c8eb9e09cfd86ff92c from Semantic Scholar
# Added semanticscholar_ae6379876801587396489e997b9847c5d361a4e9 from Semantic Scholar
# Added semanticscholar_04f653cce37d724283ea0c9f0dadac918375faf5 from Semantic Scholar
# Added semanticscholar_58e9fc59a0e44b82467ca71d67fe13d458320a70 from Semantic Scholar
# Added semanticscholar_7a6d8b6d299cf3df3ea5580fb798150288e12fb2 from Semantic Scholar
# Added semanticscholar_e17517aa939d0b8c3165f7ca9b90b453af6c536b from Semantic Scholar
# Added semanticscholar_ec432a810018418492823ad1c2b18bc6e8a0ccaf from Semantic Scholar
# Added semanticscholar_bf405db53dde57e3614b59c76333525139920eef from Semantic Scholar
# Added semanticscholar_a9b9f4c6aaab6203272c4d444af9cc6abc1a0357 from Semantic Scholar
# Added semanticscholar_d32d4706cab85d3aa71334e3d5a9f67c7218476a from Semantic Scholar
# Added semanticscholar_3fffdd24946f9037d760b0bf1572aa79302cc8b5 from Semantic Scholar
# Added semanticscholar_ff19c7e65bd10d6ca10056224937c182f1b83f41 from Semantic Scholar
# Added semanticscholar_29d481a308a9b46024ee894b81efed16842313fd from Semantic Scholar
# Added semanticscholar_e43dbff309b9f5b4f6f8e612ad116995c45b50ee from Semantic Scholar
# Added semanticscholar_98df2f3a0f8503f2a0a5bf293943b730df7784ad from Semantic Scholar
# Added semanticscholar_db6f5739b58d583822bd27673374c77589f84639 from Semantic Scholar
# Added semanticscholar_3a44cd1a95ac870f1d1240bcea411614a994ecb2 from Semantic Scholar
# Added semanticscholar_b39d22c9ae2ff8b3c0e10dd76d2202fbb44af1a5 from Semantic Scholar
# Added semanticscholar_000be55058af78361fed5c892d7097094c095627 from Semantic Scholar
# Added semanticscholar_b4962de49135289486ee6318728e0339f03bbfc5 from Semantic Scholar
# Added semanticscholar_ae6e49ca249ff7d71d403a35bb4ec2130399e8e6 from Semantic Scholar
# Added semanticscholar_d1f6cf910fdd101daecdfa7afbd4776183a0e90b from Semantic Scholar
# Added semanticscholar_ef8bb89319e87f07452c69a8bb506bc1decc4601 from Semantic Scholar
# Added semanticscholar_00483e16fe63c8810d9d537a61a199f820ceb150 from Semantic Scholar
# Added semanticscholar_1c6e4668d3de70456cc74a8a970a535d906863da from Semantic Scholar
# Added semanticscholar_840d4292fff33b264eecf625fe9a20df6a57210f from Semantic Scholar
# Added semanticscholar_d9110ef8346a5b6305c1615dccfb2bf9708540ee from Semantic Scholar
# Added semanticscholar_a95b4aba69d826259b5a5f610b26873c42e5d379 from Semantic Scholar
# Added semanticscholar_14eab58732629323cc3a11db20d213b046c17f2a from Semantic Scholar
# Added semanticscholar_306bf18723c7d622cc8a19e48ba3e02f346688e6 from Semantic Scholar
# Added semanticscholar_65c5fc422e84578d473f9fa99a89d121152581cc from Semantic Scholar
# Added semanticscholar_53e0a1eebbebaa2070fdb9c8fa10f7faa6eb06b1 from Semantic Scholar
# Added semanticscholar_32f7cfa6ace910dce170775d40e8783bb6fcc890 from Semantic Scholar
# Added semanticscholar_1af75cbcbd51481fdd1b8d5b54731cf11e4d6e45 from Semantic Scholar
# Added semanticscholar_678981be4af3e05fb8e3b85772eef0f2eeb68913 from Semantic Scholar
# Added semanticscholar_378c272be3c828119ab29c96c26f84ced0eb19c2 from Semantic Scholar
# Collected and stored 1040 papers in total.

# %%
# week 1
import os
import re
import sqlite3
import pandas as pd
import PyPDF2
import spacy
import gdown
import zipfile
from spacy.lang.en.stop_words import STOP_WORDS

# Load SpaCy model
nlp = spacy.load("en_core_web_sm")
# Google Drive file URL and local paths
GOOGLE_DRIVE_URL = "https://drive.google.com/uc?id=1QfIv0MnqHNOzKZqXSWgRU_SjlnGyx2vj"
ZIP_FILE = "med_articles2.zip"
WORKING_DIR = "med_articles_temp"
os.makedirs(WORKING_DIR, exist_ok=True)

# Step 1: Download and Extract ZIP
def download_and_extract_zip():
    if not os.path.exists(ZIP_FILE):
        print(f"Downloading {ZIP_FILE} from Google Drive...")
        gdown.download(GOOGLE_DRIVE_URL, ZIP_FILE, quiet=False)
    else:
        print(f"{ZIP_FILE} already exists, skipping download.")

    try:
        with zipfile.ZipFile(ZIP_FILE, 'r') as zip_ref:
            print(f"Extracting {ZIP_FILE} to {WORKING_DIR}...")
            zip_ref.extractall(WORKING_DIR)
        print(f"Successfully extracted to {WORKING_DIR}")
    except zipfile.BadZipFile:
        print(f"Error: {ZIP_FILE} is not a valid ZIP file or is corrupted.")
        raise

# Step 2: Text Extraction and Metadata Parsing
def extract_text_from_pdf(pdf_path):
    print(f"Attempting to extract text from {pdf_path}")
    try:
        with open(pdf_path, 'rb') as file:
            pdf_reader = PyPDF2.PdfReader(file)
            text = ""
            for page in pdf_reader.pages:
                text += page.extract_text() or ""
            print(f"Extracted {len(text)} characters from {pdf_path}")
        return text
    except Exception as e:
        print(f"Error reading {pdf_path}: {e}")
        return ""

def parse_metadata(raw_text, filename):
    doc = nlp(raw_text[:2000])
    title = "Unknown"
    author = "Unknown"
    pub_date = "Unknown"
    abstract = "Unknown"

    lines = raw_text.split('\n')
    for line in lines[:10]:
        if re.search(r"^(Title:|Abstract|Authors?:)", line, re.IGNORECASE):
            if "Title:" in line:
                title = re.sub(r"Title:\s*", "", line, flags=re.IGNORECASE).strip()
            elif "Author" in line:
                author = re.sub(r"Authors?:\s*", "", line, flags=re.IGNORECASE).strip()
        elif len(line.strip()) > 10 and title == "Unknown":
            title = line.strip()
            break

    for sent in doc.sents:
        if "by" in sent.text.lower() or re.search(r"[A-Z][a-z]+,\s*[A-Z]", sent.text):
            author = sent.text.strip()
            break

    date_match = re.search(r"\b(19|20)\d{2}\b", raw_text)
    if date_match:
        pub_date = date_match.group(0)

    abstract_match = re.search(r"Abstract\s*[:\-\s]*(.+?)(?:\n\n|\r\n\r\n|Introduction|Methods|$)", raw_text, re.DOTALL | re.IGNORECASE)
    if abstract_match:
        abstract = abstract_match.group(1).strip()

    if title == "Unknown":
        title = os.path.splitext(filename)[0]

    return {"title": title, "author": author, "pub_date": pub_date, "abstract": abstract}

# Step 3: Preprocessing
def preprocess_text(text):
    doc = nlp(text[:100000])
    tokens = [token.text.lower() for token in doc if not token.is_stop and token.is_alpha]
    return " ".join(tokens)

# Step 4: Process Files and Store in DB
def process_files_and_store_in_db(directory):
    conn = sqlite3.connect("healthcare_research.db")
    cursor = conn.cursor()

    # Add author and other columns if they don't exist
    cursor.execute("PRAGMA table_info(research_papers)")
    columns = [col[1] for col in cursor.fetchall()]
    if "author" not in columns:
        cursor.execute("ALTER TABLE research_papers ADD COLUMN author TEXT")
    if "pub_date" not in columns:
        cursor.execute("ALTER TABLE research_papers ADD COLUMN pub_date TEXT")
    if "abstract" not in columns:
        cursor.execute("ALTER TABLE research_papers ADD COLUMN abstract TEXT")
    if "cleaned_text" not in columns:
        cursor.execute("ALTER TABLE research_papers ADD COLUMN cleaned_text TEXT")
    conn.commit()



    cursor.execute('''
        CREATE TABLE IF NOT EXISTS research_papers (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            filename TEXT,
            title TEXT,
            author TEXT,
            pub_date TEXT,
            abstract TEXT,
            cleaned_text TEXT
        )
    ''')

    data = {
        "filename": [], "title": [], "author": [], "pub_date": [], "abstract": [], "cleaned_text": []
    }

    print(f"Searching recursively for PDFs in {directory}")
    pdf_count = 0
    for root, _, files in os.walk(directory):  # Recursive search
        for filename in files:
            if not filename.endswith(".pdf"):
                print(f"Skipping {filename} - not a PDF")
                continue

            pdf_count += 1
            file_path = os.path.join(root, filename)
            raw_text = extract_text_from_pdf(file_path)

            if not raw_text:
                print(f"Skipping {filename} - no text extracted")
                continue

            metadata = parse_metadata(raw_text, filename)
            cleaned_text = preprocess_text(raw_text)

            data["filename"].append(filename)
            data["title"].append(metadata["title"])
            data["author"].append(metadata["author"])
            data["pub_date"].append(metadata["pub_date"])
            data["abstract"].append(metadata["abstract"])
            data["cleaned_text"].append(cleaned_text)

            cursor.execute('''
                INSERT INTO research_papers (filename, title, author, pub_date, abstract, cleaned_text)
                VALUES (?, ?, ?, ?, ?, ?)
            ''', (filename, metadata["title"], metadata["author"], metadata["pub_date"], metadata["abstract"], cleaned_text))
            print(f"Inserted {filename} into database")

    print(f"Found and processed {pdf_count} PDF files")
    conn.commit()

    cursor.execute("SELECT COUNT(*) FROM research_papers")
    total_rows = cursor.fetchone()[0]
    print(f"Total records in database: {total_rows}")

    cursor.execute("SELECT * FROM research_papers LIMIT 5")
    rows = cursor.fetchall()
    print("Sample data from database:")
    for row in rows:
        print(row)

    conn.close()

    df = pd.DataFrame(data)
    df.to_csv("preprocessed_data.csv", index=False)
    print("Data also saved to preprocessed_data.csv")

# Run the script
if __name__ == "__main__":
    download_and_extract_zip()
    process_files_and_store_in_db(WORKING_DIR)
# Out:
# med_articles2.zip already exists, skipping download.
# Extracting med_articles2.zip to med_articles_temp...
# Successfully extracted to med_articles_temp
# Searching recursively for PDFs in med_articles_temp
# Attempting to extract text from med_articles_temp/articles medical/07-1411.pdf
# Extracted 4932 characters from med_articles_temp/articles medical/07-1411.pdf
# Inserted 07-1411.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/Longest-2287_Chap1-e8ed4666.pdf
# Extracted 126206 characters from med_articles_temp/articles medical/Longest-2287_Chap1-e8ed4666.pdf
# Inserted Longest-2287_Chap1-e8ed4666.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/POST-PN-0545.pdf
# Extracted 28237 characters from med_articles_temp/articles medical/POST-PN-0545.pdf
# Inserted POST-PN-0545.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/Medical Waste Treatment and Disposal Methods Used by Hospitals in Oregon  Washington  and Idaho.pdf
# Extracted 59100 characters from med_articles_temp/articles medical/Medical Waste Treatment and Disposal Methods Used by Hospitals in Oregon  Washington  and Idaho.pdf
# Inserted Medical Waste Treatment and Disposal Methods Used by Hospitals in Oregon  Washington  and Idaho.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/SOP-for-Quality-Improvement.pdf
# Extracted 90778 characters from med_articles_temp/articles medical/SOP-for-Quality-Improvement.pdf
# Inserted SOP-for-Quality-Improvement.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/9789240094703-eng.pdf
# Extracted 262259 characters from med_articles_temp/articles medical/9789240094703-eng.pdf
# Inserted 9789240094703-eng.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/booth-et-al-2000-waging-war-on-modern-chronic-diseases-primary-prevention-through-exercise-biology.pdf
# Extracted 83853 characters from med_articles_temp/articles medical/booth-et-al-2000-waging-war-on-modern-chronic-diseases-primary-prevention-through-exercise-biology.pdf
# Inserted booth-et-al-2000-waging-war-on-modern-chronic-diseases-primary-prevention-through-exercise-biology.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/djph-958g8g8u-003.pdf
# Extracted 143830 characters from med_articles_temp/articles medical/djph-958g8g8u-003.pdf
# Inserted djph-958g8g8u-003.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/Hospital2029%202019_v2.0.pdf
# Extracted 1630533 characters from med_articles_temp/articles medical/Hospital2029%202019_v2.0.pdf
# Inserted Hospital2029%202019_v2.0.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/the-global-strategy-of-the-us-department-of-health-and-human-services.pdf
# Extracted 83584 characters from med_articles_temp/articles medical/the-global-strategy-of-the-us-department-of-health-and-human-services.pdf
# Inserted the-global-strategy-of-the-us-department-of-health-and-human-services.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/38089-doc-faq_corona_virus.pdf
# Extracted 9150 characters from med_articles_temp/articles medical/38089-doc-faq_corona_virus.pdf
# Inserted 38089-doc-faq_corona_virus.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/hus17.pdf
# Extracted 309400 characters from med_articles_temp/articles medical/hus17.pdf
# Inserted hus17.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/GBD_2017_Booklet.pdf
# Extracted 40206 characters from med_articles_temp/articles medical/GBD_2017_Booklet.pdf
# Inserted GBD_2017_Booklet.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/p26.pdf
# Extracted 18370 characters from med_articles_temp/articles medical/p26.pdf
# Inserted p26.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/World-Heart-Report-2023.pdf
# Extracted 65118 characters from med_articles_temp/articles medical/World-Heart-Report-2023.pdf
# Inserted World-Heart-Report-2023.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/364010PAPER0Gl101OFFICIAL0USE0ONLY1.pdf
# Extracted 1852396 characters from med_articles_temp/articles medical/364010PAPER0Gl101OFFICIAL0USE0ONLY1.pdf
# Inserted 364010PAPER0Gl101OFFICIAL0USE0ONLY1.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/NRU_D1_Nauru STGs 2014 final.pdf
# Extracted 477269 characters from med_articles_temp/articles medical/NRU_D1_Nauru STGs 2014 final.pdf
# Inserted NRU_D1_Nauru STGs 2014 final.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/PatientFocusedInterventions_ReviewOfTheEvidence.pdf
# Extracted 789147 characters from med_articles_temp/articles medical/PatientFocusedInterventions_ReviewOfTheEvidence.pdf
# Inserted PatientFocusedInterventions_ReviewOfTheEvidence.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/AnatolJCardiol_1_3_166_178.pdf
# Extracted 57246 characters from med_articles_temp/articles medical/AnatolJCardiol_1_3_166_178.pdf
# Inserted AnatolJCardiol_1_3_166_178.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/guideline-170-en.pdf
# Extracted 697947 characters from med_articles_temp/articles medical/guideline-170-en.pdf
# Inserted guideline-170-en.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/health-policy-101-congress-and-the-executive-branch-and-health-policy.pdf
# Extracted 23084 characters from med_articles_temp/articles medical/health-policy-101-congress-and-the-executive-branch-and-health-policy.pdf
# Inserted health-policy-101-congress-and-the-executive-branch-and-health-policy.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/Health-Policies-for-the-21st-Century-Challenges-and-Recommendations-for-the-U.S.-Department-of-Health-and-Human-Services.pdf
# Extracted 113995 characters from med_articles_temp/articles medical/Health-Policies-for-the-21st-Century-Challenges-and-Recommendations-for-the-U.S.-Department-of-Health-and-Human-Services.pdf
# Inserted Health-Policies-for-the-21st-Century-Challenges-and-Recommendations-for-the-U.S.-Department-of-Health-and-Human-Services.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/ken_D1_clinical guidelines for management and referral of common conditions.pdf
# Extracted 1177671 characters from med_articles_temp/articles medical/ken_D1_clinical guidelines for management and referral of common conditions.pdf
# Inserted ken_D1_clinical guidelines for management and referral of common conditions.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/download.pdf
# Extracted 147926 characters from med_articles_temp/articles medical/download.pdf
# Inserted download.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/bf8b571d87b4ac4c34362a5a4ab8e147.pdf
# Extracted 40222 characters from med_articles_temp/articles medical/bf8b571d87b4ac4c34362a5a4ab8e147.pdf
# Inserted bf8b571d87b4ac4c34362a5a4ab8e147.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/introduction-to-public-health.pdf
# Extracted 17181 characters from med_articles_temp/articles medical/introduction-to-public-health.pdf
# Inserted introduction-to-public-health.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/trends-analysis-guidance-jan23.pdf
# Extracted 249914 characters from med_articles_temp/articles medical/trends-analysis-guidance-jan23.pdf
# Inserted trends-analysis-guidance-jan23.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/fcimb-2-1514207.pdf
# Extracted 14161 characters from med_articles_temp/articles medical/fcimb-2-1514207.pdf
# Inserted fcimb-2-1514207.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/SJMPS_74_179-184.pdf
# Extracted 30591 characters from med_articles_temp/articles medical/SJMPS_74_179-184.pdf
# Inserted SJMPS_74_179-184.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/3010201401.pdf
# Extracted 389186 characters from med_articles_temp/articles medical/3010201401.pdf
# Inserted 3010201401.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/update-28-covid-19-what-we-know.pdf
# Extracted 9617 characters from med_articles_temp/articles medical/update-28-covid-19-what-we-know.pdf
# Inserted update-28-covid-19-what-we-know.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/Treatment of Hospital.pdf
# Extracted 34178 characters from med_articles_temp/articles medical/Treatment of Hospital.pdf
# Inserted Treatment of Hospital.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/0965546608_eng.pdf
# Extracted 86859 characters from med_articles_temp/articles medical/0965546608_eng.pdf
# Inserted 0965546608_eng.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/health-policy-101-the-u-s-government-and-global-health.pdf
# Extracted 39979 characters from med_articles_temp/articles medical/health-policy-101-the-u-s-government-and-global-health.pdf
# Inserted health-policy-101-the-u-s-government-and-global-health.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/shm_painmanagement_guide.pdf
# Extracted 114409 characters from med_articles_temp/articles medical/shm_painmanagement_guide.pdf
# Inserted shm_painmanagement_guide.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/djph-95-003.pdf
# Extracted 26257 characters from med_articles_temp/articles medical/djph-95-003.pdf
# Inserted djph-95-003.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/download (1).pdf
# Extracted 44872 characters from med_articles_temp/articles medical/download (1).pdf
# Inserted download (1).pdf into database
# Attempting to extract text from med_articles_temp/articles medical/9789275122655_eng.pdf
# Extracted 330626 characters from med_articles_temp/articles medical/9789275122655_eng.pdf
# Inserted 9789275122655_eng.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/GBD_2021_Booklet_FINAL_2024.05.16.pdf
# Extracted 20129 characters from med_articles_temp/articles medical/GBD_2021_Booklet_FINAL_2024.05.16.pdf
# Inserted GBD_2021_Booklet_FINAL_2024.05.16.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/PIIS1201971203000109.pdf
# Extracted 30163 characters from med_articles_temp/articles medical/PIIS1201971203000109.pdf
# Inserted PIIS1201971203000109.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/1870_Oration_PDF.pdf
# Extracted 56211 characters from med_articles_temp/articles medical/1870_Oration_PDF.pdf
# Inserted 1870_Oration_PDF.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/274.full.pdf
# Extracted 30293 characters from med_articles_temp/articles medical/274.full.pdf
# Inserted 274.full.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/Shi_Chapter1_2-e629562b.pdf
# Extracted 71743 characters from med_articles_temp/articles medical/Shi_Chapter1_2-e629562b.pdf
# Inserted Shi_Chapter1_2-e629562b.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/IJHSR21.pdf
# Extracted 15817 characters from med_articles_temp/articles medical/IJHSR21.pdf
# Inserted IJHSR21.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/e034299.full.pdf
# Extracted 74831 characters from med_articles_temp/articles medical/e034299.full.pdf
# Inserted e034299.full.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/67tgt7i.pdf
# Extracted 355539 characters from med_articles_temp/articles medical/67tgt7i.pdf
# Inserted 67tgt7i.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/dp13625.pdf
# Extracted 180514 characters from med_articles_temp/articles medical/dp13625.pdf
# Inserted dp13625.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/s12992-022-00835-3.pdf
# Extracted 106530 characters from med_articles_temp/articles medical/s12992-022-00835-3.pdf
# Inserted s12992-022-00835-3.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/hus20-21.pdf
# Extracted 102486 characters from med_articles_temp/articles medical/hus20-21.pdf
# Inserted hus20-21.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/Changing levels and trends in mortality.pdf
# Extracted 188490 characters from med_articles_temp/articles medical/Changing levels and trends in mortality.pdf
# Inserted Changing levels and trends in mortality.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/who-rights-roles-respon-hw-covid-19.pdf
# Extracted 6584 characters from med_articles_temp/articles medical/who-rights-roles-respon-hw-covid-19.pdf
# Inserted who-rights-roles-respon-hw-covid-19.pdf into database
# Attempting to extract text from med_articles_temp/articles medical/STG-Primary-Hospital..pdf
# Extracted 940044 characters from med_articles_temp/articles medical/STG-Primary-Hospital..pdf
# Inserted STG-Primary-Hospital..pdf into database
# Attempting to extract text from med_articles_temp/articles medical/Overview.pdf
# Extracted 84684 characters from med_articles_temp/articles medical/Overview.pdf
# Inserted Overview.pdf into database
# Found and processed 53 PDF files
# Total records in database: 1074
# Sample data from database:
# ('pubmed_40327459', 'to evaluate prospective changes in psychological function among menopausal women using continuous nitroglycerin for hot flashes and examine repeated associations between psychological symptoms and hot flashes menopausal women with 7 hot flashesday were randomized to continuous transdermal nitroglycerin 0204 mgh or placebo for 12 weeks psychological function was evaluated using the center for epidemiologic studiesdepression scale cesd generalized anxiety disorders7 gad7 and menopausespecific quality of life menqol psychosocial subscale linear mixed models examined treatment effects on mood symptoms from baseline to 5 and 12 weeks based on validated 7day hot flash diaries additional models examined associations between mood symptoms and hot flash frequency in both groups combined among the 141 randomized participants mean 10835 hot flashesday nitroglycerin therapy did not improve cesd or gad7 scores prespecified secondary outcomes from baseline to 5 and 12 weeks compared with placebo greater hot flash frequency was associated with worse gad7 scores across all timepoints β005 per 1 hot flash p0005 but no associations between hot flashes and cesd or menqol psychosocial scores were observed improvement in hot flash frequency was associated with improvement in menqol psychosocial score β004 per 1 hot flash p003 but no associations between improvements in hot flashes and improvements in gad7 or cesd scores were detected in a randomized trial of continuous nitroglycerin improvements in hot flash frequency did not consistently translate into improvements in mood clinicians caring for women with overlapping hot flashes and mood symptoms should consider other factors influencing midlife psychological function', 'Psychological function in a randomized trial of continuous nitroglycerin for menopausal hot flashes.', 'PubMed', '2025-05-06', None, None, None)
# ('pubmed_40327390', 'the benefits of maintaining glycemic control for persons with diabetes include delaying the onset and slowing the progression of macro and microvascular complications however many children and adolescents with diabetes do not regularly meet target hemoglobin a1c levels our pilot project aimed to improve glycemic control among children and adolescents 8 to 17 years with insulindependent diabetes at greatest risk for complications and enrolled in north carolina medicaid at least 1 month during the study period we used a preintervention postintervention design we implemented an intensive care management intervention led by a nurse practitioner the nursing intervention consisted of telehealth visits emails and mychart messages with patients and caregivers to supplement inclinic visits therapeutic communication skills were applied including motivational interviewing techniques and unconditional positive regard we measured glycosylated hemoglobin hba1c at 6month intervals before during and after the intervention period mean participant n  12 hba1c levels dropped by 15 percentage points from baseline 128 to the 6month study end point 113 seventyfive percent of participants experienced some decrease in hba1c during the study period this pilot project demonstrated shortterm success of care management and therapeutic communication interventions in reducing hba1c levels among a sample of children and adolescents with complicated case histories our findings are consistent with other studies that found telephonic nursing support care management and motivational interviewing to be effective interventions among pediatric populations these studies suggest that nurses can implement relatively lowresource interventions that add value to health services delivery for children and adolescents with insulindependent diabetes however more studies are needed to understand which combinations of interventions may be most effective', 'Nursing Care Management and Glycemic Control Among Children With Diabetes Enrolled in Medicaid.', 'PubMed', '2025-05-06', None, None, None)
# ('pubmed_40327384', 'continuous positive airway pressure cpap therapy is the gold standard treatment for treating obstructive sleep apnea osa however patient adherence to cpap therapy remains a critical challenge with many individuals finding it difficult to maintain consistent use due to discomfort lack of understanding or perceived inconvenience augmented reality ar offers a novel approach to overcoming these barriers by providing interactive realtime guidance to users potentially enhancing adherence rates this clinical trial aims to examine the feasibility of ar implementation and the effect of ar on improving cpap adherence in patients with osa a randomized controlled trial with a parallel assignment will be conducted participants will be randomly assigned to either an experimental group receiving arguided cpap therapy or a control group receiving standard care the study will span 6 months with assessments at baseline t0 and with followups at 1 month t1 3 months t2 and 6 months t3 post intervention the primary outcome measure is cpap adherence defined as using the cpap device for more than 70 of sleep time with a minimum of 4 hours per night secondary outcomes will evaluate the common adverse effects associated with cpap therapy device usability and time required for cpap machine use education this study is funded by the ministry of science and technology taiwan august 2023 to july 2026 and was registered in august 2024 clinicaltrialsgov nct06520592 participant recruitment is scheduled to begin in april 2025 and by september 2025 we expect to have enrolled 40 participants 50 of the target sample of 80 preliminary analyses of cpap adherence at 1 month and usability data are currently underway final data collection is anticipated to be completed by december 2025 with results expected to be published by fall 2026 anticipated findings suggest that arguided cpap therapy may significantly enhance patient adherence by improving mask fitting and providing effective interactive education if validated this innovative approach could pave the way for more personalized technologydriven interventions in osa management and other chronic conditions requiring longterm therapy adherence clinicaltrialsgov nct06520592 httpsclinicaltrialsgovstudynct06520592 prr110219669757', 'Enhancing Adherence to Continuous Positive Airway Pressure Therapy in Patients With Obstructive Sleep Apnea Using Augmented Reality: Protocol for a Randomized Controlled Trial.', 'PubMed', '2025-05-06', None, None, None)
# ('pubmed_40327329', 'artificial intelligence ai has become a key component of the us army medical modernization strategy which seeks to enhance military health care through innovative technologies within the military health system mhs ai applications in diagnostics patient monitoring logistical support and trauma management are under active exploration key initiatives include aidriven telementoring decision support tools automated trauma documentation and remote patient monitoring these technologies aim to improve care delivery and operational efficiency in combat zones particularly during mass casualty incidents and in resourcelimited environments implementation faces significant obstacles including the need for robust data collection methods secure and interoperable storage solutions and frameworks to address ethical and trust issues decentralized storage technologies such as blockchain and explainable ai systems are proposed to enhance reliability and transparency advancements by nearpeer adversaries such as china and russia in aidriven military health care underscore the urgency for the united states to accelerate its integration efforts the us army medical modernization strategy emphasizes interagency collaboration and targeted research as critical components for maintaining a strategic edge artificial intelligencedriven automation offers a transformative pathway for military trauma care enabling enhanced efficiency and resilience addressing implementation barriers and aligning efforts with the us army medical modernization strategy are essential to ensure operational superiority and improved survival outcomes on the battlefield', 'AI on the Front Lines: A Primer for the Military Health Professional.', 'PubMed', '2025-05-06', None, None, None)
# ('pubmed_40327286\n27918725\n33766750\n17537614\n20668052\n33754023\n19641587\n35210368\n17384583\n9446642\n32392088\n34753510\n35134463\n33045622\n24382354\n21440622\n23474486\n35273493\n30053525\n38574433\n37154056\n26232232\n33314649\n32468629\n11709088\n37425037\n23325925\n10628339\n36435202\n32112883\n24058702\n31883358\n38323433\n26112889\n17250813\n37871668\n33437153\n38150302\n38316068\n29061338\n27567406\n35914558\n37714227\n36510036\n32958254\n29304479', 'doxorubicin doxinduced cardiotoxicity dic is known to be associated with reduction of cardiac protein kinase c epsilon pkcε pkcε promotes cell survival and protects hearts against various stresses however it is unclear whether or not the reduction in cardiac pkcε expression plays a causal role in dic and in particular the potential underlying mechanism whereby pkcε may protect against dic c57bl6 mice 810weekold were either treated with dox administered intraperitoneally for a duration of 4 weeks to produce cardiotoxicity or untreated in which mice received the same volume of saline in vitro neonatal rat ventricle cardiomyocytes were exposed to dox for 24 h in the absence or presence of adenovirus overexpressing pkcε cardiomyocytes in a subgroup were treated with sirtuin1 sirt1 selective inhibitor ex527 four weeks after dox cardiac contractile function was decreased concomitant with increased serum ckmb and ldh levels as well as increases in baxtobcl2 ratio and cleaved caspase 3 proteins expression while pkcε and sirt1 protein expressions were significantly decreased in vitro dox reduced cardiomyocyte pkcε and sirt1 protein expression decreased cardiomyocyte viability and increased ldh release with concomitant increases in oxidative stress and apoptosis these changes were attenuated by overexpression of pkcε ip study showed that pkcε could directly or indirectly bind sirt1 in cardiomyocytes and the protect effects of pkcε were further canceled by sirt1 inhibition in conclusion activating sirt1 may represent a major mechanism whereby pkcε protects the heart against doxinduced cell apoptosis and oxidative stress', 'Protein Kinase C Epsilon Overexpression Protects the Heart Against Doxorubicin-Induced Cardiotoxicity Via Activating SIRT1.', 'PubMed', '2025-05-06', None, None, None)
# Data also saved to preprocessed_data.csv

# %% [markdown]
# checking The dabase

# %%
import sqlite3

# Connect to the database
conn = sqlite3.connect("healthcare_research.db")
cursor = conn.cursor()

# Get the total number of rows
cursor.execute("SELECT COUNT(*) FROM research_papers")
total_rows = cursor.fetchone()[0]
print(f"Total number of records: {total_rows}")

# View the first 5 rows
cursor.execute("SELECT * FROM research_papers LIMIT 20")
rows = cursor.fetchall()

print("\nFirst 20 records:")
for row in rows:
    print(row)

# View column names
cursor.execute("PRAGMA table_info(research_papers)")
columns = cursor.fetchall()
print("\nColumn names:")
for col in columns:
    print(col[1])  # col[1] is the column name

# Close the connection
conn.close()
# Out:
# Total number of records: 1074
#
# First 20 records:
# ('pubmed_40327459', 'to evaluate prospective changes in psychological function among menopausal women using continuous nitroglycerin for hot flashes and examine repeated associations between psychological symptoms and hot flashes menopausal women with 7 hot flashesday were randomized to continuous transdermal nitroglycerin 0204 mgh or placebo for 12 weeks psychological function was evaluated using the center for epidemiologic studiesdepression scale cesd generalized anxiety disorders7 gad7 and menopausespecific quality of life menqol psychosocial subscale linear mixed models examined treatment effects on mood symptoms from baseline to 5 and 12 weeks based on validated 7day hot flash diaries additional models examined associations between mood symptoms and hot flash frequency in both groups combined among the 141 randomized participants mean 10835 hot flashesday nitroglycerin therapy did not improve cesd or gad7 scores prespecified secondary outcomes from baseline to 5 and 12 weeks compared with placebo greater hot flash frequency was associated with worse gad7 scores across all timepoints β005 per 1 hot flash p0005 but no associations between hot flashes and cesd or menqol psychosocial scores were observed improvement in hot flash frequency was associated with improvement in menqol psychosocial score β004 per 1 hot flash p003 but no associations between improvements in hot flashes and improvements in gad7 or cesd scores were detected in a randomized trial of continuous nitroglycerin improvements in hot flash frequency did not consistently translate into improvements in mood clinicians caring for women with overlapping hot flashes and mood symptoms should consider other factors influencing midlife psychological function', 'Psychological function in a randomized trial of continuous nitroglycerin for menopausal hot flashes.', 'PubMed', '2025-05-06', None, None, None)
# ('pubmed_40327390', 'the benefits of maintaining glycemic control for persons with diabetes include delaying the onset and slowing the progression of macro and microvascular complications however many children and adolescents with diabetes do not regularly meet target hemoglobin a1c levels our pilot project aimed to improve glycemic control among children and adolescents 8 to 17 years with insulindependent diabetes at greatest risk for complications and enrolled in north carolina medicaid at least 1 month during the study period we used a preintervention postintervention design we implemented an intensive care management intervention led by a nurse practitioner the nursing intervention consisted of telehealth visits emails and mychart messages with patients and caregivers to supplement inclinic visits therapeutic communication skills were applied including motivational interviewing techniques and unconditional positive regard we measured glycosylated hemoglobin hba1c at 6month intervals before during and after the intervention period mean participant n  12 hba1c levels dropped by 15 percentage points from baseline 128 to the 6month study end point 113 seventyfive percent of participants experienced some decrease in hba1c during the study period this pilot project demonstrated shortterm success of care management and therapeutic communication interventions in reducing hba1c levels among a sample of children and adolescents with complicated case histories our findings are consistent with other studies that found telephonic nursing support care management and motivational interviewing to be effective interventions among pediatric populations these studies suggest that nurses can implement relatively lowresource interventions that add value to health services delivery for children and adolescents with insulindependent diabetes however more studies are needed to understand which combinations of interventions may be most effective', 'Nursing Care Management and Glycemic Control Among Children With Diabetes Enrolled in Medicaid.', 'PubMed', '2025-05-06', None, None, None)
# ('pubmed_40327384', 'continuous positive airway pressure cpap therapy is the gold standard treatment for treating obstructive sleep apnea osa however patient adherence to cpap therapy remains a critical challenge with many individuals finding it difficult to maintain consistent use due to discomfort lack of understanding or perceived inconvenience augmented reality ar offers a novel approach to overcoming these barriers by providing interactive realtime guidance to users potentially enhancing adherence rates this clinical trial aims to examine the feasibility of ar implementation and the effect of ar on improving cpap adherence in patients with osa a randomized controlled trial with a parallel assignment will be conducted participants will be randomly assigned to either an experimental group receiving arguided cpap therapy or a control group receiving standard care the study will span 6 months with assessments at baseline t0 and with followups at 1 month t1 3 months t2 and 6 months t3 post intervention the primary outcome measure is cpap adherence defined as using the cpap device for more than 70 of sleep time with a minimum of 4 hours per night secondary outcomes will evaluate the common adverse effects associated with cpap therapy device usability and time required for cpap machine use education this study is funded by the ministry of science and technology taiwan august 2023 to july 2026 and was registered in august 2024 clinicaltrialsgov nct06520592 participant recruitment is scheduled to begin in april 2025 and by september 2025 we expect to have enrolled 40 participants 50 of the target sample of 80 preliminary analyses of cpap adherence at 1 month and usability data are currently underway final data collection is anticipated to be completed by december 2025 with results expected to be published by fall 2026 anticipated findings suggest that arguided cpap therapy may significantly enhance patient adherence by improving mask fitting and providing effective interactive education if validated this innovative approach could pave the way for more personalized technologydriven interventions in osa management and other chronic conditions requiring longterm therapy adherence clinicaltrialsgov nct06520592 httpsclinicaltrialsgovstudynct06520592 prr110219669757', 'Enhancing Adherence to Continuous Positive Airway Pressure Therapy in Patients With Obstructive Sleep Apnea Using Augmented Reality: Protocol for a Randomized Controlled Trial.', 'PubMed', '2025-05-06', None, None, None)
# ('pubmed_40327329', 'artificial intelligence ai has become a key component of the us army medical modernization strategy which seeks to enhance military health care through innovative technologies within the military health system mhs ai applications in diagnostics patient monitoring logistical support and trauma management are under active exploration key initiatives include aidriven telementoring decision support tools automated trauma documentation and remote patient monitoring these technologies aim to improve care delivery and operational efficiency in combat zones particularly during mass casualty incidents and in resourcelimited environments implementation faces significant obstacles including the need for robust data collection methods secure and interoperable storage solutions and frameworks to address ethical and trust issues decentralized storage technologies such as blockchain and explainable ai systems are proposed to enhance reliability and transparency advancements by nearpeer adversaries such as china and russia in aidriven military health care underscore the urgency for the united states to accelerate its integration efforts the us army medical modernization strategy emphasizes interagency collaboration and targeted research as critical components for maintaining a strategic edge artificial intelligencedriven automation offers a transformative pathway for military trauma care enabling enhanced efficiency and resilience addressing implementation barriers and aligning efforts with the us army medical modernization strategy are essential to ensure operational superiority and improved survival outcomes on the battlefield', 'AI on the Front Lines: A Primer for the Military Health Professional.', 'PubMed', '2025-05-06', None, None, None)
# ('pubmed_40327286\n27918725\n33766750\n17537614\n20668052\n33754023\n19641587\n35210368\n17384583\n9446642\n32392088\n34753510\n35134463\n33045622\n24382354\n21440622\n23474486\n35273493\n30053525\n38574433\n37154056\n26232232\n33314649\n32468629\n11709088\n37425037\n23325925\n10628339\n36435202\n32112883\n24058702\n31883358\n38323433\n26112889\n17250813\n37871668\n33437153\n38150302\n38316068\n29061338\n27567406\n35914558\n37714227\n36510036\n32958254\n29304479', 'doxorubicin doxinduced cardiotoxicity dic is known to be associated with reduction of cardiac protein kinase c epsilon pkcε pkcε promotes cell survival and protects hearts against various stresses however it is unclear whether or not the reduction in cardiac pkcε expression plays a causal role in dic and in particular the potential underlying mechanism whereby pkcε may protect against dic c57bl6 mice 810weekold were either treated with dox administered intraperitoneally for a duration of 4 weeks to produce cardiotoxicity or untreated in which mice received the same volume of saline in vitro neonatal rat ventricle cardiomyocytes were exposed to dox for 24 h in the absence or presence of adenovirus overexpressing pkcε cardiomyocytes in a subgroup were treated with sirtuin1 sirt1 selective inhibitor ex527 four weeks after dox cardiac contractile function was decreased concomitant with increased serum ckmb and ldh levels as well as increases in baxtobcl2 ratio and cleaved caspase 3 proteins expression while pkcε and sirt1 protein expressions were significantly decreased in vitro dox reduced cardiomyocyte pkcε and sirt1 protein expression decreased cardiomyocyte viability and increased ldh release with concomitant increases in oxidative stress and apoptosis these changes were attenuated by overexpression of pkcε ip study showed that pkcε could directly or indirectly bind sirt1 in cardiomyocytes and the protect effects of pkcε were further canceled by sirt1 inhibition in conclusion activating sirt1 may represent a major mechanism whereby pkcε protects the heart against doxinduced cell apoptosis and oxidative stress', 'Protein Kinase C Epsilon Overexpression Protects the Heart Against Doxorubicin-Induced Cardiotoxicity Via Activating SIRT1.', 'PubMed', '2025-05-06', None, None, None)
# ('pubmed_40327095\n32984198\n31953750\n15955855\n10352583\n16615053\n23958828\n14531007\n29306987\n12677511\n21643638\n20093572\n19022993\n21567143\n26736224\n15114491\n23285596\n22764084\n27330520\n14974593\n18400271\n15476531\n23793577\n19255628\n32613678', 'twodimensional d assessment of renal volume underestimates the actual value and shows high interobserver variability limited data exist on innovative 3d ultrasound us technique for the evaluation of pediatric hydronephrosis to assess the interrater agreement of kidney volume segmentation by 3d us with a matrix array transducer in children with hydronephrosis and to compare the 3d metrics to conventional hydronephrosis grading we prospectively acquired 48 renal volumes in 45 patients with hydronephrosis by freehand 3d us 61 mhz volumetric sector array electronic rotation median age 4 years 1 month to 16 years semiautomated kidney segmentation was performed by two independent readers providing volumes for total kidney renal capsule dilated collective system renal parenchyma renal capsulecollective system and hydronephrosis index renal parenchymacapsule interrater agreement was evaluated with blandaltman plots intraclass correlation coefficient icc and dice similarity coefficients the maximum calibre of renal pelvis was measured and hydronephroses were morphologically classified grade 14 interrater agreement for renal capsule collective system hydronephrosis index and renal parenchyma was good to excellent with icc of 094 087 083 and 092 respectively p  0001 each median dice was 090 capsule 077 collective system and 088 parenchyma there was a positive correlation between conventional hydronephrosis grading and ultrasonic hydronephrosis index and between renal pelvis diameter and collective system volume p  0001 both semiautomatic 3d us volumetric analysis has a high degree of interrater agreement and enables reliable assessment of renal parenchymal volume in hydronephrosis volumes of the collective system and hydronephrosis index correlate with the extent of hydronephrosis trial registration number drks00022772 date of registration 07312020', 'Semiautomatic three-dimensional ultrasound renal volume segmentation in pediatric hydronephrosis: interrater agreement and correlation to conventional hydronephrosis grading.', 'PubMed', '2025-05-06', None, None, None)
# ('pubmed_40327021', 'this narrative review joins an ongoing scholarly conversation about project echo a virtual educational innovation with an aim to understand it as a technologyenabled interface that facilitates knowledgesharing critical attention is paid to how dynamics of power are accounted for in the deployment of project echo and sociomaterial attention is paid to how communication technology is described the review is relevant to those who wish to establish understand or further develop virtual multiprovider knowledgesharing interfaces data collection followed processes set out by a narrative review methodology a review methodology that provides a comprehensive and balanced critical analysis of the published literature analysis was informed by thematic analysis fortyfive articles and one book chapter published between 2015 and 2024 were selected for inclusion this review was contained to studies of project echo in canada our data set captures an implied awareness of dynamics of power and a desire to counter such dynamics this is visible in the desire to mitigate a hierarchical differentiation between participants by using teaching and learning theories a pedagogical design and processes of interaction that favour participation and by using technology that allows participants to join from across vast geography emerging scholarly attention to how knowledge is shared and developed in project echo will help develop an understanding of how technologyenabled educational innovations facilitate knowledge sharing in spaces that are imbued with complex power dynamics future explicit inclusion of a critical gaze and sociomaterial lens will deepen understandings of technologyenabled educational innovations', 'Knowledge, Power, and Technology: A Narrative Review of Knowledge-Sharing in Project ECHO (Extension for Community Health Care Outcomes).', 'PubMed', '2025-05-06', None, None, None)
# ('pubmed_40326881', '', 'Suicidal Behavior in Women as a Risk Factor Generated by the Invisibilization of Their Affective Sexual Diversity, Gender Identity and LGTBphobia.', 'PubMed', '2025-05-06', None, None, None)
# ('pubmed_40326805', 'different cancers remain major global health challenges due to their diverse biological behaviors and significant treatment hurdles the aging of populations and lifestyle factors increase cancer occurrence and place increasing pressure on healthcare systems despite continuous advancements many cancers remain fatal due to latestage diagnosis tumor heterogeneity and drug resistance thus necessitating urgent development of innovative treatment solutions therapeutic nucleic acids a new class of biological drugs offer a promising approach to overcoming these challenges the recent nucleic acids and nanobiosystems in cancer theranostics nanct conference brought together internationally recognized experts from 15 countries to discuss cuttingedge research spanning from oncolytic viruses to anticancer rna nanoparticles and other emerging nanotechnologies this review captures key insights and developments emphasizing the need for interdisciplinary translation of scientific advancements into clinical practice and shaping the future of personalized cancer treatments for improved therapeutic outcomes', 'Nucleic acid nanobiosystems for cancer theranostics: an overview of emerging trends and challenges.', 'PubMed', '2025-05-06', None, None, None)
# ('pubmed_40326781', 'the complexity of atrial fibrillation af requires an integrated multifaceted multidisciplinary and holistic team approach to optimize the management of af patients active engagement of patients and involvement of nurses and various allied professionals ap and a strong collaboration with physicians is crucial in this respect as indicated by the 2024 european society of cardiology esc guidelines on the management of af this is also reflected in these latest guidelines by the concept of afcare which emphasizes the importance of including the patient carers and various healthcare professionals in this clinical consensus statement the role of nurses and aps is highlighted and includes optimal approaches on their involvement in the implementation and execution for these guideline recommendations in daily clinical practice moreover additional detail will be provided to the key components and their requirements to allow this integrated multidisciplinary care to be implemented alongside the perspective of the patient this statement also examines the challenges and opportunities in relation to their application to clinical practice and how optimal multidisciplinary care can be implemented', 'A multidisciplinary team approach in the 2024 ESC guidelines for the management of patients with Atrial Fibrillation - what is the role of nurses and allied professionals? A Clinical Consensus Statement of the Association of Cardiovascular Nursing and Allied Professions (ACNAP) and the European Heart Rhythm Association (EHRA) of the ESC.', 'PubMed', '2025-05-06', None, None, None)
# ('pubmed_40326754', 'wound care is a multifaceted and collaborative process and chronic wounds can have significant repercussions on a patients wellbeing and impose a financial burden on the healthcare industry while traditional wound dressings can effectively facilitate healing their limitations in addressing the intricacies of the wound healing process remain a formidable obstacle smart wound dressings have emerged as a promising solution to tackle this challenge offering numerous advantages over conventional dressings such as realtime monitoring of wound healing and enhanced wound care management these advanced medical dressings incorporate microelectronic sensors that can monitor the wound environment and provide timely interventions for accelerated and comprehensive healing furthermore advancements in drug delivery systems have enabled realtime monitoring targeted therapy and controlled release of medications smart wound dressings exhibit versatility as they are available in various forms and can be utilised for treating different types of acute or chronic wounds ultimately the development of innovative wound care technologies and treatments plays a vital role in addressing the complexities presented by wounds and enhancing patients quality of life this review sheds light on the diverse types of smart dressings and their distinctive features emphasising their potential in advancing the field of wound care', 'A review on smart dressings with advanced features.', 'PubMed', '2025-05-06', None, None, None)
# ('pubmed_40326742', 'to describe the variation in the use of potentially inappropriate antipsychotic and benzodiazepine medications in residents who have received a medication review and to evaluate the extent to which this variation is associated with aged care home ach and resident characteristics this crosssectional retrospective study used pharmacistextracted data from 15442 residents across 342 australian achs who had a medication review during 2019 the proportion of residents receiving 1 potentially inappropriate antipsychotic and benzodiazepine medication according to beers criteria were classified into quintiles by facility usage q1q5 quintile characteristics were compared using descriptive analysis of facility and resident data logistic regression was used to compare individual usage between residents in each quintile adjusting for facility and resident characteristics the cohort had mean age 85 years sd 9 with less than 14 of residents in q1 n  68 and 31 of residents in q5 n  68 using an antipsychotic for benzodiazepines these proportions were 19 in q1 n  68 and 45 in q5 n  67 facilities in major cities were significantly more likely to report antipsychotic q174 vs q588 p  03 and benzodiazepine use q169 vs q587 p  015 residents in q5 were seven times more likely to be prescribed an antipsychotic aor722 95 ci593879 than residents in q1 and eight times more likely to be prescribed a benzodiazepine aor857 95 ci 7331001 p  001 than residents in q1 significant variation exists in potentially inappropriate antipsychotic and benzodiazepine use among ach residents receiving a medication review highlighting the need for further research to reduce prescribing of these highrisk medications', 'Variation in the potentially inappropriate use of antipsychotic and benzodiazepine medications among individuals receiving residential medication management reviews.', 'PubMed', '2025-05-06', None, None, None)
# ('pubmed_40326724', 'we aimed to understand clinician perceptions of nudge interventions designed to prevent unsafe opioid prescribing for acute pain in primary care semistructured interviews were conducted fortyeight practices across three healthcare systems were included primary care clinicians who were exposed to nudge interventions as part of a randomized clinical trial were included intervention arms included an electronic health record alert upon new opioid prescribing either alone or with one or both nudge interventions written opioid justification andor monthly clinician comparison emails we used conventional content and thematic analysis to identify themes related to clinician perceptions of nudge interventions and the opioid epidemic we conducted and analyzed 77 clinician interviews clinicians voiced favorable impressions of both nudge interventions but they did not feel the nudge interventions had a direct impact on their own prescribing of opioids perhaps due to low prescribing secondary to other opioid interventions clinicians felt interventions should continue to assist high opioid prescribers nudge interventions are favorably perceived by physicians to be an additional option in the current landscape of interventions to prevent unsafe opioid prescribing for acute pain in the primary care setting', 'Clinician perceptions of electronic health record and email nudge interventions to prevent unsafe opioid prescribing: A qualitative study.', 'PubMed', '2025-05-06', None, None, None)
# ('pubmed_40326514', 'policy points antitrust enforcement has been too narrowly focused on predicting postmerger market share and not enough on the likely impact of mergers and acquisitions on production efficiency and quality care delivery redesign is a term that captures various innovations and changes in the organization and delivery of health care which may lead to increased production efficiency and improved quality of care regulators and policymakers can use the framework to develop empirical measures to assist in understanding changes in production processes as well as in resultant outcomes significant opportunities exist to improve data collection and require reporting to better assist regulators with antitrust enforcement and help policymakers create effective legislation examples include improving compliance with required hospital and insurer transaction price data reporting growing the availability of allpayer claims databases improving existing medicare cost reporting and achieving consensus on quality measures that are best used to measure the impact of consolidation there is a fundamental need to systematically track health care organizations and their affiliations and component parts eg hospitals physician practices skilled nursing facilities etc longitudinally especially as organizations expand across markets and state boundaries and are owned by various entities including private equity', 'A Policy and Regulatory Framework to Promote Care Delivery Redesign and Production Efficiency in Health Care Markets.', 'PubMed', '2025-05-06', None, None, None)
# ('pubmed_40326410', 'this is the first longitudinal qualitative study over three years to examine the development of stress in young adults with relatives with addictionparticipants experiences with violence and neglect are a risk factor for complex ptsdparticipants stress experiences were strikingly dynamic with varying patterns of intensityparticipants stress often persisted over the long term even after a relative died or contact was broken', 'The dynamics of stress experiences of students with relatives with addiction problems: a longitudinal qualitative study.', 'PubMed', '2025-05-06', None, None, None)
# ('pubmed_40326302', 'for those displaced across borders significant adversity before during and after displacement journeys including attitudes and structures in countries of transit and arrival contributes to considerable risk of poor physical and mental health and poor and exclusionary experiences of health care we aimed to understand the opportunities and practices that can support better healthcare responses for forced migrants we integrated 1 local stakeholder perspectives from workshops and dialogue 2 evidence and knowledge from a mixedmethods systematic review and 3 learning from five case examples from current international practice we ran database searches american psychological association psycinfo embase the cochrane central register of controlled trials cumulative index to nursing and allied health literature medline national institute for health and care research journals library in february 2022 searched relevant agency websites and conducted backward and forward citation searches extracted data assessed methodological quality and integrated qualitative and quantitative findings we studied three services in the uk one in belgium and one in australia conducting semistructured interviews with providers collaborators and service users and making site visits and observations if possible the review identified 108 studies we identified six domains of impact 1 benefit from and creation of community including linkages with formal health services 2 the formation of networks of care that included traditional and nontraditional providers 3 proactive engagement including conducting care in familiar spaces 4 considered communication 5 informed providers and enhanced attitudes and 6 a right to knowledge respecting the need of new arrivals for information knowledge and confidence in local systems the case examples drew attention to the benefits of a willingness to innovate and work outside existing structures microflexibility in interactions with patients and the creation of safe spaces to encourage trust in providers other positive behaviours included engaging in intercultural exchange facilitating the connection of people with their cultural sphere eg nationality language and a reflexive attitude to the individual and their broader circumstances social and political structures can diminish these efforts review wide heterogeneity in study characteristics presented challenges in drawing clear associations from the data case examples we engaged only a small numbers of service users and only with service users from some services we found that environments that enable good health and enable people to live lives of meaning are vital we found that these environments require flexibility and reflexivity in practice intercultural exchange humility and a commitment to communication we suggest that a broader range of caring practitioners can and should through intentional and interconnected practice contribute to the health care of forced migrants opening up healthcare systems to include other state actors eg teachers and settlement workers and a range of nonstate actors who should include community leaders and peers and private players is a key step in this process future work should focus on the health and health service implications of immigration practices the inclusion of peers in a range of healthcare roles alliancebuilding across unlikely collaborators and the embedding of intercultural exchange in practice this study is registered as prospero crd42021271464 this award was funded by the national institute for health and care research nihr health and social care delivery research programme nihr award ref nihr132961 and is published in full in how can we improve and shape health care to better respond to refugee and asylumseeking communities we 1 gathered the views of local refugee and asylumseeking communities healthcare staff and other stakeholders such as council and community workers about their ideas for improvements in healthc ...
# ('pubmed_40325945', 'cystic fibrosis cf is a chronic genetic disorder requiring regimented visits for maintenance of care the covid19 pandemic accelerated the accessibility of telehealth th and forced a trial of incorporating remote care into routine cf care the cf learning network cfln organized for data sharing into a telehealth innovation lab thilab to improve access to the interdisciplinary care team and coproduced shared agendasetting all persons with cf pwcf with a cf diagnosis in the cf foundation registry cffpr from 12020122021 were included and categorized into cfln thilab cfln thilab nonparticipants and noncfln programs standardized th implementation in the cfln thilab is associated with increased access to the cf care model and results in similar lung function and nutrition health outcomes in 2020 and 2021 the average number of th visits per person per year and the percentage of pwcf with one or more th visits per year were higher in the cfln thilab than in the other groups lung function was highest in pwcf followed by a program that was part of the cfln thilab in 2020 and 2021 anthropometric measurements spirometry and attainment of microbiology cultures were similar among all three groups access to interdisciplinary care was highest in the cfln nonthilab group integrating th into cf care in the cfln thilab provided access to care during the covid19 pandemic without compromising clinical outcomes further research on optimizing the telehealth experience for pwcf can help better understand ths longterm impact on cf care', 'Cystic Fibrosis Learning Network Telehealth Innovation Lab During the COVID-19 Pandemic: Impact on Access to Care, Outcomes, and a New CF Care Model.', 'PubMed', '2025-05-06', None, None, None)
# ('pubmed_40325894', 'employment status significantly affects individuals wellbeing and health outcomes positive transitions such as moving from unemployment to employment can improve job satisfaction and social standing while negative transitions such as unemployment have been associated with adverse health outcomes to assess the impact of employment stability on health outcomes among young workers we conducted a retrospective cohort study using data from the korean national health insurance service database the study included 4 031 249 individuals aged 2544 years who underwent health checkups between 2009 and 2010 employment stability was categorized into two groups stable employment and unstable employment adjusted hazard ratios hrs and 95 confidence intervals cis were estimated using multivariable cox proportional hazard models to evaluate the impact of employment stability on the risk of allcause mortality unstable employment significantly increased the risk of allcause mortality in both men and women compared with the stable employment group the hrs were 180 95 ci 174186 for men and 158 95 ci 149168 for women the impact was most pronounced among individuals aged 4044 years those in higherincome subgroups and those with diabetes highlighting these groups as particularly vulnerable to the effects of unstable employment this study highlights the impact of employment stability on allcause mortality focusing on gender differences young workers and social role theory', 'The impact of employment stability on all-cause mortality among young workers.', 'PubMed', '2025-05-06', None, None, None)
# ('pubmed_40325870', 'basic first aid fa knowledge is important for inschool adolescents to save lives in emergency situations the study aimed to evaluate the change in basic and psychological fa knowledge levels after developing an educational intervention a quasiexperimental study with a pre and posttest design and no control group was conducted the intervention consisted of sessions on basic and psychological first aid for students in six schools a knowledge test was administered to the students prior to the start of the intervention at the end a posttest was administered with the same questions used in the pretest a change in the knowledge level of 185 students was evaluated the mean difference between the pretest and posttest for knowledge level was significant 311 95 ci 268354 airway management poisoning fa basics and psychological fa all increased by more than 10 points in the posttest the study showed that the intervention improves the level of knowledge of basic and psychological fa in adolescents the results demonstrate that health education in the school setting can have a significant impact', 'Effectiveness of a Nursing Intervention to Improve Basic and Psychological First Aid Knowledge Among Adolescents. A Quasi-Experimental Study.', 'PubMed', '2025-05-06', None, None, None)
# ('pubmed_40325830', 'patients require additional treatment when pituitary surgery for cushings disease is unsuccessful exciting innovations in pituitary surgery bring hope for achieving better outcomes quantifying the potential value of these innovations using early health economic modelling can provide guidance throughout their development the aim of this study was to explore the conditions for success of these innovations using costeffectiveness analyses the model consists of a decision tree and statetransition model with a 10year time horizon the model simulates the clinical management of patients with cushings disease and pituitary surgery as primary treatment model input was derived from literature and expert opinion model outcomes were incremental healthcare costs and incremental qualityadjusted lifeyears qaly we performed scenario analyses including a headroom and threshold analysis to determine the maximum innovation price for costeffectiveness probabilistic sensitivity analysis and oneway sensitivity analyses were performed to address the impact of uncertainty on outcome parameters the headroom analysis showed that per patient 0028 qalys could be gained and 2082 euros could be saved over 10 years with a willingness to pay of 80000 euros the maximum price of an innovation is 4288 euros 95 ci 33775181 to reach costeffectiveness sensitivity analyses showed that utility values mainly determined costeffectiveness our early health economic model exploring the conditions for success of innovations in pituitary surgery shows room for improvement but also the importance of accurate healthrelated quality of life data to assess the economic value of innovations in individuals with cd', "Innovative Approaches to Improve the Success of Pituitary Surgery in Cushing's Disease: A Cost-Effectiveness Perspective.", 'PubMed', '2025-05-06', None, None, None)
#
# Column names:
# filename
# cleaned_text
# title
# source
# publication_date
# author
# pub_date
# abstract

# %% [markdown]
# week 2 new with bert

# %%
# weeeek 2 new
# Week 2 - Extractive Summarization using BERT

import sqlite3
import pandas as pd

# Ensure necessary packages are installed
try:
    from summarizer import Summarizer
except ImportError:
    print("Installing necessary packages...")
    import os
    os.system("pip install bert-extractive-summarizer")
    from summarizer import Summarizer

# Step 1: Set up the BERT Extractive Summarization model
print("Loading BERT summarization model...")
bert_model = Summarizer()

# Step 2: Connect to the SQLite database
def connect_to_db():
    conn = sqlite3.connect("healthcare_research.db")
    return conn

# Step 3: Add a summary column to the database (if not already present)
def add_summary_column(conn):
    cursor = conn.cursor()
    cursor.execute("PRAGMA table_info(research_papers)")
    columns = [col[1] for col in cursor.fetchall()]
    if "summary" not in columns:
        cursor.execute("ALTER TABLE research_papers ADD COLUMN summary TEXT")
        print("Added 'summary' column to research_papers table.")
    conn.commit()

# Step 4: Generate extractive summaries using BERT
def generate_summary(text, ratio=0.2):  # Extract 20% of the most important sentences
    try:
        if len(text.split()) < 50:  # Skip very short texts
            return "Text too short for summarization"
        summary = bert_model(text, ratio=ratio)
        return summary
    except Exception as e:
        print(f"Error summarizing text: {e}")
        return "Summary generation failed"

# Step 5: Process papers and update the database
def summarize_papers():
    conn = connect_to_db()
    add_summary_column(conn)
    cursor = conn.cursor()

    # Check if an id column exists; if not, add it as a non-primary key column
    cursor.execute("PRAGMA table_info(research_papers)")
    columns = [col[1] for col in cursor.fetchall()]
    if "id" not in columns:
        cursor.execute("ALTER TABLE research_papers ADD COLUMN id INTEGER")  # Removed PRIMARY KEY and AUTOINCREMENT
        # Initialize the 'id' column with values
        cursor.execute("SELECT filename FROM research_papers")
        filenames = cursor.fetchall()
        for i, filename in enumerate(filenames):
            cursor.execute("UPDATE research_papers SET id = ? WHERE filename = ?", (i + 1, filename[0]))
        conn.commit()
        print("Added and initialized 'id' column to research_papers table.")


    # Fetch papers that don't have summaries
    cursor.execute("SELECT id, filename, cleaned_text FROM research_papers WHERE summary IS NULL OR summary = ''")
    papers = cursor.fetchall()

    total_papers = len(papers)
    print(f"Found {total_papers} papers to summarize.")

    for idx, (paper_id, filename, text) in enumerate(papers, 1):
        print(f"Processing {idx}/{total_papers}: {filename}")

        summary = generate_summary(text) if text else "Text too short or empty for summarization"

        # Update the database with the summary
        cursor.execute("UPDATE research_papers SET summary = ? WHERE id = ?", (summary, paper_id))
        conn.commit()
        print(f"Summary for {filename}: {summary[:100]}...")  # Print first 100 chars

    conn.close()
    print("Summarization complete. All summaries stored in the database.")

# Step 6: Verify the results
def verify_summaries():
    conn = connect_to_db()
    cursor = conn.cursor()

    cursor.execute("SELECT filename, title, summary FROM research_papers LIMIT 5")
    rows = cursor.fetchall()

    print("\nSample summaries from database:")
    for row in rows:
        print(f"Filename: {row[0]}")
        print(f"Title: {row[1]}")
        print(f"Summary: {row[2]}")
        print("-" * 50)

    conn.close()

# Run the script
if __name__ == "__main__":
    summarize_papers()
    verify_summaries()
# Out:
# Loading BERT summarization model...
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Added 'summary' column to research_papers table.
# Added and initialized 'id' column to research_papers table.
# Found 1074 papers to summarize.
# Processing 1/1074: pubmed_40327459
# Summary for pubmed_40327459: ...
# Processing 2/1074: pubmed_40327390
# Summary for pubmed_40327390: ...
# Processing 3/1074: pubmed_40327384
# Summary for pubmed_40327384: ...
# Processing 4/1074: pubmed_40327329
# Summary for pubmed_40327329: ...
# Processing 5/1074: pubmed_40327286
# 27918725
# 33766750
# 17537614
# 20668052
# 33754023
# 19641587
# 35210368
# 17384583
# 9446642
# 32392088
# 34753510
# 35134463
# 33045622
# 24382354
# 21440622
# 23474486
# 35273493
# 30053525
# 38574433
# 37154056
# 26232232
# 33314649
# 32468629
# 11709088
# 37425037
# 23325925
# 10628339
# 36435202
# 32112883
# 24058702
# 31883358
# 38323433
# 26112889
# 17250813
# 37871668
# 33437153
# 38150302
# 38316068
# 29061338
# 27567406
# 35914558
# 37714227
# 36510036
# 32958254
# 29304479
# Summary for pubmed_40327286
# 27918725
# 33766750
# 17537614
# 20668052
# 33754023
# 19641587
# 35210368
# 17384583
# 9446642
# 32392088
# 34753510
# 35134463
# 33045622
# 24382354
# 21440622
# 23474486
# 35273493
# 30053525
# 38574433
# 37154056
# 26232232
# 33314649
# 32468629
# 11709088
# 37425037
# 23325925
# 10628339
# 36435202
# 32112883
# 24058702
# 31883358
# 38323433
# 26112889
# 17250813
# 37871668
# 33437153
# 38150302
# 38316068
# 29061338
# 27567406
# 35914558
# 37714227
# 36510036
# 32958254
# 29304479: ...
# Processing 6/1074: pubmed_40327095
# 32984198
# 31953750
# 15955855
# 10352583
# 16615053
# 23958828
# 14531007
# 29306987
# 12677511
# 21643638
# 20093572
# 19022993
# 21567143
# 26736224
# 15114491
# 23285596
# 22764084
# 27330520
# 14974593
# 18400271
# 15476531
# 23793577
# 19255628
# 32613678
# Summary for pubmed_40327095
# 32984198
# 31953750
# 15955855
# 10352583
# 16615053
# 23958828
# 14531007
# 29306987
# 12677511
# 21643638
# 20093572
# 19022993
# 21567143
# 26736224
# 15114491
# 23285596
# 22764084
# 27330520
# 14974593
# 18400271
# 15476531
# 23793577
# 19255628
# 32613678: ...
# Processing 7/1074: pubmed_40327021
# Summary for pubmed_40327021: ...
# Processing 8/1074: pubmed_40326881
# Summary for pubmed_40326881: Text too short or empty for summarization...
# Processing 9/1074: pubmed_40326805
# Summary for pubmed_40326805: ...
# Processing 10/1074: pubmed_40326781
# Summary for pubmed_40326781: ...
# Processing 11/1074: pubmed_40326754
# Summary for pubmed_40326754: ...
# Processing 12/1074: pubmed_40326742
# Summary for pubmed_40326742: ...
# Processing 13/1074: pubmed_40326724
# Summary for pubmed_40326724: ...
# Processing 14/1074: pubmed_40326514
# Summary for pubmed_40326514: ...
# Processing 15/1074: pubmed_40326410
# Summary for pubmed_40326410: this is the first longitudinal qualitative study over three years to examine the development of stre...
# Processing 16/1074: pubmed_40326302
# Summary for pubmed_40326302: ...
# Processing 17/1074: pubmed_40325945
# Summary for pubmed_40325945: ...
# Processing 18/1074: pubmed_40325894
# Summary for pubmed_40325894: ...
# Processing 19/1074: pubmed_40325870
# Summary for pubmed_40325870: ...
# Processing 20/1074: pubmed_40325830
# Summary for pubmed_40325830: ...
# Processing 21/1074: arxiv_2505.02751v1
# Summary for arxiv_2505.02751v1: ...
# Processing 22/1074: arxiv_2505.02694v1
# Summary for arxiv_2505.02694v1: ...
# Processing 23/1074: arxiv_2505.02470v1
# Summary for arxiv_2505.02470v1: ...
# Processing 24/1074: arxiv_2505.02238v1
# Summary for arxiv_2505.02238v1: ...
# Processing 25/1074: arxiv_2505.02228v1
# Summary for arxiv_2505.02228v1: ...
# Processing 26/1074: arxiv_2505.02173v1
# Summary for arxiv_2505.02173v1: ...
# Processing 27/1074: arxiv_2505.02062v1
# Summary for arxiv_2505.02062v1: ...
# Processing 28/1074: arxiv_2505.02024v1
# Summary for arxiv_2505.02024v1: ...
# Processing 29/1074: arxiv_2505.02008v1
# Summary for arxiv_2505.02008v1: ...
# Processing 30/1074: arxiv_2505.01866v1
# Summary for arxiv_2505.01866v1: ...
# Processing 31/1074: arxiv_2505.01821v1
# Summary for arxiv_2505.01821v1: ...
# Processing 32/1074: arxiv_2505.01783v1
# Summary for arxiv_2505.01783v1: ...
# Processing 33/1074: arxiv_2505.01651v1
# Summary for arxiv_2505.01651v1: ...
# Processing 34/1074: arxiv_2505.01576v1
# Summary for arxiv_2505.01576v1: ...
# Processing 35/1074: arxiv_2505.01543v1
# Summary for arxiv_2505.01543v1: ...
# Processing 36/1074: arxiv_2505.01277v1
# Summary for arxiv_2505.01277v1: ...
# Processing 37/1074: arxiv_2505.01096v1
# Summary for arxiv_2505.01096v1: ...
# Processing 38/1074: arxiv_2505.01091v1
# Summary for arxiv_2505.01091v1: ...
# Processing 39/1074: arxiv_2505.00941v1
# Summary for arxiv_2505.00941v1: ...
# Processing 40/1074: arxiv_2505.00918v1
# Summary for arxiv_2505.00918v1: ...
# Processing 41/1074: semanticscholar_6e7b07d3fc06e2332107eefa4325e54f16d1cb1a
# Summary for semanticscholar_6e7b07d3fc06e2332107eefa4325e54f16d1cb1a: ...
# Processing 42/1074: semanticscholar_386fe40398087a63ba0e2e8c646b678244b85461
# Summary for semanticscholar_386fe40398087a63ba0e2e8c646b678244b85461: Text too short or empty for summarization...
# Processing 43/1074: semanticscholar_8157f3f9c1be66f448ee0589cbb4b699e2f9e1a8
# Summary for semanticscholar_8157f3f9c1be66f448ee0589cbb4b699e2f9e1a8: patient and public involvement ppi has become increasingly important in the development delivery and...
# Processing 44/1074: semanticscholar_78e1aec5f05d0b435ca119ebce1b55bd85124fcb
# Summary for semanticscholar_78e1aec5f05d0b435ca119ebce1b55bd85124fcb: ...
# Processing 45/1074: semanticscholar_f2f453f4f3cbb342bd45d1104ea5a15e3e814d07
# Summary for semanticscholar_f2f453f4f3cbb342bd45d1104ea5a15e3e814d07: ...
# Processing 46/1074: semanticscholar_7680092a1dab52c9db1972085610470e7b9465b5
# Summary for semanticscholar_7680092a1dab52c9db1972085610470e7b9465b5: ...
# Processing 47/1074: semanticscholar_14881b7be6f8c409d766cbd7c2c5db9450baf9e8
# Summary for semanticscholar_14881b7be6f8c409d766cbd7c2c5db9450baf9e8: ...
# Processing 48/1074: semanticscholar_d50bc2f0b4c0b858c1887b923c562e21731e54b2
# Summary for semanticscholar_d50bc2f0b4c0b858c1887b923c562e21731e54b2: ...
# Processing 49/1074: semanticscholar_71402259d3073e789d8eba0367ecf87e8def79b8
# Summary for semanticscholar_71402259d3073e789d8eba0367ecf87e8def79b8: Text too short or empty for summarization...
# Processing 50/1074: semanticscholar_cf7bbcfbeae7ad78594cd39556d348f8b90e4988
# Summary for semanticscholar_cf7bbcfbeae7ad78594cd39556d348f8b90e4988: ...
# Processing 51/1074: semanticscholar_e8678b399310baa26cdbc42ec75f37adc8a112f2
# Summary for semanticscholar_e8678b399310baa26cdbc42ec75f37adc8a112f2: ...
# Processing 52/1074: semanticscholar_fe771cc1c6d6f0403bf0e30048a9cbc34263e200
# Summary for semanticscholar_fe771cc1c6d6f0403bf0e30048a9cbc34263e200: ...
# Processing 53/1074: semanticscholar_c8f6ca89c0b0e99028d38d73f149cf6d180dbafb
# Summary for semanticscholar_c8f6ca89c0b0e99028d38d73f149cf6d180dbafb: ...
# Processing 54/1074: semanticscholar_90f3b8904f2735de916fbbd6906f7745590a5a01
# Summary for semanticscholar_90f3b8904f2735de916fbbd6906f7745590a5a01: ...
# Processing 55/1074: semanticscholar_e376965b86dce35866c8f9d76ea967ddee96e9f3
# Summary for semanticscholar_e376965b86dce35866c8f9d76ea967ddee96e9f3: ...
# Processing 56/1074: semanticscholar_e6fd611e426b1a2b38a8f8682e4d07aa61d9839a
# Summary for semanticscholar_e6fd611e426b1a2b38a8f8682e4d07aa61d9839a: ...
# Processing 57/1074: semanticscholar_333fdaabc15bb8e7e9b2386ff1b7cb4a42c9855a
# Summary for semanticscholar_333fdaabc15bb8e7e9b2386ff1b7cb4a42c9855a: ...
# Processing 58/1074: semanticscholar_41246b1805d4c35ac6c575c2e4146225ebfec0e1
# Summary for semanticscholar_41246b1805d4c35ac6c575c2e4146225ebfec0e1: Text too short or empty for summarization...
# Processing 59/1074: semanticscholar_650a366890e65390e4ed1cc8c134cf2540928706
# Summary for semanticscholar_650a366890e65390e4ed1cc8c134cf2540928706: ...
# Processing 60/1074: semanticscholar_b5a6a7bc2a3234ed162287d8c3f6782ac0c95b48
# Summary for semanticscholar_b5a6a7bc2a3234ed162287d8c3f6782ac0c95b48: Text too short or empty for summarization...
# Processing 61/1074: semanticscholar_2eb675abb55e48406d0dfe24ecef09d200a5f1ff
# Summary for semanticscholar_2eb675abb55e48406d0dfe24ecef09d200a5f1ff: Text too short or empty for summarization...
# Processing 62/1074: semanticscholar_54fb8f91de3166af35064a5b9f8d521ae785791a
# Summary for semanticscholar_54fb8f91de3166af35064a5b9f8d521ae785791a: ...
# Processing 63/1074: semanticscholar_46a3c95a10907ff9003387b501173c6f709a55d3
# Summary for semanticscholar_46a3c95a10907ff9003387b501173c6f709a55d3: ...
# Processing 64/1074: semanticscholar_3a0f0bcea2ece1892caa0eb702dcb8b3fe9ffac4
# Summary for semanticscholar_3a0f0bcea2ece1892caa0eb702dcb8b3fe9ffac4: ...
# Processing 65/1074: semanticscholar_4a0faf540174e072e8440ded65057c10d5964667
# Summary for semanticscholar_4a0faf540174e072e8440ded65057c10d5964667: ...
# Processing 66/1074: semanticscholar_035e9cd81d5dd3b1621fb14e00b452959daffddf
# Summary for semanticscholar_035e9cd81d5dd3b1621fb14e00b452959daffddf: Text too short or empty for summarization...
# Processing 67/1074: semanticscholar_dc4a70cb41612703a4e0ac94d883c1abe82b2fc2
# Summary for semanticscholar_dc4a70cb41612703a4e0ac94d883c1abe82b2fc2: Text too short or empty for summarization...
# Processing 68/1074: semanticscholar_e55dabadb91d28c2fd00afaf4be49c7144845abd
# Summary for semanticscholar_e55dabadb91d28c2fd00afaf4be49c7144845abd: ...
# Processing 69/1074: semanticscholar_edfad9cb15febd303ed930b9462539df7059f473
# Summary for semanticscholar_edfad9cb15febd303ed930b9462539df7059f473: ...
# Processing 70/1074: semanticscholar_21a76ab24e50f3d0690e839f313e6963d79e95c8
# Summary for semanticscholar_21a76ab24e50f3d0690e839f313e6963d79e95c8: ...
# Processing 71/1074: semanticscholar_68c1c45da73d232dfe351870b129f44039ca0129
# Summary for semanticscholar_68c1c45da73d232dfe351870b129f44039ca0129: ...
# Processing 72/1074: semanticscholar_09eb0319a81a548edbcfaf894c7dffc60b502edd
# Summary for semanticscholar_09eb0319a81a548edbcfaf894c7dffc60b502edd: ...
# Processing 73/1074: semanticscholar_2e85e45c367b02d59c29eacbd95dbf65dab77fcf
# Summary for semanticscholar_2e85e45c367b02d59c29eacbd95dbf65dab77fcf: ...
# Processing 74/1074: semanticscholar_02c6cada355425284c4533e244356c43b21e9507
# Summary for semanticscholar_02c6cada355425284c4533e244356c43b21e9507: Text too short or empty for summarization...
# Processing 75/1074: semanticscholar_82f731b9f127cf682b29f3111b8a789e0147865e
# Summary for semanticscholar_82f731b9f127cf682b29f3111b8a789e0147865e: ...
# Processing 76/1074: semanticscholar_8ca6dc0c2320c81a45107c6176580a5948544782
# Summary for semanticscholar_8ca6dc0c2320c81a45107c6176580a5948544782: Text too short or empty for summarization...
# Processing 77/1074: semanticscholar_f6389aff7b977adcf55bb5910127e18a21da593f
# Summary for semanticscholar_f6389aff7b977adcf55bb5910127e18a21da593f: Text too short or empty for summarization...
# Processing 78/1074: semanticscholar_8f729f8e898e64a5c56741b41216ad786ccd97c1
# Summary for semanticscholar_8f729f8e898e64a5c56741b41216ad786ccd97c1: ...
# Processing 79/1074: semanticscholar_286e6f95ee536ffc9c99477fbff7927d86003619
# Summary for semanticscholar_286e6f95ee536ffc9c99477fbff7927d86003619: ...
# Processing 80/1074: semanticscholar_cf6d8164c74a25e4119e23f69d5ab8412f11a609
# Summary for semanticscholar_cf6d8164c74a25e4119e23f69d5ab8412f11a609: ...
# Processing 81/1074: semanticscholar_bd8050e477fdbacc8f65bfb207f6ad12c586a5ed
# Summary for semanticscholar_bd8050e477fdbacc8f65bfb207f6ad12c586a5ed: ...
# Processing 82/1074: semanticscholar_0d23516441fc5e2b616e46affb6e5ea1e00e1044
# Summary for semanticscholar_0d23516441fc5e2b616e46affb6e5ea1e00e1044: ...
# Processing 83/1074: semanticscholar_1ad53bae43ed95b4edcd463065356ca143fe7af5
# Summary for semanticscholar_1ad53bae43ed95b4edcd463065356ca143fe7af5: ...
# Processing 84/1074: semanticscholar_a27b40d323eb98b10115f28f8a0fe1957eda40c8
# Summary for semanticscholar_a27b40d323eb98b10115f28f8a0fe1957eda40c8: Text too short or empty for summarization...
# Processing 85/1074: semanticscholar_374bda97d2de12046e6324607911ed22e6f48cb1
# Summary for semanticscholar_374bda97d2de12046e6324607911ed22e6f48cb1: ...
# Processing 86/1074: semanticscholar_f601141f187b0c99429b2619c5fbb85888e132df
# Summary for semanticscholar_f601141f187b0c99429b2619c5fbb85888e132df: ...
# Processing 87/1074: semanticscholar_e4ff102c17bf869a3bea02ccc72775b7c55e8ad2
# Summary for semanticscholar_e4ff102c17bf869a3bea02ccc72775b7c55e8ad2: ...
# Processing 88/1074: semanticscholar_428c161cbd3a8f9150010c486af3099d166b491e
# Summary for semanticscholar_428c161cbd3a8f9150010c486af3099d166b491e: ...
# Processing 89/1074: semanticscholar_53d9c883de5f75369faf4c7e0eeb4a5110fa390f
# Summary for semanticscholar_53d9c883de5f75369faf4c7e0eeb4a5110fa390f: ...
# Processing 90/1074: semanticscholar_e02083b119100609612724552cbdfa7249a55bca
# Summary for semanticscholar_e02083b119100609612724552cbdfa7249a55bca: ...
# Processing 91/1074: semanticscholar_03b61b6886a7d066e3b008f727bf06adf797b222
# Summary for semanticscholar_03b61b6886a7d066e3b008f727bf06adf797b222: ...
# Processing 92/1074: semanticscholar_4943781074f37a3768f52fa1757a0cf5a9f51db7
# Summary for semanticscholar_4943781074f37a3768f52fa1757a0cf5a9f51db7: ...
# Processing 93/1074: semanticscholar_2fba87886961b502416dace3cdaf44387629c134
# Summary for semanticscholar_2fba87886961b502416dace3cdaf44387629c134: ...
# Processing 94/1074: semanticscholar_4756fbd25aa0d65f336730cf2eb43d4c8f4beee1
# Summary for semanticscholar_4756fbd25aa0d65f336730cf2eb43d4c8f4beee1: ...
# Processing 95/1074: semanticscholar_789735aa46c0d97fb73f3ab8aa62511251e54604
# Summary for semanticscholar_789735aa46c0d97fb73f3ab8aa62511251e54604: Text too short or empty for summarization...
# Processing 96/1074: semanticscholar_ad6ce4a1d8a11208fc19b3dd17b5f0e96f40d2ab
# Summary for semanticscholar_ad6ce4a1d8a11208fc19b3dd17b5f0e96f40d2ab: Text too short or empty for summarization...
# Processing 97/1074: semanticscholar_960c3417ac5500575b1ab1f64f478fd52fcdfc16
# Summary for semanticscholar_960c3417ac5500575b1ab1f64f478fd52fcdfc16: ...
# Processing 98/1074: semanticscholar_3fb042a4ad98aa8e9f3ea11bce8676dee6e2de4b
# Summary for semanticscholar_3fb042a4ad98aa8e9f3ea11bce8676dee6e2de4b: healthcare institutions have been searching for ways to increase the value they deliver to patients ...
# Processing 99/1074: semanticscholar_4bf266fe2809db66cfb896bdb060302346d214be
# Summary for semanticscholar_4bf266fe2809db66cfb896bdb060302346d214be: ...
# Processing 100/1074: semanticscholar_8e460a050511bc0cca84a4c28c80e06162a13b50
# Summary for semanticscholar_8e460a050511bc0cca84a4c28c80e06162a13b50: ...
# Processing 101/1074: semanticscholar_c160bc4f02f75199c8edf9239126b0729cfae465
# Summary for semanticscholar_c160bc4f02f75199c8edf9239126b0729cfae465: ...
# Processing 102/1074: semanticscholar_eca3e31d7f37fb586e6bdf5bf8df6e60db0ba135
# Summary for semanticscholar_eca3e31d7f37fb586e6bdf5bf8df6e60db0ba135: ...
# Processing 103/1074: semanticscholar_c19015b925ab9083a5addcd76ebf0192ff455844
# Summary for semanticscholar_c19015b925ab9083a5addcd76ebf0192ff455844: Text too short or empty for summarization...
# Processing 104/1074: semanticscholar_82c3f2ce5a93e397611dd860cd1a5159b6d0809a
# Summary for semanticscholar_82c3f2ce5a93e397611dd860cd1a5159b6d0809a: Text too short or empty for summarization...
# Processing 105/1074: semanticscholar_9af09ff23e6bb9cc8316b51a8772d036e7a3b2c1
# Summary for semanticscholar_9af09ff23e6bb9cc8316b51a8772d036e7a3b2c1: Text too short or empty for summarization...
# Processing 106/1074: semanticscholar_056d86a6599429db18a31ec04d037589295e9028
# Summary for semanticscholar_056d86a6599429db18a31ec04d037589295e9028: Text too short or empty for summarization...
# Processing 107/1074: semanticscholar_5c4ded20583de8216232e62b83503ef8b2c0ee63
# Summary for semanticscholar_5c4ded20583de8216232e62b83503ef8b2c0ee63: ...
# Processing 108/1074: semanticscholar_c593c1adf858050fdf09c840e71e815cf1bcf5c9
# Summary for semanticscholar_c593c1adf858050fdf09c840e71e815cf1bcf5c9: ...
# Processing 109/1074: semanticscholar_5611b42596ff91b4319ea25379e71d6589adc327
# Summary for semanticscholar_5611b42596ff91b4319ea25379e71d6589adc327: ...
# Processing 110/1074: semanticscholar_3b39e8321996180a4f6a0609c876c15f73e039e9
# Summary for semanticscholar_3b39e8321996180a4f6a0609c876c15f73e039e9: ...
# Processing 111/1074: semanticscholar_d5ef3cdac56ebd3121579e263e1623ae2926913e
# Summary for semanticscholar_d5ef3cdac56ebd3121579e263e1623ae2926913e: ...
# Processing 112/1074: semanticscholar_c4739da86061103a52ee628133c0c8ce5dc11353
# Summary for semanticscholar_c4739da86061103a52ee628133c0c8ce5dc11353: ...
# Processing 113/1074: semanticscholar_693fa610798d760d70fe1fb92d1cfd685d93bb8c
# Summary for semanticscholar_693fa610798d760d70fe1fb92d1cfd685d93bb8c: ...
# Processing 114/1074: semanticscholar_379c269f70ad7a7437367893fa394c33399d7e77
# Summary for semanticscholar_379c269f70ad7a7437367893fa394c33399d7e77: ...
# Processing 115/1074: semanticscholar_009ad4aabd241dda2905d07933cd7347f326a2b8
# Summary for semanticscholar_009ad4aabd241dda2905d07933cd7347f326a2b8: Text too short or empty for summarization...
# Processing 116/1074: semanticscholar_37d899488dbf70b247d9ec99992b5bb12fcfdaf2
# Summary for semanticscholar_37d899488dbf70b247d9ec99992b5bb12fcfdaf2: ...
# Processing 117/1074: semanticscholar_3eb43bedda8240244a47f3144561608731f68f26
# Summary for semanticscholar_3eb43bedda8240244a47f3144561608731f68f26: ...
# Processing 118/1074: semanticscholar_08f8217037a004433a24f6a5be2a8b8c63a0d470
# Summary for semanticscholar_08f8217037a004433a24f6a5be2a8b8c63a0d470: Text too short or empty for summarization...
# Processing 119/1074: semanticscholar_c9c5756f6bb25d5dc222f8dfbfd4bf349acbcdea
# Summary for semanticscholar_c9c5756f6bb25d5dc222f8dfbfd4bf349acbcdea: ...
# Processing 120/1074: semanticscholar_9629e1e882d17f51a6dadaa1d5349e2198b0a7b5
# Summary for semanticscholar_9629e1e882d17f51a6dadaa1d5349e2198b0a7b5: ...
# Processing 121/1074: semanticscholar_85e42ad30ef2bd78273f46b05a406dd265a42cbb
# Summary for semanticscholar_85e42ad30ef2bd78273f46b05a406dd265a42cbb: Text too short or empty for summarization...
# Processing 122/1074: semanticscholar_54924924c4c4ecc73320a5466e34a22ca5f62ba7
# Summary for semanticscholar_54924924c4c4ecc73320a5466e34a22ca5f62ba7: ...
# Processing 123/1074: semanticscholar_7369f51ae86b07ff91362deacb2820e042054942
# Summary for semanticscholar_7369f51ae86b07ff91362deacb2820e042054942: ...
# Processing 124/1074: semanticscholar_8ec9a9ee4c4bbbbe76b53c174145c2b8a7a29978
# Summary for semanticscholar_8ec9a9ee4c4bbbbe76b53c174145c2b8a7a29978: ...
# Processing 125/1074: semanticscholar_0777ca86319c1f44e9ffdb458571adb028d65925
# Summary for semanticscholar_0777ca86319c1f44e9ffdb458571adb028d65925: Text too short or empty for summarization...
# Processing 126/1074: semanticscholar_666e4983f9eb5396266a2bef598ebe4a883447a2
# Summary for semanticscholar_666e4983f9eb5396266a2bef598ebe4a883447a2: Text too short or empty for summarization...
# Processing 127/1074: semanticscholar_dbb6a5534fb1216b678f822c00c15bcae1d23f00
# Summary for semanticscholar_dbb6a5534fb1216b678f822c00c15bcae1d23f00: ...
# Processing 128/1074: semanticscholar_69f31f547788c33ba66b25cbfaffd7bbbac753e6
# Summary for semanticscholar_69f31f547788c33ba66b25cbfaffd7bbbac753e6: Text too short or empty for summarization...
# Processing 129/1074: semanticscholar_973aa725aa80b0bbd51a899b4db72b5f94a28e64
# Summary for semanticscholar_973aa725aa80b0bbd51a899b4db72b5f94a28e64: ...
# Processing 130/1074: semanticscholar_c1e1e971d993a50fa470710bb7a7bbbb4ce5b1af
# Summary for semanticscholar_c1e1e971d993a50fa470710bb7a7bbbb4ce5b1af: ...
# Processing 131/1074: semanticscholar_9c6c7cd4133357c4ead8f0c3ca3727063dd57b84
# Summary for semanticscholar_9c6c7cd4133357c4ead8f0c3ca3727063dd57b84: ...
# Processing 132/1074: semanticscholar_7fe59291a57aa743ca42a91199d4519e214c328f
# Summary for semanticscholar_7fe59291a57aa743ca42a91199d4519e214c328f: ...
# Processing 133/1074: semanticscholar_8fd904d492b2250752e7ffbfd210f5331f5994c0
# Summary for semanticscholar_8fd904d492b2250752e7ffbfd210f5331f5994c0: an online portal to help healthcare innovators including front line clinicians and service managers ...
# Processing 134/1074: semanticscholar_56d65b54e02b5fb5b1d690fd6ffd2b2839b28294
# Summary for semanticscholar_56d65b54e02b5fb5b1d690fd6ffd2b2839b28294: ...
# Processing 135/1074: semanticscholar_d3dd9b5a6d927cb3974d58467dfda03ce22289dc
# Summary for semanticscholar_d3dd9b5a6d927cb3974d58467dfda03ce22289dc: ...
# Processing 136/1074: semanticscholar_2721971f2e525e55c03dc6cd231deb65d9d06438
# Summary for semanticscholar_2721971f2e525e55c03dc6cd231deb65d9d06438: ...
# Processing 137/1074: semanticscholar_b2eb39cf9f99e49dc2ebe4f52ee8c3f8ada6dcfc
# Summary for semanticscholar_b2eb39cf9f99e49dc2ebe4f52ee8c3f8ada6dcfc: Text too short for summarization...
# Processing 138/1074: semanticscholar_e77a6fc69b4f30e3c28253dfa83e14b72bbc8597
# Summary for semanticscholar_e77a6fc69b4f30e3c28253dfa83e14b72bbc8597: Text too short or empty for summarization...
# Processing 139/1074: semanticscholar_7783d83cd68c99106d637537ba3291b0ff432b3b
# Summary for semanticscholar_7783d83cd68c99106d637537ba3291b0ff432b3b: ...
# Processing 140/1074: semanticscholar_df558a3daf22955fe42f4bbeb1415f6607b67567
# Summary for semanticscholar_df558a3daf22955fe42f4bbeb1415f6607b67567: ...
# Processing 141/1074: semanticscholar_673132dce3103851763663a42c28073a665a8b2d
# Summary for semanticscholar_673132dce3103851763663a42c28073a665a8b2d: ...
# Processing 142/1074: semanticscholar_b515eb7cade478e41280d724a846aa70037d85df
# Summary for semanticscholar_b515eb7cade478e41280d724a846aa70037d85df: Text too short or empty for summarization...
# Processing 143/1074: semanticscholar_44d4dd3163749490a92922536e8ea60615a6c9c6
# Summary for semanticscholar_44d4dd3163749490a92922536e8ea60615a6c9c6: ...
# Processing 144/1074: semanticscholar_b2e9c91a9c909977991438e508af9e5c00388aad
# Summary for semanticscholar_b2e9c91a9c909977991438e508af9e5c00388aad: ...
# Processing 145/1074: semanticscholar_0e64cdbac3b13b08d0836e00062caec71631e57a
# Summary for semanticscholar_0e64cdbac3b13b08d0836e00062caec71631e57a: Text too short or empty for summarization...
# Processing 146/1074: semanticscholar_136d4add842368a398e6549e4389a54354899eff
# Summary for semanticscholar_136d4add842368a398e6549e4389a54354899eff: ...
# Processing 147/1074: semanticscholar_20547a8aa2545921ea4515b17d8fc3b7780c234f
# Summary for semanticscholar_20547a8aa2545921ea4515b17d8fc3b7780c234f: Text too short or empty for summarization...
# Processing 148/1074: semanticscholar_3649c4cbde4f5d81de774b7fae366f19ad9fb3aa
# Summary for semanticscholar_3649c4cbde4f5d81de774b7fae366f19ad9fb3aa: ...
# Processing 149/1074: semanticscholar_38fe11166e85ae06d0af0aecdcb9a6a0e6275f74
# Summary for semanticscholar_38fe11166e85ae06d0af0aecdcb9a6a0e6275f74: Text too short or empty for summarization...
# Processing 150/1074: semanticscholar_395aad5ec8f591913253f531c979f56fc3029d2d
# Summary for semanticscholar_395aad5ec8f591913253f531c979f56fc3029d2d: ...
# Processing 151/1074: semanticscholar_ab4c13eb618057bf98b8f6c1e3e7120eefc43ddc
# Summary for semanticscholar_ab4c13eb618057bf98b8f6c1e3e7120eefc43ddc: Text too short or empty for summarization...
# Processing 152/1074: semanticscholar_bb678afa2685e6493f9875b66ac2b32dce5e7e9b
# Summary for semanticscholar_bb678afa2685e6493f9875b66ac2b32dce5e7e9b: ...
# Processing 153/1074: semanticscholar_ee86393e9889e3735f57c9adf5990d41f10c5d22
# Summary for semanticscholar_ee86393e9889e3735f57c9adf5990d41f10c5d22: ...
# Processing 154/1074: semanticscholar_f623cd030c74a8bb7c2aae2f8bcd1dd8325bef32
# Summary for semanticscholar_f623cd030c74a8bb7c2aae2f8bcd1dd8325bef32: ...
# Processing 155/1074: semanticscholar_bc561f967f300a14d61c35247a908318956a502b
# Summary for semanticscholar_bc561f967f300a14d61c35247a908318956a502b: ...
# Processing 156/1074: semanticscholar_33566ed3adfdbd7c950d1d02a113a5b78513cb36
# Summary for semanticscholar_33566ed3adfdbd7c950d1d02a113a5b78513cb36: ...
# Processing 157/1074: semanticscholar_6d85819e23c463b602830728751f4c292c77a9d4
# Summary for semanticscholar_6d85819e23c463b602830728751f4c292c77a9d4: ...
# Processing 158/1074: semanticscholar_2414e25d0a59be3b0cd3caa8db7b9328ef118c2d
# Summary for semanticscholar_2414e25d0a59be3b0cd3caa8db7b9328ef118c2d: Text too short for summarization...
# Processing 159/1074: semanticscholar_37556b31ac092d8872db064e9afc44b1cd2f47be
# Summary for semanticscholar_37556b31ac092d8872db064e9afc44b1cd2f47be: ...
# Processing 160/1074: semanticscholar_5c8073c7c908c65e41ec11bb6c43b4a80848178a
# Summary for semanticscholar_5c8073c7c908c65e41ec11bb6c43b4a80848178a: ...
# Processing 161/1074: semanticscholar_6b7af1b8442ec82ab63610448197f7c883385e6d
# Summary for semanticscholar_6b7af1b8442ec82ab63610448197f7c883385e6d: ...
# Processing 162/1074: semanticscholar_a49c9ac390039a1be7344b7c8f03a5fcd3d696f5
# Summary for semanticscholar_a49c9ac390039a1be7344b7c8f03a5fcd3d696f5: ...
# Processing 163/1074: semanticscholar_9929a068d29503413b93a0e26896e88c7ae1c29c
# Summary for semanticscholar_9929a068d29503413b93a0e26896e88c7ae1c29c: Text too short or empty for summarization...
# Processing 164/1074: semanticscholar_1f9ee8bc72bfcd31a23f6b592518af3e67e48597
# Summary for semanticscholar_1f9ee8bc72bfcd31a23f6b592518af3e67e48597: Text too short or empty for summarization...
# Processing 165/1074: semanticscholar_482967072c8f0751cb326cd22dba7d6fecc21d98
# Summary for semanticscholar_482967072c8f0751cb326cd22dba7d6fecc21d98: Text too short or empty for summarization...
# Processing 166/1074: semanticscholar_50301a231a41fe3dffd89b8a19f818c554a0a389
# Summary for semanticscholar_50301a231a41fe3dffd89b8a19f818c554a0a389: Text too short or empty for summarization...
# Processing 167/1074: semanticscholar_732e2d5f2ad782710ab08d89545906bc97579ef1
# Summary for semanticscholar_732e2d5f2ad782710ab08d89545906bc97579ef1: Text too short or empty for summarization...
# Processing 168/1074: semanticscholar_64cee874b4214f94e6db61b84f6097f97c1b1216
# Summary for semanticscholar_64cee874b4214f94e6db61b84f6097f97c1b1216: ...
# Processing 169/1074: semanticscholar_991f0e9a39455c2e7d90b6cd3ea8144acdda0cc6
# Summary for semanticscholar_991f0e9a39455c2e7d90b6cd3ea8144acdda0cc6: Text too short for summarization...
# Processing 170/1074: semanticscholar_4f67cc883f007614fbd42dd4948b466c265e2938
# Summary for semanticscholar_4f67cc883f007614fbd42dd4948b466c265e2938: ...
# Processing 171/1074: semanticscholar_7830588b35f5ba4a7e98df572c86790ee959e4ca
# Summary for semanticscholar_7830588b35f5ba4a7e98df572c86790ee959e4ca: Text too short or empty for summarization...
# Processing 172/1074: semanticscholar_e78d9a379ee348c6ce048056ac35a61d2eb32376
# Summary for semanticscholar_e78d9a379ee348c6ce048056ac35a61d2eb32376: ...
# Processing 173/1074: semanticscholar_3dc26a373298e2e7848823021a31a829eee5beb3
# Summary for semanticscholar_3dc26a373298e2e7848823021a31a829eee5beb3: Text too short or empty for summarization...
# Processing 174/1074: semanticscholar_fb5e621fd31a8f0d5116d4d2e2beb2d11b5a7361
# Summary for semanticscholar_fb5e621fd31a8f0d5116d4d2e2beb2d11b5a7361: ...
# Processing 175/1074: semanticscholar_340e1e09fe3c5b98ed2835360f9bb87dbfee3858
# Summary for semanticscholar_340e1e09fe3c5b98ed2835360f9bb87dbfee3858: Text too short or empty for summarization...
# Processing 176/1074: semanticscholar_8c7dbf117c22d3413fc7c91463fb20dc1fca78b7
# Summary for semanticscholar_8c7dbf117c22d3413fc7c91463fb20dc1fca78b7: Text too short or empty for summarization...
# Processing 177/1074: semanticscholar_1c4e74510b0257727f35c421f93a54e0727c1f0c
# Summary for semanticscholar_1c4e74510b0257727f35c421f93a54e0727c1f0c: ...
# Processing 178/1074: semanticscholar_3efe88c120819c08143ede15b9ccac04f3b00b36
# Summary for semanticscholar_3efe88c120819c08143ede15b9ccac04f3b00b36: the february 2018 edition of health affairs focuses on the critical issue of diffusion of innovation...
# Processing 179/1074: semanticscholar_36e40ddee4e6c5ffe82f70889176e0c28c3d8aed
# Summary for semanticscholar_36e40ddee4e6c5ffe82f70889176e0c28c3d8aed: Text too short or empty for summarization...
# Processing 180/1074: semanticscholar_caa0a90d8d746ecb4b1fb115767cfef5b6bae0b1
# Summary for semanticscholar_caa0a90d8d746ecb4b1fb115767cfef5b6bae0b1: Text too short or empty for summarization...
# Processing 181/1074: semanticscholar_9e0782de01c63712eddd9930fa73a7babe7452e5
# Summary for semanticscholar_9e0782de01c63712eddd9930fa73a7babe7452e5: just as in other modern industries the term innovation in healthcare has become associated with new ...
# Processing 182/1074: semanticscholar_18740741a4f5536c7e4b0efa7992a77299d87f1f
# Summary for semanticscholar_18740741a4f5536c7e4b0efa7992a77299d87f1f: Text too short or empty for summarization...
# Processing 183/1074: semanticscholar_e53b8666519da7a1d577c838159d301de5d8b90f
# Summary for semanticscholar_e53b8666519da7a1d577c838159d301de5d8b90f: Text too short or empty for summarization...
# Processing 184/1074: semanticscholar_02ea3610c071966159accc5c816c6c3ffa871aff
# Summary for semanticscholar_02ea3610c071966159accc5c816c6c3ffa871aff: Text too short or empty for summarization...
# Processing 185/1074: semanticscholar_e26ef616143f7bdde98ff7c23403ab42b4fb6901
# Summary for semanticscholar_e26ef616143f7bdde98ff7c23403ab42b4fb6901: Text too short or empty for summarization...
# Processing 186/1074: semanticscholar_4062c5c579b3f307e14977725ce20fac87527498
# Summary for semanticscholar_4062c5c579b3f307e14977725ce20fac87527498: ...
# Processing 187/1074: semanticscholar_66fa19493838d43074ef4eb46f9bc1ad7d17e423
# Summary for semanticscholar_66fa19493838d43074ef4eb46f9bc1ad7d17e423: ...
# Processing 188/1074: semanticscholar_a8594df3a3aaa6264fbf00030374e2542729f260
# Summary for semanticscholar_a8594df3a3aaa6264fbf00030374e2542729f260: Text too short or empty for summarization...
# Processing 189/1074: semanticscholar_eb6f3f02404976a0d9ee771e1330a7bede735897
# Summary for semanticscholar_eb6f3f02404976a0d9ee771e1330a7bede735897: Text too short for summarization...
# Processing 190/1074: semanticscholar_4893c9b1b0e99bf3be1f2ce533a4b4752ae1a6ff
# Summary for semanticscholar_4893c9b1b0e99bf3be1f2ce533a4b4752ae1a6ff: ...
# Processing 191/1074: semanticscholar_8cdba45b11698cef9fc96e1920d04d00bbefd9e1
# Summary for semanticscholar_8cdba45b11698cef9fc96e1920d04d00bbefd9e1: ...
# Processing 192/1074: semanticscholar_ecb555071b6d04c8266056bc10d23a314e176958
# Summary for semanticscholar_ecb555071b6d04c8266056bc10d23a314e176958: Text too short or empty for summarization...
# Processing 193/1074: semanticscholar_655bd8c11b2489426abe0ef6bb3384cb625aa57c
# Summary for semanticscholar_655bd8c11b2489426abe0ef6bb3384cb625aa57c: ...
# Processing 194/1074: semanticscholar_cd811e941c44c6a31959ccf0e8183801cbf4d291
# Summary for semanticscholar_cd811e941c44c6a31959ccf0e8183801cbf4d291: Text too short or empty for summarization...
# Processing 195/1074: semanticscholar_8a5da714d01365c55f344de0616b0e44536750a5
# Summary for semanticscholar_8a5da714d01365c55f344de0616b0e44536750a5: ...
# Processing 196/1074: semanticscholar_6d70b411ffbee540673951ae13afe987865bd2e4
# Summary for semanticscholar_6d70b411ffbee540673951ae13afe987865bd2e4: ...
# Processing 197/1074: semanticscholar_89fb44297ebaa1c6908479da86322909132be6ee
# Summary for semanticscholar_89fb44297ebaa1c6908479da86322909132be6ee: ...
# Processing 198/1074: semanticscholar_b3327e8c1571bb0e2e65ff41d9d9c7700991cf21
# Summary for semanticscholar_b3327e8c1571bb0e2e65ff41d9d9c7700991cf21: Text too short or empty for summarization...
# Processing 199/1074: semanticscholar_738ddd45d4e9a075ae93aa5528b63e81a6a09ae7
# Summary for semanticscholar_738ddd45d4e9a075ae93aa5528b63e81a6a09ae7: ...
# Processing 200/1074: semanticscholar_cc7392d0514c8c5e3e45e3fa9513596a58640623
# Summary for semanticscholar_cc7392d0514c8c5e3e45e3fa9513596a58640623: Text too short or empty for summarization...
# Processing 201/1074: semanticscholar_7ca78ae4dbe943b9b5d78c7dfcba7f88cd088343
# Summary for semanticscholar_7ca78ae4dbe943b9b5d78c7dfcba7f88cd088343: Text too short or empty for summarization...
# Processing 202/1074: semanticscholar_eb617ab7017997cc047bb81a29be5a378e00c02a
# Summary for semanticscholar_eb617ab7017997cc047bb81a29be5a378e00c02a: Text too short or empty for summarization...
# Processing 203/1074: semanticscholar_820923c859c110c03ff79639055af123ab8c7e6e
# Summary for semanticscholar_820923c859c110c03ff79639055af123ab8c7e6e: Text too short or empty for summarization...
# Processing 204/1074: semanticscholar_94c8c8b4125f2fc8b141e60ebb25213ff7427b70
# Summary for semanticscholar_94c8c8b4125f2fc8b141e60ebb25213ff7427b70: ...
# Processing 205/1074: semanticscholar_fdbd1350e14171eaebd82eb2b11ee9141b0963c2
# Summary for semanticscholar_fdbd1350e14171eaebd82eb2b11ee9141b0963c2: ...
# Processing 206/1074: semanticscholar_903e4648b47bb0acfb57c3ced9729499774b7b57
# Summary for semanticscholar_903e4648b47bb0acfb57c3ced9729499774b7b57: Text too short or empty for summarization...
# Processing 207/1074: semanticscholar_4814237990c2916ff783b6b77ea0b09ee701a4dd
# Summary for semanticscholar_4814237990c2916ff783b6b77ea0b09ee701a4dd: ...
# Processing 208/1074: semanticscholar_bfb6542da475c8fb5712dc85bc5b972f4f0bb589
# Summary for semanticscholar_bfb6542da475c8fb5712dc85bc5b972f4f0bb589: ...
# Processing 209/1074: semanticscholar_e9650176e09979926947c653b246328720c6d5f9
# Summary for semanticscholar_e9650176e09979926947c653b246328720c6d5f9: Text too short or empty for summarization...
# Processing 210/1074: semanticscholar_e05ba0020d6382b436c180d168fbfa289b616f4d
# Summary for semanticscholar_e05ba0020d6382b436c180d168fbfa289b616f4d: Text too short or empty for summarization...
# Processing 211/1074: semanticscholar_2e39846444e149098d141d9fb39c3eaf3928ed3e
# Summary for semanticscholar_2e39846444e149098d141d9fb39c3eaf3928ed3e: Text too short or empty for summarization...
# Processing 212/1074: semanticscholar_4a4a2ccc19d41e2642fe797b303b2f398e93a912
# Summary for semanticscholar_4a4a2ccc19d41e2642fe797b303b2f398e93a912: ...
# Processing 213/1074: semanticscholar_487ee0e58d699ae0aa7c64233c9633f3d084b973
# Summary for semanticscholar_487ee0e58d699ae0aa7c64233c9633f3d084b973: Text too short or empty for summarization...
# Processing 214/1074: semanticscholar_a1179741c1db18506b3c667d83fb31e4f5e13398
# Summary for semanticscholar_a1179741c1db18506b3c667d83fb31e4f5e13398: Text too short or empty for summarization...
# Processing 215/1074: semanticscholar_1e9a754e5b60161cd99f017fa6641ae1acee5b3e
# Summary for semanticscholar_1e9a754e5b60161cd99f017fa6641ae1acee5b3e: Text too short or empty for summarization...
# Processing 216/1074: semanticscholar_a1eb35cc4494e48dd587203366b49ba6ba3594ed
# Summary for semanticscholar_a1eb35cc4494e48dd587203366b49ba6ba3594ed: Text too short or empty for summarization...
# Processing 217/1074: semanticscholar_67eb1b19b5b5d3f8209c25b2e9611d74ba9457f6
# Summary for semanticscholar_67eb1b19b5b5d3f8209c25b2e9611d74ba9457f6: Text too short or empty for summarization...
# Processing 218/1074: semanticscholar_bfafc7589e98af46f164e8b9b73c899260070229
# Summary for semanticscholar_bfafc7589e98af46f164e8b9b73c899260070229: ...
# Processing 219/1074: semanticscholar_342ab99d9219bdccbcb307a4f933cb7e51e51c80
# Summary for semanticscholar_342ab99d9219bdccbcb307a4f933cb7e51e51c80: ...
# Processing 220/1074: semanticscholar_dd7b11fefab05d92923bde35c84305ab3b96fda8
# Summary for semanticscholar_dd7b11fefab05d92923bde35c84305ab3b96fda8: ...
# Processing 221/1074: semanticscholar_b20d75cc72fa529974a2a3c7a0d614c05a733fdc
# Summary for semanticscholar_b20d75cc72fa529974a2a3c7a0d614c05a733fdc: ...
# Processing 222/1074: semanticscholar_8ece9a6cdfd6ff1b25f92768fa0356a57c90df33
# Summary for semanticscholar_8ece9a6cdfd6ff1b25f92768fa0356a57c90df33: ...
# Processing 223/1074: semanticscholar_94149c8b50ae89978433d965aea937a2e0077d8c
# Summary for semanticscholar_94149c8b50ae89978433d965aea937a2e0077d8c: ...
# Processing 224/1074: semanticscholar_e21beac4201b565b8d881311c9c8cce7ad1362cb
# Summary for semanticscholar_e21beac4201b565b8d881311c9c8cce7ad1362cb: Text too short or empty for summarization...
# Processing 225/1074: semanticscholar_3ed0db58a7aec7bafc2aa14ca550031b9f7021d5
# Summary for semanticscholar_3ed0db58a7aec7bafc2aa14ca550031b9f7021d5: Text too short or empty for summarization...
# Processing 226/1074: semanticscholar_e45e5bc3e1bdad1c8fa49ebd9ab863ece9e785e6
# Summary for semanticscholar_e45e5bc3e1bdad1c8fa49ebd9ab863ece9e785e6: ...
# Processing 227/1074: semanticscholar_4f728e5d0fb5575a1c1547a338c53779be4dfaed
# Summary for semanticscholar_4f728e5d0fb5575a1c1547a338c53779be4dfaed: Text too short or empty for summarization...
# Processing 228/1074: semanticscholar_4aabb8a7c60060239ed236ed8b6fe5818c2e975d
# Summary for semanticscholar_4aabb8a7c60060239ed236ed8b6fe5818c2e975d: ...
# Processing 229/1074: semanticscholar_6bc897c05523c212a9630c1494ad2795ae610c18
# Summary for semanticscholar_6bc897c05523c212a9630c1494ad2795ae610c18: ...
# Processing 230/1074: semanticscholar_45cf2fea37858d0fa446a954e0bedd24ed3de9c5
# Summary for semanticscholar_45cf2fea37858d0fa446a954e0bedd24ed3de9c5: ...
# Processing 231/1074: semanticscholar_582ad10b10b13e9e97b2e8bac314cccbac9c60a0
# Summary for semanticscholar_582ad10b10b13e9e97b2e8bac314cccbac9c60a0: Text too short or empty for summarization...
# Processing 232/1074: semanticscholar_98ee255b86dea6a71c9e65d512f7476d263439fe
# Summary for semanticscholar_98ee255b86dea6a71c9e65d512f7476d263439fe: ...
# Processing 233/1074: semanticscholar_bce43a15423c7b1b049cfec2d923cb2352f646df
# Summary for semanticscholar_bce43a15423c7b1b049cfec2d923cb2352f646df: ...
# Processing 234/1074: semanticscholar_a0c82ecc13ec21a9bd339dd36a0b6a80cb6f521f
# Summary for semanticscholar_a0c82ecc13ec21a9bd339dd36a0b6a80cb6f521f: Text too short or empty for summarization...
# Processing 235/1074: semanticscholar_4e164481df2f4317ad2552daf0be01b4c2af5531
# Summary for semanticscholar_4e164481df2f4317ad2552daf0be01b4c2af5531: Text too short or empty for summarization...
# Processing 236/1074: semanticscholar_0507d09681b05fe3db73b1df241f8055559c3d4e
# Summary for semanticscholar_0507d09681b05fe3db73b1df241f8055559c3d4e: ...
# Processing 237/1074: semanticscholar_6380518596352a0be5e9612812a15e1d366212bf
# Summary for semanticscholar_6380518596352a0be5e9612812a15e1d366212bf: ...
# Processing 238/1074: semanticscholar_e565bc2ca7767eb7d5c2282a03946d27c6b12294
# Summary for semanticscholar_e565bc2ca7767eb7d5c2282a03946d27c6b12294: ...
# Processing 239/1074: semanticscholar_6aeeb865aca80aa30bb2ee6ba0e42d41c6220645
# Summary for semanticscholar_6aeeb865aca80aa30bb2ee6ba0e42d41c6220645: Text too short or empty for summarization...
# Processing 240/1074: semanticscholar_fdc5179a0068e8b84424de26bf355cedad249422
# Summary for semanticscholar_fdc5179a0068e8b84424de26bf355cedad249422: ...
# Processing 241/1074: semanticscholar_a5fb2790be9ea6326b8bb21795b8344faafb475f
# Summary for semanticscholar_a5fb2790be9ea6326b8bb21795b8344faafb475f: ...
# Processing 242/1074: semanticscholar_9f0cb0e4dce2daf3a4fb624b4d6e89d9a4280b74
# Summary for semanticscholar_9f0cb0e4dce2daf3a4fb624b4d6e89d9a4280b74: ...
# Processing 243/1074: semanticscholar_1ca10199c89785895f204c4be81cf2316167c24f
# Summary for semanticscholar_1ca10199c89785895f204c4be81cf2316167c24f: ...
# Processing 244/1074: semanticscholar_8fd934cee2a571952aeb90db0e752cf446d273eb
# Summary for semanticscholar_8fd934cee2a571952aeb90db0e752cf446d273eb: ...
# Processing 245/1074: semanticscholar_c99577b334c2d151cac086b4b5a590c4678dbeb4
# Summary for semanticscholar_c99577b334c2d151cac086b4b5a590c4678dbeb4: ...
# Processing 246/1074: semanticscholar_6d819f14cfb95df86ceccf53cec8cc7794bd6f9c
# Summary for semanticscholar_6d819f14cfb95df86ceccf53cec8cc7794bd6f9c: Text too short or empty for summarization...
# Processing 247/1074: semanticscholar_0326932f09a540ecc63e42072af608a59db6e602
# Summary for semanticscholar_0326932f09a540ecc63e42072af608a59db6e602: ...
# Processing 248/1074: semanticscholar_38ac6ad1e3b9646f03b6d99f50ee312f2df5dd3c
# Summary for semanticscholar_38ac6ad1e3b9646f03b6d99f50ee312f2df5dd3c: Text too short or empty for summarization...
# Processing 249/1074: semanticscholar_fd953a36992e3f2e0806bcbe280e05f26f4a710f
# Summary for semanticscholar_fd953a36992e3f2e0806bcbe280e05f26f4a710f: ...
# Processing 250/1074: semanticscholar_25f4b12a94ffc40593087ad3b3824ff29831be57
# Summary for semanticscholar_25f4b12a94ffc40593087ad3b3824ff29831be57: ...
# Processing 251/1074: semanticscholar_eb4a4d50610c19767936a4bd6fcd740509a4314a
# Summary for semanticscholar_eb4a4d50610c19767936a4bd6fcd740509a4314a: ...
# Processing 252/1074: semanticscholar_368763addecc9cc62e87c2dcd71f10ad171c4a7b
# Summary for semanticscholar_368763addecc9cc62e87c2dcd71f10ad171c4a7b: Text too short for summarization...
# Processing 253/1074: semanticscholar_c3e4eefcaac995833a258634292b22b5960287a8
# Summary for semanticscholar_c3e4eefcaac995833a258634292b22b5960287a8: ...
# Processing 254/1074: semanticscholar_a9d52b468187afb7bbae35b576d2e08c85717b35
# Summary for semanticscholar_a9d52b468187afb7bbae35b576d2e08c85717b35: ...
# Processing 255/1074: semanticscholar_2ebb87d3ec1b0f949ca836c65bc9c2ccfb7db98c
# Summary for semanticscholar_2ebb87d3ec1b0f949ca836c65bc9c2ccfb7db98c: Text too short for summarization...
# Processing 256/1074: semanticscholar_98642f121bfaf3bb6deb045516650528db04ecc4
# Summary for semanticscholar_98642f121bfaf3bb6deb045516650528db04ecc4: ...
# Processing 257/1074: semanticscholar_03667c5cb3b2e685743d0c76c394e218fbc32d4e
# Summary for semanticscholar_03667c5cb3b2e685743d0c76c394e218fbc32d4e: ...
# Processing 258/1074: semanticscholar_bdc5c520b3eeeaee80198e482ed8070427a322c2
# Summary for semanticscholar_bdc5c520b3eeeaee80198e482ed8070427a322c2: ...
# Processing 259/1074: semanticscholar_0b6252259cf78d0e2e24c3faf3da248b6d37226c
# Summary for semanticscholar_0b6252259cf78d0e2e24c3faf3da248b6d37226c: Text too short or empty for summarization...
# Processing 260/1074: semanticscholar_eb6a68ed1250fa6cb3318b2f6c0b887ef85fb047
# Summary for semanticscholar_eb6a68ed1250fa6cb3318b2f6c0b887ef85fb047: ...
# Processing 261/1074: semanticscholar_e84d39ab8491deb640aa87dbde33961f86be5e34
# Summary for semanticscholar_e84d39ab8491deb640aa87dbde33961f86be5e34: Text too short or empty for summarization...
# Processing 262/1074: semanticscholar_1b38202e9243878aaa2cd82172bd12ecaf6c2adb
# Summary for semanticscholar_1b38202e9243878aaa2cd82172bd12ecaf6c2adb: Text too short or empty for summarization...
# Processing 263/1074: semanticscholar_515e4277a268ff7fd83ddfd355503bf9c9e5ede7
# Summary for semanticscholar_515e4277a268ff7fd83ddfd355503bf9c9e5ede7: ...
# Processing 264/1074: semanticscholar_da422f6e82cab7ced4f6cbfe4a7383f15437c844
# Summary for semanticscholar_da422f6e82cab7ced4f6cbfe4a7383f15437c844: ...
# Processing 265/1074: semanticscholar_92a13c9b3b4a34ccafc485aaa255ae43edf3c655
# Summary for semanticscholar_92a13c9b3b4a34ccafc485aaa255ae43edf3c655: ...
# Processing 266/1074: semanticscholar_3df8dce8bbdb9dea5f6ade66e95880f50c300cf4
# Summary for semanticscholar_3df8dce8bbdb9dea5f6ade66e95880f50c300cf4: ...
# Processing 267/1074: semanticscholar_78ce793c5b1ab80450780d2ba92e3931d13bc026
# Summary for semanticscholar_78ce793c5b1ab80450780d2ba92e3931d13bc026: blockchain technology though originally designed for keeping financial ledgers recently has found ap...
# Processing 268/1074: semanticscholar_d8b4ae975076aec4a826d65850fe8741b525bb7d
# Summary for semanticscholar_d8b4ae975076aec4a826d65850fe8741b525bb7d: ...
# Processing 269/1074: semanticscholar_325bd5eb738f847e5016fe536a41ac310e78f1f4
# Summary for semanticscholar_325bd5eb738f847e5016fe536a41ac310e78f1f4: Text too short or empty for summarization...
# Processing 270/1074: semanticscholar_4848a787aee70448214c00c1d4b551227969b94f
# Summary for semanticscholar_4848a787aee70448214c00c1d4b551227969b94f: ...
# Processing 271/1074: semanticscholar_c392b4533659ae039c7c761b3764d8f3b55f43a2
# Summary for semanticscholar_c392b4533659ae039c7c761b3764d8f3b55f43a2: ...
# Processing 272/1074: semanticscholar_fca789e057ca0c6ed3c1a4bf19be80c261003e16
# Summary for semanticscholar_fca789e057ca0c6ed3c1a4bf19be80c261003e16: ...
# Processing 273/1074: semanticscholar_3d9116fb4a75e2ab8c47a94ecb40a23a707324a6
# Summary for semanticscholar_3d9116fb4a75e2ab8c47a94ecb40a23a707324a6: ...
# Processing 274/1074: semanticscholar_bceb59a6c696990cb7ece1646062adbad2e6189b
# Summary for semanticscholar_bceb59a6c696990cb7ece1646062adbad2e6189b: Text too short or empty for summarization...
# Processing 275/1074: semanticscholar_e19cbab9fb23d5170e65bda39926dd5da2d1c138
# Summary for semanticscholar_e19cbab9fb23d5170e65bda39926dd5da2d1c138: ...
# Processing 276/1074: semanticscholar_fcb9cfc2275787d6e9c78022284520b7e18bd895
# Summary for semanticscholar_fcb9cfc2275787d6e9c78022284520b7e18bd895: ...
# Processing 277/1074: semanticscholar_4a14a851c1c393b83c317d1bc85b95e77092c38d
# Summary for semanticscholar_4a14a851c1c393b83c317d1bc85b95e77092c38d: ...
# Processing 278/1074: semanticscholar_6c54dce835c732948d3a877722ab23948a2b7562
# Summary for semanticscholar_6c54dce835c732948d3a877722ab23948a2b7562: Text too short or empty for summarization...
# Processing 279/1074: semanticscholar_12b413befc9ded4d72b84ebcdee06ba28cf7b90f
# Summary for semanticscholar_12b413befc9ded4d72b84ebcdee06ba28cf7b90f: ...
# Processing 280/1074: semanticscholar_45e01e301877e8d50485ad925958216073aaa0e3
# Summary for semanticscholar_45e01e301877e8d50485ad925958216073aaa0e3: Text too short or empty for summarization...
# Processing 281/1074: semanticscholar_b1b9d899f27733f1270c9809721b8865bbf66400
# Summary for semanticscholar_b1b9d899f27733f1270c9809721b8865bbf66400: ...
# Processing 282/1074: semanticscholar_09c2ac984b26fcb7949454d2dda6c45800b79a05
# Summary for semanticscholar_09c2ac984b26fcb7949454d2dda6c45800b79a05: ...
# Processing 283/1074: semanticscholar_8c04cc9854b363629f7ee673515985627702d879
# Summary for semanticscholar_8c04cc9854b363629f7ee673515985627702d879: ...
# Processing 284/1074: semanticscholar_b0c5410bf7ecc6f81fbdaab660a897f6a2eba944
# Summary for semanticscholar_b0c5410bf7ecc6f81fbdaab660a897f6a2eba944: ...
# Processing 285/1074: semanticscholar_82690746cdc142e9b3a72757513819a15c733eca
# Summary for semanticscholar_82690746cdc142e9b3a72757513819a15c733eca: ...
# Processing 286/1074: semanticscholar_fac9053637e7f490d6bd4edee24a90f58865e16b
# Summary for semanticscholar_fac9053637e7f490d6bd4edee24a90f58865e16b: ...
# Processing 287/1074: semanticscholar_3e7dabbea88d45d961b9c6b1de98ba5325a45317
# Summary for semanticscholar_3e7dabbea88d45d961b9c6b1de98ba5325a45317: Text too short or empty for summarization...
# Processing 288/1074: semanticscholar_6c7da9c38e60774ece709110ba50f4f6adb607d2
# Summary for semanticscholar_6c7da9c38e60774ece709110ba50f4f6adb607d2: Text too short or empty for summarization...
# Processing 289/1074: semanticscholar_30b8fcd5c72f495f092af2c3f7303f657ad80996
# Summary for semanticscholar_30b8fcd5c72f495f092af2c3f7303f657ad80996: ...
# Processing 290/1074: semanticscholar_3cffb8ff68c168702f0bfb4b49021aacf2d47ac4
# Summary for semanticscholar_3cffb8ff68c168702f0bfb4b49021aacf2d47ac4: ...
# Processing 291/1074: semanticscholar_8ddc50257cc90d675a7ef967362a078227f798a7
# Summary for semanticscholar_8ddc50257cc90d675a7ef967362a078227f798a7: Text too short or empty for summarization...
# Processing 292/1074: semanticscholar_022bb5ff6e1dce8eeeb6833c859450a391ba43ea
# Summary for semanticscholar_022bb5ff6e1dce8eeeb6833c859450a391ba43ea: Text too short or empty for summarization...
# Processing 293/1074: semanticscholar_3d2b95682e4167f62878c88cb9265f9267de0465
# Summary for semanticscholar_3d2b95682e4167f62878c88cb9265f9267de0465: ...
# Processing 294/1074: semanticscholar_2f794410c588d38dc9c9ed1791e7013f2813fa0b
# Summary for semanticscholar_2f794410c588d38dc9c9ed1791e7013f2813fa0b: ...
# Processing 295/1074: semanticscholar_f7fd93b25217d27868d203f882377c3d0d1fe6e9
# Summary for semanticscholar_f7fd93b25217d27868d203f882377c3d0d1fe6e9: Text too short or empty for summarization...
# Processing 296/1074: semanticscholar_64228bc0cdff11df5d1a2b314bd5ab04f0959736
# Summary for semanticscholar_64228bc0cdff11df5d1a2b314bd5ab04f0959736: ...
# ...
# Summary for semanticscholar_470bf0917061f3a0e8d0e0e43651e1636a4824ff: ...
# Processing 971/1074: semanticscholar_78a0ba7ed264be130bace995ddc5c45c1df9a797
# Summary for semanticscholar_78a0ba7ed264be130bace995ddc5c45c1df9a797: ...
# Processing 972/1074: semanticscholar_189e4fdc794255d4f225af9439491489a3104585
# Summary for semanticscholar_189e4fdc794255d4f225af9439491489a3104585: ...
# Processing 973/1074: semanticscholar_8da647ea43c75e018f4ff0c684787a8eeeac8e79
# Summary for semanticscholar_8da647ea43c75e018f4ff0c684787a8eeeac8e79: ...
# Processing 974/1074: semanticscholar_f1ed3285cb4b1e0537193e8d94cb535878b1e7ec
# Summary for semanticscholar_f1ed3285cb4b1e0537193e8d94cb535878b1e7ec: ...
# Processing 975/1074: semanticscholar_059df6faeecafff28bc57496b1a6cecbb758e5fb
# Summary for semanticscholar_059df6faeecafff28bc57496b1a6cecbb758e5fb: by combining innovative prevention and treatment strategies in a sustainable stateoftheart virtual e...
# Processing 976/1074: semanticscholar_4fa84bbe5520892397027bcdcd385648d93c94a7
# Summary for semanticscholar_4fa84bbe5520892397027bcdcd385648d93c94a7: Text too short or empty for summarization...
# Processing 977/1074: semanticscholar_4ebe725e19f4bff7de199b5017e2b9e31d29442e
# Summary for semanticscholar_4ebe725e19f4bff7de199b5017e2b9e31d29442e: ...
# Processing 978/1074: semanticscholar_cd91d5c48763aee41f32e43ee29809cac55e6b16
# Summary for semanticscholar_cd91d5c48763aee41f32e43ee29809cac55e6b16: ...
# Processing 979/1074: semanticscholar_a86ecb673473f1d117e34afc5517399f31dc252b
# Summary for semanticscholar_a86ecb673473f1d117e34afc5517399f31dc252b: ...
# Processing 980/1074: semanticscholar_1b429d66f91a485dde5bb254b2fba3e9689e8cb7
# Summary for semanticscholar_1b429d66f91a485dde5bb254b2fba3e9689e8cb7: ...
# Processing 981/1074: semanticscholar_6f50537e70885fa4b94c5725c559d76d7bd01b53
# Summary for semanticscholar_6f50537e70885fa4b94c5725c559d76d7bd01b53: Text too short or empty for summarization...
# Processing 982/1074: semanticscholar_24cac144020ce74b36f340db66b74189a30b5197
# Summary for semanticscholar_24cac144020ce74b36f340db66b74189a30b5197: Text too short or empty for summarization...
# Processing 983/1074: semanticscholar_ee0e65c3e8185426d8ef14fec05113b156860406
# Summary for semanticscholar_ee0e65c3e8185426d8ef14fec05113b156860406: Text too short or empty for summarization...
# Processing 984/1074: semanticscholar_7f46c756798ddb41b3d953237f8f4540b7462231
# Summary for semanticscholar_7f46c756798ddb41b3d953237f8f4540b7462231: ...
# Processing 985/1074: semanticscholar_39ac1eb83b6b122ce7041737c3c98b4a0f0ab3f2
# Summary for semanticscholar_39ac1eb83b6b122ce7041737c3c98b4a0f0ab3f2: Text too short or empty for summarization...
# Processing 986/1074: semanticscholar_62bb80bae84fbbb4361161c8eb9e09cfd86ff92c
# Summary for semanticscholar_62bb80bae84fbbb4361161c8eb9e09cfd86ff92c: ...
# Processing 987/1074: semanticscholar_ae6379876801587396489e997b9847c5d361a4e9
# Summary for semanticscholar_ae6379876801587396489e997b9847c5d361a4e9: ...
# Processing 988/1074: semanticscholar_04f653cce37d724283ea0c9f0dadac918375faf5
# Summary for semanticscholar_04f653cce37d724283ea0c9f0dadac918375faf5: Text too short or empty for summarization...
# Processing 989/1074: semanticscholar_58e9fc59a0e44b82467ca71d67fe13d458320a70
# Summary for semanticscholar_58e9fc59a0e44b82467ca71d67fe13d458320a70: Text too short or empty for summarization...
# Processing 990/1074: semanticscholar_7a6d8b6d299cf3df3ea5580fb798150288e12fb2
# Summary for semanticscholar_7a6d8b6d299cf3df3ea5580fb798150288e12fb2: Text too short or empty for summarization...
# Processing 991/1074: semanticscholar_e17517aa939d0b8c3165f7ca9b90b453af6c536b
# Summary for semanticscholar_e17517aa939d0b8c3165f7ca9b90b453af6c536b: ...
# Processing 992/1074: semanticscholar_ec432a810018418492823ad1c2b18bc6e8a0ccaf
# Summary for semanticscholar_ec432a810018418492823ad1c2b18bc6e8a0ccaf: ...
# Processing 993/1074: semanticscholar_bf405db53dde57e3614b59c76333525139920eef
# Summary for semanticscholar_bf405db53dde57e3614b59c76333525139920eef: ...
# Processing 994/1074: semanticscholar_a9b9f4c6aaab6203272c4d444af9cc6abc1a0357
# Summary for semanticscholar_a9b9f4c6aaab6203272c4d444af9cc6abc1a0357: ...
# Processing 995/1074: semanticscholar_d32d4706cab85d3aa71334e3d5a9f67c7218476a
# Summary for semanticscholar_d32d4706cab85d3aa71334e3d5a9f67c7218476a: ...
# Processing 996/1074: semanticscholar_3fffdd24946f9037d760b0bf1572aa79302cc8b5
# Summary for semanticscholar_3fffdd24946f9037d760b0bf1572aa79302cc8b5: ...
# Processing 997/1074: semanticscholar_ff19c7e65bd10d6ca10056224937c182f1b83f41
# Summary for semanticscholar_ff19c7e65bd10d6ca10056224937c182f1b83f41: ...
# Processing 998/1074: semanticscholar_29d481a308a9b46024ee894b81efed16842313fd
# Summary for semanticscholar_29d481a308a9b46024ee894b81efed16842313fd: ...
# Processing 999/1074: semanticscholar_e43dbff309b9f5b4f6f8e612ad116995c45b50ee
# Summary for semanticscholar_e43dbff309b9f5b4f6f8e612ad116995c45b50ee: ...
# Processing 1000/1074: semanticscholar_98df2f3a0f8503f2a0a5bf293943b730df7784ad
# Summary for semanticscholar_98df2f3a0f8503f2a0a5bf293943b730df7784ad: ...
# Processing 1001/1074: semanticscholar_db6f5739b58d583822bd27673374c77589f84639
# Summary for semanticscholar_db6f5739b58d583822bd27673374c77589f84639: Text too short or empty for summarization...
# Processing 1002/1074: semanticscholar_3a44cd1a95ac870f1d1240bcea411614a994ecb2
# Summary for semanticscholar_3a44cd1a95ac870f1d1240bcea411614a994ecb2: Text too short or empty for summarization...
# Processing 1003/1074: semanticscholar_b39d22c9ae2ff8b3c0e10dd76d2202fbb44af1a5
# Summary for semanticscholar_b39d22c9ae2ff8b3c0e10dd76d2202fbb44af1a5: Text too short or empty for summarization...
# Processing 1004/1074: semanticscholar_000be55058af78361fed5c892d7097094c095627
# Summary for semanticscholar_000be55058af78361fed5c892d7097094c095627: ...
# Processing 1005/1074: semanticscholar_b4962de49135289486ee6318728e0339f03bbfc5
# Summary for semanticscholar_b4962de49135289486ee6318728e0339f03bbfc5: ...
# Processing 1006/1074: semanticscholar_ae6e49ca249ff7d71d403a35bb4ec2130399e8e6
# Summary for semanticscholar_ae6e49ca249ff7d71d403a35bb4ec2130399e8e6: Text too short or empty for summarization...
# Processing 1007/1074: semanticscholar_d1f6cf910fdd101daecdfa7afbd4776183a0e90b
# Summary for semanticscholar_d1f6cf910fdd101daecdfa7afbd4776183a0e90b: ...
# Processing 1008/1074: semanticscholar_ef8bb89319e87f07452c69a8bb506bc1decc4601
# Summary for semanticscholar_ef8bb89319e87f07452c69a8bb506bc1decc4601: ...
# Processing 1009/1074: semanticscholar_00483e16fe63c8810d9d537a61a199f820ceb150
# Summary for semanticscholar_00483e16fe63c8810d9d537a61a199f820ceb150: content emphasizes complementary traditional and holistic nursing and healthcare practices articles ...
# Processing 1010/1074: semanticscholar_1c6e4668d3de70456cc74a8a970a535d906863da
# Summary for semanticscholar_1c6e4668d3de70456cc74a8a970a535d906863da: ...
# Processing 1011/1074: semanticscholar_840d4292fff33b264eecf625fe9a20df6a57210f
# Summary for semanticscholar_840d4292fff33b264eecf625fe9a20df6a57210f: Text too short or empty for summarization...
# Processing 1012/1074: semanticscholar_d9110ef8346a5b6305c1615dccfb2bf9708540ee
# Summary for semanticscholar_d9110ef8346a5b6305c1615dccfb2bf9708540ee: ...
# Processing 1013/1074: semanticscholar_a95b4aba69d826259b5a5f610b26873c42e5d379
# Summary for semanticscholar_a95b4aba69d826259b5a5f610b26873c42e5d379: Text too short or empty for summarization...
# Processing 1014/1074: semanticscholar_14eab58732629323cc3a11db20d213b046c17f2a
# Summary for semanticscholar_14eab58732629323cc3a11db20d213b046c17f2a: ...
# Processing 1015/1074: semanticscholar_306bf18723c7d622cc8a19e48ba3e02f346688e6
# Summary for semanticscholar_306bf18723c7d622cc8a19e48ba3e02f346688e6: ...
# Processing 1016/1074: semanticscholar_65c5fc422e84578d473f9fa99a89d121152581cc
# Summary for semanticscholar_65c5fc422e84578d473f9fa99a89d121152581cc: Text too short or empty for summarization...
# Processing 1017/1074: semanticscholar_53e0a1eebbebaa2070fdb9c8fa10f7faa6eb06b1
# Summary for semanticscholar_53e0a1eebbebaa2070fdb9c8fa10f7faa6eb06b1: in recent years technical innovations have combined to make artificial limbs much more comfortable e...
# Processing 1018/1074: semanticscholar_32f7cfa6ace910dce170775d40e8783bb6fcc890
# Summary for semanticscholar_32f7cfa6ace910dce170775d40e8783bb6fcc890: ...
# Processing 1019/1074: semanticscholar_1af75cbcbd51481fdd1b8d5b54731cf11e4d6e45
# Summary for semanticscholar_1af75cbcbd51481fdd1b8d5b54731cf11e4d6e45: Text too short or empty for summarization...
# Processing 1020/1074: semanticscholar_678981be4af3e05fb8e3b85772eef0f2eeb68913
# Summary for semanticscholar_678981be4af3e05fb8e3b85772eef0f2eeb68913: Text too short or empty for summarization...
# Processing 1021/1074: semanticscholar_378c272be3c828119ab29c96c26f84ced0eb19c2
# Summary for semanticscholar_378c272be3c828119ab29c96c26f84ced0eb19c2: Text too short or empty for summarization...
# Processing 1022/1074: 07-1411.pdf
# Summary for 07-1411.pdf: ...
# Processing 1023/1074: Longest-2287_Chap1-e8ed4666.pdf
# Summary for Longest-2287_Chap1-e8ed4666.pdf: ...
# Processing 1024/1074: POST-PN-0545.pdf
# Summary for POST-PN-0545.pdf: ...
# Processing 1025/1074: Medical Waste Treatment and Disposal Methods Used by Hospitals in Oregon  Washington  and Idaho.pdf
# Summary for Medical Waste Treatment and Disposal Methods Used by Hospitals in Oregon  Washington  and Idaho.pdf: ...
# Processing 1026/1074: SOP-for-Quality-Improvement.pdf
# Summary for SOP-for-Quality-Improvement.pdf: ...
# Processing 1027/1074: 9789240094703-eng.pdf
# Summary for 9789240094703-eng.pdf: ...
# Processing 1028/1074: booth-et-al-2000-waging-war-on-modern-chronic-diseases-primary-prevention-through-exercise-biology.pdf
# Summary for booth-et-al-2000-waging-war-on-modern-chronic-diseases-primary-prevention-through-exercise-biology.pdf: ...
# Processing 1029/1074: djph-958g8g8u-003.pdf
# Summary for djph-958g8g8u-003.pdf: ...
# Processing 1030/1074: Hospital2029%202019_v2.0.pdf
# Summary for Hospital2029%202019_v2.0.pdf: ...
# Processing 1031/1074: the-global-strategy-of-the-us-department-of-health-and-human-services.pdf
# Summary for the-global-strategy-of-the-us-department-of-health-and-human-services.pdf: ...
# Processing 1032/1074: 38089-doc-faq_corona_virus.pdf
# Summary for 38089-doc-faq_corona_virus.pdf: ...
# Processing 1033/1074: hus17.pdf
# Summary for hus17.pdf: ...
# Processing 1034/1074: GBD_2017_Booklet.pdf
# Summary for GBD_2017_Booklet.pdf: ...
# Processing 1035/1074: p26.pdf
# Summary for p26.pdf: ...
# Processing 1036/1074: World-Heart-Report-2023.pdf
# Summary for World-Heart-Report-2023.pdf: ...
# Processing 1037/1074: 364010PAPER0Gl101OFFICIAL0USE0ONLY1.pdf
# Summary for 364010PAPER0Gl101OFFICIAL0USE0ONLY1.pdf: ...
# Processing 1038/1074: NRU_D1_Nauru STGs 2014 final.pdf
# Summary for NRU_D1_Nauru STGs 2014 final.pdf: ...
# Processing 1039/1074: PatientFocusedInterventions_ReviewOfTheEvidence.pdf
# Summary for PatientFocusedInterventions_ReviewOfTheEvidence.pdf: ...
# Processing 1040/1074: AnatolJCardiol_1_3_166_178.pdf
# Summary for AnatolJCardiol_1_3_166_178.pdf: ...
# Processing 1041/1074: guideline-170-en.pdf
# Summary for guideline-170-en.pdf: ...
# Processing 1042/1074: health-policy-101-congress-and-the-executive-branch-and-health-policy.pdf
# Summary for health-policy-101-congress-and-the-executive-branch-and-health-policy.pdf: ...
# Processing 1043/1074: Health-Policies-for-the-21st-Century-Challenges-and-Recommendations-for-the-U.S.-Department-of-Health-and-Human-Services.pdf
# Summary for Health-Policies-for-the-21st-Century-Challenges-and-Recommendations-for-the-U.S.-Department-of-Health-and-Human-Services.pdf: ...
# Processing 1044/1074: ken_D1_clinical guidelines for management and referral of common conditions.pdf
# Summary for ken_D1_clinical guidelines for management and referral of common conditions.pdf: ...
# Processing 1045/1074: download.pdf
# Summary for download.pdf: ...
# Processing 1046/1074: bf8b571d87b4ac4c34362a5a4ab8e147.pdf
# Summary for bf8b571d87b4ac4c34362a5a4ab8e147.pdf: ...
# Processing 1047/1074: introduction-to-public-health.pdf
# Summary for introduction-to-public-health.pdf: ...
# Processing 1048/1074: trends-analysis-guidance-jan23.pdf
# Summary for trends-analysis-guidance-jan23.pdf: ...
# Processing 1049/1074: fcimb-2-1514207.pdf
# Summary for fcimb-2-1514207.pdf: ...
# Processing 1050/1074: SJMPS_74_179-184.pdf
# Summary for SJMPS_74_179-184.pdf: ...
# Processing 1051/1074: 3010201401.pdf
# Summary for 3010201401.pdf: ...
# Processing 1052/1074: update-28-covid-19-what-we-know.pdf
# Summary for update-28-covid-19-what-we-know.pdf: ...
# Processing 1053/1074: Treatment of Hospital.pdf
# Summary for Treatment of Hospital.pdf: ...
# Processing 1054/1074: 0965546608_eng.pdf
# Summary for 0965546608_eng.pdf: ...
# Processing 1055/1074: health-policy-101-the-u-s-government-and-global-health.pdf
# Summary for health-policy-101-the-u-s-government-and-global-health.pdf: ...
# Processing 1056/1074: shm_painmanagement_guide.pdf
# Summary for shm_painmanagement_guide.pdf: ...
# Processing 1057/1074: djph-95-003.pdf
# Summary for djph-95-003.pdf: ...
# Processing 1058/1074: download (1).pdf
# Summary for download (1).pdf: ...
# Processing 1059/1074: 9789275122655_eng.pdf
# Summary for 9789275122655_eng.pdf: ...
# Processing 1060/1074: GBD_2021_Booklet_FINAL_2024.05.16.pdf
# Summary for GBD_2021_Booklet_FINAL_2024.05.16.pdf: ...
# Processing 1061/1074: PIIS1201971203000109.pdf
# Summary for PIIS1201971203000109.pdf: ...
# Processing 1062/1074: 1870_Oration_PDF.pdf
# Summary for 1870_Oration_PDF.pdf: ...
# Processing 1063/1074: 274.full.pdf
# Summary for 274.full.pdf: ...
# Processing 1064/1074: Shi_Chapter1_2-e629562b.pdf
# Summary for Shi_Chapter1_2-e629562b.pdf: ...
# Processing 1065/1074: IJHSR21.pdf
# Summary for IJHSR21.pdf: ...
# Processing 1066/1074: e034299.full.pdf
# Summary for e034299.full.pdf: ...
# Processing 1067/1074: 67tgt7i.pdf
# Summary for 67tgt7i.pdf: ...
# Processing 1068/1074: dp13625.pdf
# Summary for dp13625.pdf: ...
# Processing 1069/1074: s12992-022-00835-3.pdf
# Summary for s12992-022-00835-3.pdf: ...
# Processing 1070/1074: hus20-21.pdf
# Summary for hus20-21.pdf: ...
# Processing 1071/1074: Changing levels and trends in mortality.pdf
# Summary for Changing levels and trends in mortality.pdf: ...
# Processing 1072/1074: who-rights-roles-respon-hw-covid-19.pdf
# Summary for who-rights-roles-respon-hw-covid-19.pdf: ...
# Processing 1073/1074: STG-Primary-Hospital..pdf
# Summary for STG-Primary-Hospital..pdf: ...
# Processing 1074/1074: Overview.pdf
# Summary for Overview.pdf: ...
# Summarization complete. All summaries stored in the database.
#
# Sample summaries from database:
# Filename: pubmed_40327459
# Title: Psychological function in a randomized trial of continuous nitroglycerin for menopausal hot flashes.
# Summary:
# --------------------------------------------------
# Filename: pubmed_40327390
# Title: Nursing Care Management and Glycemic Control Among Children With Diabetes Enrolled in Medicaid.
# Summary:
# --------------------------------------------------
# Filename: pubmed_40327384
# Title: Enhancing Adherence to Continuous Positive Airway Pressure Therapy in Patients With Obstructive Sleep Apnea Using Augmented Reality: Protocol for a Randomized Controlled Trial.
# Summary:
# --------------------------------------------------
# Filename: pubmed_40327329
# Title: AI on the Front Lines: A Primer for the Military Health Professional.
# Summary:
# --------------------------------------------------
# Filename: pubmed_40327286
# 27918725
# 33766750
# 17537614
# 20668052
# 33754023
# 19641587
# 35210368
# 17384583
# 9446642
# 32392088
# 34753510
# 35134463
# 33045622
# 24382354
# 21440622
# 23474486
# 35273493
# 30053525
# 38574433
# 37154056
# 26232232
# 33314649
# 32468629
# 11709088
# 37425037
# 23325925
# 10628339
# 36435202
# 32112883
# 24058702
# 31883358
# 38323433
# 26112889
# 17250813
# 37871668
# 33437153
# 38150302
# 38316068
# 29061338
# 27567406
# 35914558
# 37714227
# 36510036
# 32958254
# 29304479
# Title: Protein Kinase C Epsilon Overexpression Protects the Heart Against Doxorubicin-Induced Cardiotoxicity Via Activating SIRT1.
# Summary:
# --------------------------------------------------

# %% [markdown]
# #############################
#
# week 2 old
#
# ##################################

# %%
# pip install transformers torch  pandas

# %%
"""
# week 2

import sqlite3
from transformers import pipeline
import pandas as pd

# Step 1: Set up the Hugging Face summarization model
print("Loading summarization model...")
summarizer = pipeline("summarization", model="facebook/bart-large-cnn")

# Step 2: Connect to the SQLite database
def connect_to_db():
    conn = sqlite3.connect("healthcare_research.db")
    return conn

# Step 3: Add a summary column to the database (if not already present)
def add_summary_column(conn):
    cursor = conn.cursor()
    # Check if 'summary' column exists, if not, add it
    cursor.execute("PRAGMA table_info(research_papers)")
    columns = [col[1] for col in cursor.fetchall()]
    if "summary" not in columns:
        cursor.execute("ALTER TABLE research_papers ADD COLUMN summary TEXT")
        print("Added 'summary' column to research_papers table.")
    conn.commit()

# Step 4: Summarize text
def generate_summary(text, max_length=150, min_length=30):
    try:
        # Truncate text if too long (BART has a max input length of 1024 tokens)
        if len(text) > 1000:
            text = text[:1000]
        summary = summarizer(text, max_length=max_length, min_length=min_length, do_sample=False)[0]['summary_text']
        return summary
    except Exception as e:
        print(f"Error summarizing text: {e}")
        return "Summary generation failed"

# Step 5: Process papers and update database
def summarize_papers():
    conn = connect_to_db()
    add_summary_column(conn)
    cursor = conn.cursor()

    # Fetch all papers (you can use 'abstract' or 'cleaned_text' for summarization)
    cursor.execute("SELECT id, filename, cleaned_text FROM research_papers WHERE summary IS NULL OR summary = ''")
    papers = cursor.fetchall()

    total_papers = len(papers)
    print(f"Found {total_papers} papers to summarize.")

    for idx, (paper_id, filename, text) in enumerate(papers, 1):
        print(f"Processing {idx}/{total_papers}: {filename}")

        if not text or len(text.strip()) < 50:  # Skip if text is too short or empty
            summary = "Text too short or empty for summarization"
        else:
            summary = generate_summary(text)

        # Update the database with the summary
        cursor.execute("UPDATE research_papers SET summary = ? WHERE id = ?", (summary, paper_id))
        conn.commit()
        print(f"Summary for {filename}: {summary[:100]}...")  # Print first 100 chars

    conn.close()
    print("Summarization complete. All summaries stored in the database.")

# Step 6: Verify the results
def verify_summaries():
    conn = connect_to_db()
    cursor = conn.cursor()

    cursor.execute("SELECT filename, title, summary FROM research_papers LIMIT 5")
    rows = cursor.fetchall()

    print("\nSample summaries from database:")
    for row in rows:
        print(f"Filename: {row[0]}")
        print(f"Title: {row[1]}")
        print(f"Summary: {row[2]}")
        print("-" * 50)

    conn.close()

# Run the script
if __name__ == "__main__":
    summarize_papers()
    verify_summaries()
    """
# Out:
# '\n# week 2\n\nimport sqlite3\nfrom transformers import pipeline\nimport pandas as pd\n\n# Step 1: Set up the Hugging Face summarization model\nprint("Loading summarization model...")\nsummarizer = pipeline("summarization", model="facebook/bart-large-cnn")\n\n# Step 2: Connect to the SQLite database\ndef connect_to_db():\n    conn = sqlite3.connect("healthcare_research.db")\n    return conn\n\n# Step 3: Add a summary column to the database (if not already present)\ndef add_summary_column(conn):\n    cursor = conn.cursor()\n    # Check if \'summary\' column exists, if not, add it\n    cursor.execute("PRAGMA table_info(research_papers)")\n    columns = [col[1] for col in cursor.fetchall()]\n    if "summary" not in columns:\n        cursor.execute("ALTER TABLE research_papers ADD COLUMN summary TEXT")\n        print("Added \'summary\' column to research_papers table.")\n    conn.commit()\n\n# Step 4: Summarize text\ndef generate_summary(text, max_length=150, min_length=30):\n    try:\n        # Truncate text if too long (BART has a max input length of 1024 tokens)\n        if len(text) > 1000:\n            text = text[:1000]\n        summary = summarizer(text, max_length=max_length, min_length=min_length, do_sample=False)[0][\'summary_text\']\n        return summary\n    except Exception as e:\n        print(f"Error summarizing text: {e}")\n        return "Summary generation failed"\n\n# Step 5: Process papers and update database\ndef summarize_papers():\n    conn = connect_to_db()\n    add_summary_column(conn)\n    cursor = conn.cursor()\n\n    # Fetch all papers (you can use \'abstract\' or \'cleaned_text\' for summarization)\n    cursor.execute("SELECT id, filename, cleaned_text FROM research_papers WHERE summary IS NULL OR summary = \'\'")\n    papers = cursor.fetchall()\n\n    total_papers = len(papers)\n    print(f"Found {total_papers} papers to summarize.")\n\n    for idx, (paper_id, filename, text) in enumerate(papers, 1):\n        print(f"Processing {idx}/{total_papers}: {filename}")\n\n        if not text or len(text.strip()) < 50:  # Skip if text is too short or empty\n            summary = "Text too short or empty for summarization"\n        else:\n            summary = generate_summary(text)\n\n        # Update the database with the summary\n        cursor.execute("UPDATE research_papers SET summary = ? WHERE id = ?", (summary, paper_id))\n        conn.commit()\n        print(f"Summary for {filename}: {summary[:100]}...")  # Print first 100 chars\n\n    conn.close()\n    print("Summarization complete. All summaries stored in the database.")\n\n# Step 6: Verify the results\ndef verify_summaries():\n    conn = connect_to_db()\n    cursor = conn.cursor()\n\n    cursor.execute("SELECT filename, title, summary FROM research_papers LIMIT 5")\n    rows = cursor.fetchall()\n\n    print("\nSample summaries from database:")\n    for row in rows:\n        print(f"Filename: {row[0]}")\n        print(f"Title: {row[1]}")\n        print(f"Summary: {row[2]}")\n        print("-" * 50)\n\n    conn.close()\n\n# Run the script\nif __name__ == "__main__":\n    summarize_papers()\n    verify_summaries()\n    '

# %% [markdown]
# ##################################################
#
# week 3
#
# ################################################
#
# BERTopic and visualization librarie

# %%
# !pip install bertopic pandas matplotlib seaborn wordcloud sqlite3
# !pip install bertopic
# !pip install bertopic matplotlib seaborn wordcloud pandas sqlite3
# !pip install bertopic matplotlib seaborn wordcloud pandas
# Out:
# Collecting bertopic
#   Downloading bertopic-0.17.0-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.11/dist-packages (1.9.4)
# ERROR: Could not find a version that satisfies the requirement sqlite3 (from versions: none)
# ERROR: No matching distribution found for sqlite3
# Collecting bertopic
#   Using cached bertopic-0.17.0-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: hdbscan>=0.8.29 in /usr/local/lib/python3.11/dist-packages (from bertopic) (0.8.40)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (2.0.2)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.11/dist-packages (from bertopic) (2.2.2)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (5.24.1)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (1.6.1)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from bertopic) (3.4.1)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.11/dist-packages (from bertopic) (4.67.1)
# Requirement already satisfied: umap-learn>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (0.5.7)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.11/dist-packages (from hdbscan>=0.8.29->bertopic) (1.15.2)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/dist-packages (from hdbscan>=0.8.29->bertopic) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=4.7.0->bertopic) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly>=4.7.0->bertopic) (24.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0->bertopic) (3.6.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.51.3)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.6.0+cu124)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.30.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (11.2.1)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.11/dist-packages (from umap-learn>=0.5.0->bertopic) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.11/dist-packages (from umap-learn>=0.5.0->bertopic) (0.5.13)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2025.3.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (4.13.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic) (1.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.5.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2025.4.26)
# Downloading bertopic-0.17.0-py3-none-any.whl (150 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.6/150.6 kB 9.2 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 75.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 23.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 15.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.7 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 93.7 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, bertopic
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed bertopic-0.17.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127
# Requirement already satisfied: bertopic in /usr/local/lib/python3.11/dist-packages (0.17.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# ^C
# ^C

# %%
"""
import sqlite3
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# Ensure Matplotlib uses a non-interactive backend
plt.switch_backend('agg')

# Step 1: Load Data from SQLite
def load_data_from_db():
    conn = sqlite3.connect("healthcare_research.db")
    query = "SELECT filename, cleaned_text FROM research_papers"
    df = pd.read_sql_query(query, conn)
    conn.close()
    print(f"Loaded {len(df)} records from the database.")
    print(f"Sample cleaned_text lengths: {df['cleaned_text'].str.len().head().tolist()}")
    return df

# Step 2: Topic Modeling with LDA
def perform_topic_modeling(df):
    docs = df["cleaned_text"].tolist()
    num_docs = len(docs)
    print(f"Number of documents: {num_docs}")

    if num_docs < 2:
        print("Too few documents for topic modeling (minimum 2 required).")
        return None, None, None

    # Vectorize the text
    vectorizer = CountVectorizer(max_df=0.95, min_df=2, stop_words='english')
    doc_term_matrix = vectorizer.fit_transform(docs)
    feature_names = vectorizer.get_feature_names_out()

    # Fit LDA model
    n_topics = min(5, num_docs)  # Limit topics to number of documents
    print(f"Using {n_topics} topics for LDA.")
    lda = LatentDirichletAllocation(n_components=n_topics, random_state=42)
    lda.fit(doc_term_matrix)

    # Get topic assignments for each document
    topic_assignments = lda.transform(doc_term_matrix).argmax(axis=1)
    df["topic"] = topic_assignments

    # Generate topic info (topic ID, keywords, count)
    topic_info = []
    for topic_idx in range(n_topics):
        top_words = [feature_names[i] for i in lda.components_[topic_idx].argsort()[:-10 - 1:-1]]
        num_docs_in_topic = (topic_assignments == topic_idx).sum()
        topic_info.append({
            "Topic": topic_idx,
            "Name": f"{topic_idx}_" + "_".join(top_words[:3]),
            "Keywords": ", ".join(top_words),
            "Count": num_docs_in_topic
        })
    topic_info_df = pd.DataFrame(topic_info)

    print("Topic modeling completed. Topic info:")
    print(topic_info_df.head(10))

    return lda, topic_info_df, df

# Step 3: Store Topic Results in SQLite
def store_topics_in_db(df, topic_info):
    conn = sqlite3.connect("healthcare_research.db")
    cursor = conn.cursor()

    # Drop the existing topics table to recreate with correct schema (or alter it)
    cursor.execute("DROP TABLE IF EXISTS topics")
    cursor.execute('''
        CREATE TABLE topics (
            topic_id INTEGER PRIMARY KEY,
            topic_name TEXT,
            keywords TEXT,
            num_documents INTEGER
        )
    ''')

    # Add topic_id column to research_papers if not exists
    try:
        cursor.execute('ALTER TABLE research_papers ADD COLUMN topic_id INTEGER')
    except sqlite3.OperationalError:
        print("Column topic_id already exists in research_papers, skipping alteration.")

    # Insert topic info
    for index, row in topic_info.iterrows():
        cursor.execute('''
            INSERT OR REPLACE INTO topics (topic_id, topic_name, keywords, num_documents)
            VALUES (?, ?, ?, ?)
        ''', (row["Topic"], row["Name"], row["Keywords"], row["Count"]))

    # Update research_papers with topic IDs
    for index, row in df.iterrows():
        if pd.notna(row["topic"]):
            cursor.execute('''
                UPDATE research_papers SET topic_id = ? WHERE filename = ?
            ''', (int(row["topic"]), row["filename"]))

    conn.commit()
    conn.close()
    print("Topic modeling results stored in database.")

# Step 4: Visualizations
def create_visualizations(topic_info):
    valid_topics = topic_info[topic_info["Count"] > 0]  # Exclude empty topics
    if valid_topics.empty:
        print("No valid topics found. No visualizations created.")
        return

    # Bar chart
    plt.figure(figsize=(10, 6))
    sns.barplot(x="Count", y="Name", data=valid_topics.head(10))
    plt.title("Top 10 Most Common Topics")
    plt.xlabel("Number of Documents")
    plt.ylabel("Topic Name")
    plt.tight_layout()
    plt.savefig("top_topics_bar_chart.png")
    print("Saved bar chart to 'top_topics_bar_chart.png'")
    plt.close()

    # Word clouds
    top_topics = valid_topics.head(5)["Topic"].tolist()
    for topic_id in top_topics:
        keywords = valid_topics[valid_topics["Topic"] == topic_id]["Keywords"].iloc[0].split(", ")
        word_dict = {word: 1.0 / (i + 1) for i, word in enumerate(keywords)}  # Simple weighting
        wordcloud = WordCloud(width=800, height=400, background_color="white").generate_from_frequencies(word_dict)
        plt.figure(figsize=(10, 5))
        plt.imshow(wordcloud, interpolation="bilinear")
        plt.axis("off")
        plt.title(f"Word Cloud for Topic {topic_id}: {valid_topics[valid_topics['Topic'] == topic_id]['Name'].iloc[0]}")
        plt.savefig(f"wordcloud_topic_{topic_id}.png")
        print(f"Saved word cloud for Topic {topic_id} to 'wordcloud_topic_{topic_id}.png'")
        plt.close()

# Main execution
if __name__ == "__main__":
    df = load_data_from_db()
    if df.empty:
        print("No data found in the database. Please ensure the research_papers table is populated.")
    else:
        lda_model, topic_info, df_with_topics = perform_topic_modeling(df)
        if lda_model is None:
            print("Topic modeling failed. Check error messages above.")
        else:
            store_topics_in_db(df_with_topics, topic_info)
            create_visualizations(topic_info)
  """
# Out:
# Loaded 106 records from the database.
# Sample cleaned_text lengths: [74782, 26401, 44194, 14468, 38267]
# Number of documents: 106
# Using 5 topics for LDA.
# Topic modeling completed. Topic info:
#    Topic                           Name  \
# 0      0         0_public_care_services
# 1      1        1_waste_medical_patient
# 2      2            2_pain_mg_treatment
# 3      3     3_countries_mortality_data
# 4      4  4_information_hispanic_states
#
#                                             Keywords  Count
# 0  public, care, services, al, et, policy, global...     32
# 1  waste, medical, patient, hospitals, operating,...     10
# 2  pain, mg, treatment, patients, patient, manage...     30
# 3  countries, mortality, data, years, age, deaths...     24
# 4  information, hispanic, states, united, table, ...     10
# Column topic_id already exists in research_papers, skipping alteration.
# Topic modeling results stored in database.
# Saved bar chart to 'top_topics_bar_chart.png'
# Saved word cloud for Topic 0 to 'wordcloud_topic_0.png'
# Saved word cloud for Topic 1 to 'wordcloud_topic_1.png'
# Saved word cloud for Topic 2 to 'wordcloud_topic_2.png'
# Saved word cloud for Topic 3 to 'wordcloud_topic_3.png'
# Saved word cloud for Topic 4 to 'wordcloud_topic_4.png'

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Dummy data
data = np.random.rand(10, 12)

plt.figure(figsize=(8, 6))
sns.heatmap(data, annot=True, fmt=".2f", cmap='YlGnBu')
plt.title("Sample Heatmap")
plt.tight_layout()
plt.show()
sns.heatmap(data, annot=True, fmt=".2f", cmap='YlGnBu')
plt.title("Sample Heatmap")
plt.tight_layout()
plt.show()

# %% [markdown]
# week 3 new with network/heat

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import networkx as nx
from scipy.sparse import csr_matrix
from datetime import datetime

def create_advanced_visualizations(df_with_topics, topic_info):
    # Assign random dates if not already present
    if 'date' not in df_with_topics.columns:
        df_with_topics['date'] = pd.to_datetime(np.random.choice(
            pd.date_range('2020-01-01', '2025-03-30', freq='M'),
            size=len(df_with_topics)
        ))

    # Ensure consistent topic indexing
    topics = sorted(df_with_topics['topic'].unique())
    topic_to_idx = {topic: idx for idx, topic in enumerate(topics)}
    co_occurrence = np.zeros((len(topics), len(topics)))

    # Compute co-occurrence matrix
    for i, topic_i in enumerate(topics):
        for j, topic_j in enumerate(topics):
            if i <= j:
                keywords_list = topic_info[topic_info['Topic'] == topic_j]['Keywords']
                if not keywords_list.empty:
                    keywords = keywords_list.iloc[0].split(', ')
                    co_occurrence[i, j] = len(df_with_topics[
                        (df_with_topics['topic'] == topic_i) &
                        (df_with_topics['cleaned_text'].str.contains('|'.join(keywords)))
                    ])
                co_occurrence[j, i] = co_occurrence[i, j]

    # === 1. Heatmap ===
    plt.figure(figsize=(10, 8))
    sns.heatmap(co_occurrence, annot=True, fmt='.0f', cmap='YlGnBu',
                xticklabels=[f"Topic {t}" for t in topics],
                yticklabels=[f"Topic {t}" for t in topics])
    plt.title("Topic Co-occurrence Heatmap")
    plt.tight_layout()
    plt.savefig("topic_cooccurrence_heatmap.png")
    plt.show()

    # === 2. Bubble Plot Over Time ===
    df_with_topics['year'] = df_with_topics['date'].dt.year
    topic_time = df_with_topics.groupby(['year', 'topic']).size().reset_index(name='count')
    topic_time = topic_time.merge(topic_info[['Topic', 'Name']], left_on='topic', right_on='Topic')

    plt.figure(figsize=(12, 8))
    bubble_size = 100 * (topic_time['count'] / topic_time['count'].max())
    scatter = plt.scatter(topic_time['year'], topic_time['Name'],
                          s=bubble_size, alpha=0.5, c=topic_time['topic'], cmap='viridis')
    plt.colorbar(scatter, label='Topic ID')
    plt.xlabel("Year")
    plt.ylabel("Topic Name")
    plt.title("Topic Importance Over Time (Bubble Size = Document Count)")
    plt.tight_layout()
    plt.savefig("topic_importance_bubble.png")
    plt.show()

    # === 3. Network Graph ===
    G = nx.Graph()
    for _, row in topic_info.iterrows():
        G.add_node(row['Topic'], size=row['Count'], label=row['Name'])

    threshold = np.percentile(co_occurrence.flatten(), 75)
    for i, topic_i in enumerate(topics):
        for j, topic_j in enumerate(topics):
            if i < j and co_occurrence[i, j] > threshold:
                G.add_edge(topic_i, topic_j, weight=co_occurrence[i, j])

    plt.figure(figsize=(12, 10))
    pos = nx.spring_layout(G, k=0.5)
    sizes = [G.nodes[n]['size'] * 20 for n in G.nodes]
    nx.draw_networkx_nodes(G, pos, node_size=sizes, node_color='skyblue', alpha=0.7)
    nx.draw_networkx_edges(G, pos, width=[d['weight']/10 for (u, v, d) in G.edges(data=True)], alpha=0.5)
    nx.draw_networkx_labels(G, pos, labels={n: G.nodes[n]['label'] for n in G.nodes}, font_size=8)

    # Optional edge labels (uncomment if desired)
    # edge_labels = {(u, v): f"{d['weight']:.0f}" for u, v, d in G.edges(data=True)}
    # nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=7)

    plt.title("Network Graph of Topic Relationships")
    plt.axis('off')
    plt.tight_layout()
    plt.savefig("topic_relationships_network.png")
    plt.show()


# # Ensure Matplotlib uses a non-interactive backend
# plt.switch_backend('agg')

# # Step 5: Additional Visualizations
# def create_advanced_visualizations(df_with_topics, topic_info):
#     # Assuming filename might contain a date or we need to simulate dates
#     # For this example, we'll simulate dates if not available
#     if 'date' not in df_with_topics.columns:
#         df_with_topics['date'] = pd.to_datetime(np.random.choice(
#             pd.date_range('2020-01-01', '2025-03-30', freq='M'),
#             size=len(df_with_topics)
#         ))

#     # --- Heatmap: Topic Co-occurrence ---
#     # Create a co-occurrence matrix
#     topics = df_with_topics['topic'].unique()
#     co_occurrence = np.zeros((len(topics), len(topics)))
#     for i, topic_i in enumerate(topics):
#         for j, topic_j in enumerate(topics):
#             if i <= j:  # Only calculate upper triangle to avoid duplication
#                 co_occurrence[i, j] = len(df_with_topics[
#                     (df_with_topics['topic'] == topic_i) &
#                     (df_with_topics['cleaned_text'].str.contains('|'.join(
#                         topic_info[topic_info['Topic'] == topic_j]['Keywords'].iloc[0].split(', ')
#                     )))
#                 ])
#                 co_occurrence[j, i] = co_occurrence[i, j]  # Symmetric matrix

#     plt.figure(figsize=(10, 8))
#     sns.heatmap(co_occurrence, annot=True, fmt='.0f', cmap='YlGnBu',
#                 xticklabels=[f"Topic {t}" for t in topics],
#                 yticklabels=[f"Topic {t}" for t in topics])
#     plt.title("Topic Co-occurrence Heatmap")
#     plt.tight_layout()
#     plt.savefig("topic_cooccurrence_heatmap.png")
#     print("Saved heatmap to 'topic_cooccurrence_heatmap.png'")
#     plt.close()

#     # --- Bubble Chart: Topic Importance Over Time ---
#     # Aggregate topic counts by year
#     df_with_topics['year'] = df_with_topics['date'].dt.year
#     topic_time = df_with_topics.groupby(['year', 'topic']).size().reset_index(name='count')
#     topic_time = topic_time.merge(topic_info[['Topic', 'Name']], left_on='topic', right_on='Topic')

#     plt.figure(figsize=(12, 8))
#     plt.scatter(topic_time['year'], topic_time['Name'], s=topic_time['count']*100,
#                 alpha=0.5, c=topic_time['topic'], cmap='viridis')
#     plt.colorbar(label='Topic ID')
#     plt.xlabel("Year")
#     plt.ylabel("Topic Name")
#     plt.title("Topic Importance Over Time (Bubble Size = Document Count)")
#     plt.tight_layout()
#     plt.savefig("topic_importance_bubble.png")
#     print("Saved bubble chart to 'topic_importance_bubble.png'")
#     plt.close()

#     # --- Network Graph: Topic Relationships ---
#     G = nx.Graph()
#     # Add nodes (topics)
#     for _, row in topic_info.iterrows():
#         G.add_node(row['Topic'], size=row['Count'], label=row['Name'])

#     # Add edges based on co-occurrence (threshold to reduce clutter)
#     threshold = np.percentile(co_occurrence.flatten(), 75)  # Top 25% of co-occurrences
#     for i, topic_i in enumerate(topics):
#         for j, topic_j in enumerate(topics):
#             if i < j and co_occurrence[i, j] > threshold:
#                 G.add_edge(topic_i, topic_j, weight=co_occurrence[i, j])

#     plt.figure(figsize=(12, 10))
#     pos = nx.spring_layout(G, k=0.5)
#     sizes = [G.nodes[n]['size'] * 20 for n in G.nodes]
#     nx.draw_networkx_nodes(G, pos, node_size=sizes, node_color='skyblue', alpha=0.7)
#     nx.draw_networkx_edges(G, pos, width=[d['weight']/10 for (u, v, d) in G.edges(data=True)],
#                            alpha=0.5)
#     nx.draw_networkx_labels(G, pos, labels={n: G.nodes[n]['label'] for n in G.nodes},
#                             font_size=8)
#     plt.title("Network Graph of Topic Relationships")
#     plt.axis('off')
#     plt.tight_layout()
#     plt.savefig("topic_relationships_network.png")
#     print("Saved network graph to 'topic_relationships_network.png'")
#     plt.close()

# # Update main execution to include new visualizations
# if __name__ == "__main__":
#     df = load_data_from_db()
#     if df.empty:
#         print("No data found in the database. Please ensure the research_papers table is populated.")
#     else:
#         lda_model, topic_info, df_with_topics = perform_topic_modeling(df)
#         if lda_model is None:
#             print("Topic modeling failed. Check error messages above.")
#         else:
#             store_topics_in_db(df_with_topics, topic_info)
#             create_visualizations(topic_info)
#             create_advanced_visualizations(df_with_topics, topic_info)

# %% [markdown]
# week 3 new 3

# %%
# Install required packages
# !pip install bertopic pandas matplotlib seaborn wordcloud sqlite3
# !pip install scikit-learn  # For TF-IDF and other utilities

import sqlite3
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from bertopic import BERTopic
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
import networkx as nx
from datetime import datetime

# Ensure Matplotlib uses a non-interactive backend
plt.switch_backend('agg')

# Step 1: Load Data from SQLite
def load_data_from_db():
    conn = sqlite3.connect("healthcare_research.db")
    query = "SELECT filename, cleaned_text FROM research_papers"
    df = pd.read_sql_query(query, conn)
    conn.close()
    print(f"Loaded {len(df)} records from the database.")
    print(f"Sample cleaned_text lengths: {df['cleaned_text'].str.len().head().tolist()}")
    return df

# Step 2a: Topic Modeling with Improved LDA (using TF-IDF)
def perform_lda_topic_modeling(df):
    docs = df["cleaned_text"].dropna().tolist()  # Drop NaN values
    num_docs = len(docs)
    print(f"Number of documents for LDA: {num_docs}")

    if num_docs < 2:
        print("Too few documents for LDA (minimum 2 required).")
        return None, None, None

    # Use TF-IDF instead of CountVectorizer
    vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, stop_words='english')
    doc_term_matrix = vectorizer.fit_transform(docs)
    feature_names = vectorizer.get_feature_names_out()

    # Fit LDA model
    n_topics = min(5, num_docs)
    print(f"Using {n_topics} topics for LDA.")
    lda = LatentDirichletAllocation(n_components=n_topics, random_state=42)
    lda.fit(doc_term_matrix)

    # Get topic assignments
    topic_assignments = lda.transform(doc_term_matrix).argmax(axis=1)
    df.loc[df["cleaned_text"].notna(), "lda_topic"] = topic_assignments

    # Generate topic info
    topic_info = []
    for topic_idx in range(n_topics):
        top_words = [feature_names[i] for i in lda.components_[topic_idx].argsort()[:-10 - 1:-1]]
        num_docs_in_topic = (topic_assignments == topic_idx).sum()
        topic_info.append({
            "Topic": topic_idx,
            "Name": f"{topic_idx}_" + "_".join(top_words[:3]),
            "Keywords": ", ".join(top_words),
            "Count": num_docs_in_topic
        })
    topic_info_df = pd.DataFrame(topic_info)
    print("LDA Topic modeling completed. Topic info:")
    print(topic_info_df.head(10))
    return lda, topic_info_df, df

# Step 2b: Topic Modeling with BERTopic
def perform_bertopic_modeling(df):
    docs = df["cleaned_text"].dropna().tolist()
    num_docs = len(docs)
    print(f"Number of documents for BERTopic: {num_docs}")

    if num_docs < 2:
        print("Too few documents for BERTopic (minimum 2 required).")
        return None, None

    # Initialize and fit BERTopic
    topic_model = BERTopic(nr_topics="auto", min_topic_size=2, verbose=True)
    topics, _ = topic_model.fit_transform(docs)
    df.loc[df["cleaned_text"].notna(), "bertopic"] = topics

    # Get topic info
    topic_info = topic_model.get_topic_info()
    topic_info = topic_info.rename(columns={"Topic": "Topic", "Count": "Count", "Name": "Name"})
    topic_info["Keywords"] = topic_info["Topic"].apply(
        lambda x: ", ".join([word for word, _ in topic_model.get_topic(x)[:10]]) if x >= 0 else "N/A"
    )
    print("BERTopic modeling completed. Topic info:")
    print(topic_info.head(10))
    return topic_model, topic_info, df

# Step 2c: Dynamic Topic Modeling (LDA over time)
def perform_dynamic_topic_modeling(df):
    docs = df["cleaned_text"].dropna().tolist()
    if 'date' not in df.columns:
        df['date'] = pd.to_datetime(np.random.choice(
            pd.date_range('2020-01-01', '2025-03-30', freq='M'),
            size=len(df)
        ))
    df['year'] = df['date'].dt.year

    dynamic_results = []
    for year in sorted(df['year'].unique()):
        year_docs = df[df['year'] == year]["cleaned_text"].dropna().tolist()
        if len(year_docs) < 2:
            continue
        vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, stop_words='english')
        doc_term_matrix = vectorizer.fit_transform(year_docs)
        n_topics = min(5, len(year_docs))
        lda = LatentDirichletAllocation(n_components=n_topics, random_state=42)
        lda.fit(doc_term_matrix)
        topic_dist = lda.transform(doc_term_matrix).sum(axis=0)
        dynamic_results.append({"Year": year, "Topic_Distribution": topic_dist / topic_dist.sum()})

    dynamic_df = pd.DataFrame(dynamic_results)
    print("Dynamic topic modeling completed.")
    return dynamic_df, df

# Step 3: Store Results in SQLite
def store_results_in_db(df, lda_info, bertopic_info):
    conn = sqlite3.connect("healthcare_research.db")
    cursor = conn.cursor()

    # Update topics table for LDA
    cursor.execute("DROP TABLE IF EXISTS lda_topics")
    cursor.execute('''
        CREATE TABLE lda_topics (
            topic_id INTEGER PRIMARY KEY,
            topic_name TEXT,
            keywords TEXT,
            num_documents INTEGER
        )
    ''')
    for _, row in lda_info.iterrows():
        cursor.execute('''
            INSERT INTO lda_topics (topic_id, topic_name, keywords, num_documents)
            VALUES (?, ?, ?, ?)
        ''', (row["Topic"], row["Name"], row["Keywords"], row["Count"]))

    # Create table for BERTopic
    cursor.execute("DROP TABLE IF EXISTS bertopic_topics")
    cursor.execute('''
        CREATE TABLE bertopic_topics (
            topic_id INTEGER PRIMARY KEY,
            topic_name TEXT,
            keywords TEXT,
            num_documents INTEGER
        )
    ''')
    for _, row in bertopic_info.iterrows():
        if row["Topic"] >= 0:  # Exclude -1 (outliers in BERTopic)
            cursor.execute('''
                INSERT INTO bertopic_topics (topic_id, topic_name, keywords, num_documents)
                VALUES (?, ?, ?, ?)
            ''', (row["Topic"], row["Name"], row["Keywords"], row["Count"]))

    # Update research_papers with topic IDs
    try:
        cursor.execute('ALTER TABLE research_papers ADD COLUMN lda_topic_id INTEGER')
        cursor.execute('ALTER TABLE research_papers ADD COLUMN bertopic_id INTEGER')
    except sqlite3.OperationalError:
        pass  # Columns might already exist

    for _, row in df.iterrows():
        if pd.notna(row.get("lda_topic")):
            cursor.execute('UPDATE research_papers SET lda_topic_id = ? WHERE filename = ?',
                           (int(row["lda_topic"]), row["filename"]))
        if pd.notna(row.get("bertopic")) and row["bertopic"] >= 0:
            cursor.execute('UPDATE research_papers SET bertopic_id = ? WHERE filename = ?',
                           (int(row["bertopic"]), row["filename"]))

    conn.commit()
    conn.close()
    print("Results stored in database.")

# Step 4: Visualizations (Updated for all models)
def create_visualizations(lda_info, bertopic_info, dynamic_df):
    # LDA Bar Chart
    plt.figure(figsize=(10, 6))
    sns.barplot(x="Count", y="Name", data=lda_info.head(10))
    plt.title("Top 10 LDA Topics")
    plt.savefig("lda_top_topics.png")
    plt.close()

    # BERTopic Bar Chart
    valid_topics = bertopic_info[bertopic_info["Topic"] >= 0]
    plt.figure(figsize=(10, 6))
    sns.barplot(x="Count", y="Name", data=valid_topics.head(10))
    plt.title("Top 10 BERTopic Topics")
    plt.savefig("bertopic_top_topics.png")
    plt.close()

    # Dynamic Topic Evolution
    if not dynamic_df.empty:
        plt.figure(figsize=(12, 6))
        for i in range(dynamic_df["Topic_Distribution"].iloc[0].shape[0]):
            plt.plot(dynamic_df["Year"], dynamic_df["Topic_Distribution"].apply(lambda x: x[i]),
                     label=f"Topic {i}")
        plt.title("Dynamic Topic Evolution Over Time")
        plt.xlabel("Year")
        plt.ylabel("Topic Prevalence")
        plt.legend()
        plt.savefig("dynamic_topic_evolution.png")
        plt.close()
        print("Saved dynamic topic evolution plot.")

# Main execution
if __name__ == "__main__":
    df = load_data_from_db()
    if df.empty:
        print("No data found in the database.")
    else:
        # LDA with TF-IDF
        lda_model, lda_info, df = perform_lda_topic_modeling(df)

        # BERTopic
        bertopic_model, bertopic_info, df = perform_bertopic_modeling(df)

        # Dynamic Topic Modeling
        dynamic_df, df = perform_dynamic_topic_modeling(df)

        if lda_model and bertopic_model:
            store_results_in_db(df, lda_info, bertopic_info)
            create_visualizations(lda_info, bertopic_info, dynamic_df)
        else:
            print("One or more topic modeling steps failed.")
# Out:
# Requirement already satisfied: bertopic in /usr/local/lib/python3.11/dist-packages (0.17.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.11/dist-packages (1.9.4)
# ERROR: Could not find a version that satisfies the requirement sqlite3 (from versions: none)
# ERROR: No matching distribution found for sqlite3
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Loaded 1074 records from the database.
# Sample cleaned_text lengths: [1727, 1937, 2275, 1640, 1636]
# Number of documents for LDA: 1074
# Using 5 topics for LDA.
# 2025-05-07 00:56:26,953 - BERTopic - Embedding - Transforming documents to embeddings.
# LDA Topic modeling completed. Topic info:
#    Topic                            Name  \
# 0      0  0_healthcare_innovation_health
# 1      1                1_sha_laura_miao
# 2      2     2_forces_sections_following
# 3      3    3_celebration_yunan_michigan
# 4      4      4_lawton_greenhalgh_trisha
#
#                                             Keywords  Count
# 0  healthcare, innovation, health, care, data, in...   1072
# 1  sha, laura, miao, qu, shu, xing, films, datta,...      0
# 2  forces, sections, following, col, redefining, ...      1
# 3  celebration, yunan, michigan, arbor, ann, beth...      0
# 4  lawton, greenhalgh, trisha, burns, testosteron...      1
# Number of documents for BERTopic: 1074
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/34 [00:00<?, ?it/s]
# 2025-05-07 00:58:02,297 - BERTopic - Embedding - Completed ✓
# 2025-05-07 00:58:02,299 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-05-07 00:58:16,722 - BERTopic - Dimensionality - Completed ✓
# 2025-05-07 00:58:16,724 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-05-07 00:58:16,797 - BERTopic - Cluster - Completed ✓
# 2025-05-07 00:58:16,798 - BERTopic - Representation - Extracting topics using c-TF-IDF for topic reduction.
# 2025-05-07 00:58:17,404 - BERTopic - Representation - Completed ✓
# 2025-05-07 00:58:17,405 - BERTopic - Topic reduction - Reducing number of topics
# 2025-05-07 00:58:17,435 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-05-07 00:58:17,950 - BERTopic - Representation - Completed ✓
# 2025-05-07 00:58:17,953 - BERTopic - Topic reduction - Reduced number of topics from 99 to 34
# BERTopic modeling completed. Topic info:
#    Topic  Count                                     Name  \
# 0     -1    170                         -1_and_the_of_to
# 1      0    366                          0_the_and_of_to
# 2      1    320                                    1____
# 3      2     47            2_health_disease_public_years
# 4      3     30                                    3____
# 5      4     21          4_blockchain_the_and_technology
# 6      5     12  5_flexible_wearable_electronics_sensors
# 7      6     10                    6_iot_the_and_devices
# 8      7      9                    7_of_the_education_in
# 9      8      8               8_hydronephrosis_ai_and_of
#
#                                       Representation  \
# 0  [and, the, of, to, in, waste, healthcare, for,...
# 1  [the, and, of, to, in, innovation, healthcare,...
# 2                               [, , , , , , , , , ]
# 3  [health, disease, public, years, care, global,...
# 4                               [, , , , , , , , , ]
# 5  [blockchain, the, and, technology, of, for, in...
# 6  [flexible, wearable, electronics, sensors, and...
# 7  [iot, the, and, devices, of, security, in, com...
# 8  [of, the, education, in, and, for, to, as, edu...
# 9  [hydronephrosis, ai, and, of, the, in, to, mri...
#
#                                  Representative_Docs  \
# 0  [backgroundimplementation of digital monitorin...
# 1  [background artificial intelligence ai for hea...
# 2                                             [, , ]
# 3  [introduction health policy copying distributi...
# 4                                             [, , ]
# 5  [blockchain technology is among the most signi...
# 6  [the emergence of textilebased wearable sensor...
# 7  [the impact of the internet of things iot on t...
# 8  [abstract medical education has changed focus ...
# 9  [twodimensional d assessment of renal volume u...
#
#                                             Keywords
# 0                                                N/A
# 1  the, and, of, to, in, innovation, healthcare, ...
# 2                                 , , , , , , , , ,
# 3  health, disease, public, years, care, global, ...
# 4                                 , , , , , , , , ,
# 5  blockchain, the, and, technology, of, for, in,...
# 6  flexible, wearable, electronics, sensors, and,...
# 7  iot, the, and, devices, of, security, in, comp...
# 8  of, the, education, in, and, for, to, as, educ...
# 9  hydronephrosis, ai, and, of, the, in, to, mri,...
# Dynamic topic modeling completed.
# Results stored in database.
# Saved dynamic topic evolution plot.

# %% [markdown]
# tranfering image to database

# %% [markdown]
# # New Section

# %%
import sqlite3
import os

# List of PNG files to store in the database
png_files = [
    "bertopic_top_topics.png",  # N
    "dynamic_topic_evolution.png",
    "lda_top_topics.png",  # Corrected from "Ida_top_topics.png" assuming it's a typo
    "top_topics_bar_chart.png",
    "topic_cooccurrence_heatmap.png",
    "topic_importance_bubble.png",
    "topic_relationships_network.png",
    "wordcloud_topic_0.png",  # Corrected "wordcloud_topic_o.png" to "wordcloud_topic_0.png" assuming typo
    "wordcloud_topic_1.png",
    "wordcloud_topic_2.png",  # Corrected "wordcloud_topic_2png" to "wordcloud_topic_2.png"
    "wordcloud_topic_3.png",
    "wordcloud_topic_4.png",
    "research_papers_table.png"
]

# Function to store PNG files in the database
def store_pngs_in_db(png_files, db_name="healthcare_research.db"):
    # Connect to the database
    conn = sqlite3.connect(db_name)
    cursor = conn.cursor()

    # Create a table for storing images if it doesn't exist
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS visualizations (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            filename TEXT UNIQUE,
            image_data BLOB
        )
    ''')

    # Store each PNG file
    for png_file in png_files:
        if os.path.exists(png_file):
            try:
                with open(png_file, 'rb') as file:
                    image_data = file.read()
                cursor.execute('''
                    INSERT OR REPLACE INTO visualizations (filename, image_data)
                    VALUES (?, ?)
                ''', (png_file, sqlite3.Binary(image_data)))
                print(f"Stored {png_file} in the database.")
            except Exception as e:
                print(f"Error storing {png_file}: {e}")
        else:
            print(f"File {png_file} not found. Skipping.")

    # Commit changes and close connection
    conn.commit()
    conn.close()
    print("All available PNG files have been stored in the database.")

# Execute the function
if __name__ == "__main__":
    store_pngs_in_db(png_files)
# Out:
# Stored bertopic_top_topics.png in the database.
# Stored dynamic_topic_evolution.png in the database.
# Stored lda_top_topics.png in the database.
# File top_topics_bar_chart.png not found. Skipping.
# File topic_cooccurrence_heatmap.png not found. Skipping.
# File topic_importance_bubble.png not found. Skipping.
# File topic_relationships_network.png not found. Skipping.
# File wordcloud_topic_0.png not found. Skipping.
# File wordcloud_topic_1.png not found. Skipping.
# File wordcloud_topic_2.png not found. Skipping.
# File wordcloud_topic_3.png not found. Skipping.
# File wordcloud_topic_4.png not found. Skipping.
# Stored research_papers_table.png in the database.
# All available PNG files have been stored in the database.
